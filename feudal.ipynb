# %%
#!/usr/bin/env python3
"""
A complete Feudal Reinforcement Learning example from scratch, using a
3D milling environment as the training testbed. This code demonstrates:

1. A 3D voxel-based milling simulation (stock + shape).
2. A hierarchical RL setup (Feudal RL) with:
   - Manager Network: Produces a subgoal (3D router target or region).
   - Worker Network: Executes fine-grained actions to achieve that subgoal.
3. Two replay buffers (one for Manager, one for Worker).
4. Training loop with separate updates for Manager and Worker.
5. TensorBoard logging for monitoring progress.

DISCLAIMER:
- This code is a didactic, end-to-end *example*. It may need tuning,
  optimizations, or expansions (e.g., advanced replay strategies, 
  target networks, deeper architectures, etc.) to perform well in 
  real applications. But it lays out the essential pieces.
- The environment is simplified for demonstration; real CNC milling 
  involves more complex geometry and physics.
- The feudal approach here is fairly minimal; advanced FeUdal networks 
  or Option-Critic expansions can refine the concept.

USAGE:
    python feudal_milling.py

Then run:
    tensorboard --logdir=runs
to monitor training curves.

Enjoy!
"""

import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import imageio
import os
import datetime

from torch.utils.tensorboard import SummaryWriter

########################################################
# 1) ENVIRONMENT DEFINITION (3D VOXEL MILLING)
########################################################

class Milling3DEnvFeudal:
    """
    A simplified 3D milling environment with:
    - stock[x,y,z] = 1 means material present, 0 means removed
    - shape[x,y,z] = 1 means protected shape
    - router_pos = (rx, ry, rz) within [0, N-1]
    - 6 discrete worker actions: ±x, ±y, ±z (small 1-step moves)
    - The manager sets a subgoal coordinate in the grid,
      which the worker tries to reach.

    NOTE: The manager does NOT directly interact with the environment. 
    We store subgoals in the environment's state so the worker can 
    see them. For clarity, 'manager_step()' is done externally 
    in the training loop.
    """

    def __init__(
        self,
        grid_size=8,
        max_steps=200,
        penalty_cut_shape=10.0,
        reward_outside_cut=1.0,
        success_bonus=30.0,
        step_penalty=0.1,
        min_radius=2,
        max_radius=3
    ):
        """
        :param grid_size: NxNxN
        :param max_steps: episode terminates after these many worker steps
        :param penalty_cut_shape: penalty for removing shape voxel
        :param reward_outside_cut: reward for removing outside voxel
        :param success_bonus: reward if all outside is removed
        :param step_penalty: small penalty each step
        :param min_radius, max_radius: random sphere radius for shape
        """
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.penalty_cut_shape = penalty_cut_shape
        self.reward_outside_cut = reward_outside_cut
        self.success_bonus = success_bonus
        self.step_penalty = step_penalty
        self.min_radius = min_radius
        self.max_radius = max_radius

        # Worker has 6 discrete actions
        self.worker_action_space = [0,1,2,3,4,5]  # +x,-x,+y,-y,+z,-z
        self.reset()

    def reset(self):
        self.stock = np.ones((self.grid_size, self.grid_size, self.grid_size), dtype=int)
        self.shape = np.zeros((self.grid_size, self.grid_size, self.grid_size), dtype=int)

        # random sphere for shape in center
        cx = self.grid_size // 2
        cy = self.grid_size // 2
        cz = self.grid_size // 2
        radius = np.random.randint(self.min_radius, self.max_radius+1)
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                for z in range(self.grid_size):
                    dist_sq = (x-cx)**2 + (y-cy)**2 + (z-cz)**2
                    if dist_sq <= radius**2:
                        self.shape[x,y,z] = 1

        # router at (0,0,0)
        self.router_pos = np.array([0,0,0], dtype=int)
        self.steps_taken = 0

        # subgoal (set by manager externally), initialize to center
        self.subgoal = np.array([cx,cy,cz], dtype=int)

        # track done or not
        self.done = False

        # return manager observation, worker observation as needed
        return self._get_manager_obs(), self._get_worker_obs()

    def set_subgoal(self, subgoal):
        """
        The manager calls this to set subgoal, shape = (3,).
        We clamp within the environment's boundaries.
        """
        subgoal = np.clip(subgoal, 0, self.grid_size-1)
        self.subgoal = subgoal.astype(int)

    def worker_step(self, action):
        """
        The worker acts with a discrete action in [0..5].
        Returns (worker_obs, worker_reward, done).
        Manager is updated externally.
        """
        if self.done:
            # If environment is already done, no further changes
            return self._get_worker_obs(), 0.0, True

        # decode action
        if action == 0:  # +x
            self.router_pos[0] += 1
        elif action == 1:  # -x
            self.router_pos[0] -= 1
        elif action == 2:  # +y
            self.router_pos[1] += 1
        elif action == 3:  # -y
            self.router_pos[1] -= 1
        elif action == 4:  # +z
            self.router_pos[2] += 1
        elif action == 5:  # -z
            self.router_pos[2] -= 1

        # clamp
        self.router_pos = np.clip(self.router_pos, 0, self.grid_size-1)
        rx, ry, rz = self.router_pos

        self.steps_taken += 1

        # compute reward for the worker
        worker_reward = 0.0

        # if we cut a voxel
        if self.stock[rx, ry, rz] == 1:
            self.stock[rx, ry, rz] = 0
            if self.shape[rx, ry, rz] == 1:
                # shape => big penalty
                worker_reward -= self.penalty_cut_shape
                self.done = True
            else:
                # outside => small positive
                worker_reward += self.reward_outside_cut

        # step penalty
        worker_reward -= self.step_penalty

        # check if all outside stock is removed
        outside_mask = (self.shape == 0)
        if np.sum(self.stock[outside_mask]) == 0:
            worker_reward += self.success_bonus
            self.done = True

        # check step limit
        if self.steps_taken >= self.max_steps:
            self.done = True

        # worker also gets an intrinsic reward for moving closer to subgoal
        subgoal_dist_before = 0.0  # we need to define a "before" measure if we want difference-based
        # In a typical approach, you'd store the old position, but let's do a simpler direct approach:
        # negative distance to subgoal, i.e. -||router - subgoal||. We'll incorporate it directly.
        dist = np.linalg.norm(self.router_pos - self.subgoal)
        # We'll do: worker_reward += -0.1 * dist  (some weighting)
        # but to be consistent each step, let's do it:
        worker_reward -= 0.1 * dist

        # now we have a partial measure of "intrinsic" subgoal approach
        # in practice, you'd define a more advanced shaping.

        # build next worker obs
        w_obs = self._get_worker_obs()
        return w_obs, worker_reward, self.done

    def manager_reward(self):
        """
        Manager reward is based on global progress:
        - fraction of outside stock removed
        - penalty if shape is cut
        - success if everything is removed
        For simplicity, let's do:
          R = (outside_removed_frac) * 10
              - (shape_cut_count) * 5
        plus a big bonus if done successfully
        We'll do a simpler approach: measure at the end of manager's timescale.
        """
        # count how many shape voxels are cut:
        shape_cut = (self.shape == 1) & (self.stock == 0)
        shape_cut_count = np.sum(shape_cut)

        # fraction outside removed:
        outside_mask = (self.shape == 0)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_outside_removed = outside_removed / (outside_total + 1e-8)

        # define a simple manager reward function
        # e.g. manager gets +10 * frac_outside_removed - 5*(cut shape count)
        # This is only a demonstration. Tuning is needed in real usage.
        r = 10.0 * frac_outside_removed - 5.0 * shape_cut_count
        return r

    def manager_done(self):
        """ 
        The manager can be considered 'done' when the environment is done 
        or if we want it to set subgoals multiple times per episode. 
        Typically, we keep manager's episode = env episode for simplicity. 
        """
        return self.done

    def _get_manager_obs(self):
        """
        Manager can see a downsampled version of the stock + shape,
        or a summarized feature. 
        Here, let's do a naive approach: flatten everything 
        but then downsample drastically or just flatten the full grid 
        (not recommended if large).
        We'll do a naive flatten for demonstration. In real usage, 
        you'd do a more compact representation or a 3D CNN with pooling.
        """
        # flatten
        stock_f = self.stock.flatten().astype(np.float32)
        shape_f = self.shape.flatten().astype(np.float32)
        router_f = self.router_pos.astype(np.float32)
        # combine
        obs = np.concatenate([stock_f, shape_f, router_f], axis=0)
        return obs

    def _get_worker_obs(self):
        """
        Worker sees local environment + subgoal. 
        For demonstration, let's flatten as well, with subgoal appended.
        """
        stock_f = self.stock.flatten().astype(np.float32)
        shape_f = self.shape.flatten().astype(np.float32)
        router_f = self.router_pos.astype(np.float32)
        subgoal_f = self.subgoal.astype(np.float32)
        obs = np.concatenate([stock_f, shape_f, router_f, subgoal_f], axis=0)
        return obs

########################################################
# 2) FEUDAL NETWORKS: MANAGER & WORKER ARCHITECTURES
########################################################

class ManagerNet(nn.Module):
    """
    Manager policy (discrete or continuous subgoal).
    For simplicity, let's produce a discrete subgoal coordinate in [0, grid_size).
    Or we produce 3 integers (subgoal_x, subgoal_y, subgoal_z).
    
    We'll do a small MLP that outputs 3 integers by classification 
    or a continuous approach. We'll do discrete for demonstration.
    
    We'll define: 
      subgoal_x in [0..grid_size-1]
      subgoal_y in [0..grid_size-1]
      subgoal_z in [0..grid_size-1]
    => (grid_size^3) possible subgoals is huge, but we'll keep it small (like 8^3=512)
    
    We'll do a single "logits" vector of length = grid_size^3, then sample from that distribution.
    
    In a real system, you might do a param for subgoal or a 3D bounding region, etc.
    """
    def __init__(self, input_dim, grid_size=8, hidden_dim=256):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3  # subgoal as a single categorical
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    
    def forward(self, x):
        """
        x shape: [batch, input_dim]
        return: [batch, grid_size^3] (logits)
        """
        return self.net(x)

class WorkerNet(nn.Module):
    """
    Worker policy. The worker has 6 discrete actions: +x,-x,+y,-y,+z,-z.
    We'll do a small MLP that outputs 6 Q-values or policy logits. 
    We'll do a policy approach for simplicity (like a categorical distribution).
    """
    def __init__(self, input_dim, n_actions=6, hidden_dim=256):
        super().__init__()
        self.n_actions = n_actions
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, n_actions)
        )
    
    def forward(self, x):
        """
        x shape: [batch, input_dim]
        output: [batch, n_actions] (logits for discrete actions)
        """
        return self.net(x)

########################################################
# 3) REPLAY BUFFERS
########################################################

class ManagerReplayBuffer:
    """
    For manager: we store (s, subgoal, reward, s_next, done).
    But manager's action = subgoal in discrete space (0..grid_size^3 -1).
    """
    def __init__(self, capacity=10000):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, s, a, r, s_next, done):
        self.buffer.append((s, a, r, s_next, done))
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s, a, r, s_next, d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(s_next), np.array(d)
    
    def __len__(self):
        return len(self.buffer)


class WorkerReplayBuffer:
    """
    For worker: (s, action, reward, s_next, done).
    actions in [0..5].
    """
    def __init__(self, capacity=10000):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, s, a, r, s_next, done):
        self.buffer.append((s, a, r, s_next, done))
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s, a, r, s_next, d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(s_next), np.array(d)
    
    def __len__(self):
        return len(self.buffer)

########################################################
# 4) TRAINING FUNCTIONS
########################################################

def manager_select_subgoal(manager_net, manager_state, grid_size, epsilon=0.1):
    """
    Epsilon-greedy selection for subgoal.
    manager_net outputs logits for grid_size^3 subgoals.
    """
    if random.random() < epsilon:
        # random subgoal
        subgoal_id = random.randint(0, grid_size**3 - 1)
    else:
        with torch.no_grad():
            inp = torch.FloatTensor(manager_state).unsqueeze(0)  # [1, input_dim]
            logits = manager_net(inp)  # [1, grid_size^3]
            subgoal_id = logits.argmax(dim=1).item()
    # decode subgoal_id -> (x,y,z)
    z = subgoal_id % grid_size
    y = (subgoal_id // grid_size) % grid_size
    x = (subgoal_id // (grid_size*grid_size)) % grid_size
    return subgoal_id, (x,y,z)

def worker_select_action(worker_net, worker_state, n_actions=6, epsilon=0.1):
    """
    Epsilon-greedy for worker's discrete 6 actions.
    """
    if random.random() < epsilon:
        return random.randint(0, n_actions-1)
    else:
        with torch.no_grad():
            inp = torch.FloatTensor(worker_state).unsqueeze(0)
            logits = worker_net(inp)
            action_id = logits.argmax(dim=1).item()
        return action_id

def manager_update(
    manager_net,
    manager_optimizer,
    replay_buffer,
    batch_size,
    gamma=0.9,
    grid_size=8,
    device="cpu"
):
    if len(replay_buffer) < batch_size:
        return
    s, a, r, s_next, d = replay_buffer.sample(batch_size)

    # convert to tensors
    s_t = torch.FloatTensor(s).to(device)
    a_t = torch.LongTensor(a).to(device)
    r_t = torch.FloatTensor(r).to(device)
    s_next_t = torch.FloatTensor(s_next).to(device)
    d_t = torch.BoolTensor(d).to(device)

    # forward
    logits = manager_net(s_t)  # [batch, grid_size^3]
    # gather predicted Q ~ cross-entropy approach or we do a Q approach?
    # Typically for a policy approach, we do policy gradient, but let's do a DQN style for manager:
    # We'll treat output as Q(s, subgoal). Then a is index in [0..grid_size^3).
    q_s_a = logits.gather(1, a_t.unsqueeze(1)).squeeze(1)

    # next Q
    with torch.no_grad():
        logits_next = manager_net(s_next_t)
        max_q_next, _ = torch.max(logits_next, dim=1)
        max_q_next[d_t] = 0.0

    target = r_t + gamma * max_q_next

    # MSE loss
    loss = nn.MSELoss()(q_s_a, target)

    manager_optimizer.zero_grad()
    loss.backward()
    manager_optimizer.step()

def worker_update(
    worker_net,
    worker_optimizer,
    replay_buffer,
    batch_size,
    gamma=0.9,
    n_actions=6,
    device="cpu"
):
    if len(replay_buffer) < batch_size:
        return
    s, a, r, s_next, d = replay_buffer.sample(batch_size)

    s_t = torch.FloatTensor(s).to(device)
    a_t = torch.LongTensor(a).to(device)
    r_t = torch.FloatTensor(r).to(device)
    s_next_t = torch.FloatTensor(s_next).to(device)
    d_t = torch.BoolTensor(d).to(device)

    # Q-style:
    logits = worker_net(s_t)  # [batch, n_actions]
    q_s_a = logits.gather(1, a_t.unsqueeze(1)).squeeze(1)

    with torch.no_grad():
        logits_next = worker_net(s_next_t)
        max_q_next, _ = torch.max(logits_next, dim=1)
        max_q_next[d_t] = 0.0

    target = r_t + gamma * max_q_next

    loss = nn.MSELoss()(q_s_a, target)

    worker_optimizer.zero_grad()
    loss.backward()
    worker_optimizer.step()

########################################################
# 5) MAIN TRAINING LOOP
########################################################

def train_feudal_milling(
    num_episodes=1000,
    grid_size=8,
    manager_update_freq=10,  # T steps
    manager_gamma=0.9,
    worker_gamma=0.9,
    lr_manager=1e-3,
    lr_worker=1e-3,
    batch_size=32,
    manager_epsilon_start=1.0,
    worker_epsilon_start=1.0,
    manager_epsilon_end=0.1,
    worker_epsilon_end=0.1,
    manager_epsilon_decay=0.995,
    worker_epsilon_decay=0.995,
    device="cpu"
):
    """
    A full training loop for Feudal RL on the 3D milling environment.
    The manager sets subgoals every manager_update_freq steps.
    The worker attempts to follow them.
    """
    env = Milling3DEnvFeudal(grid_size=grid_size)
    # manager / worker input dims
    manager_input_dim = env._get_manager_obs().shape[0]
    worker_input_dim = env._get_worker_obs().shape[0]
    manager_net = ManagerNet(manager_input_dim, grid_size=grid_size).to(device)
    worker_net = WorkerNet(worker_input_dim, n_actions=6).to(device)

    manager_optimizer = optim.Adam(manager_net.parameters(), lr=lr_manager)
    worker_optimizer = optim.Adam(worker_net.parameters(), lr=lr_worker)

    manager_replay = ManagerReplayBuffer(capacity=50000)
    worker_replay = WorkerReplayBuffer(capacity=50000)

    manager_epsilon = manager_epsilon_start
    worker_epsilon = worker_epsilon_start

    # TensorBoard
    log_dir = os.path.join("runs", f"feudal_milling_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}")
    writer = SummaryWriter(log_dir=log_dir)

    global_step = 0

    for ep in range(num_episodes):
        m_obs, w_obs = env.reset()

        done = False
        episode_reward_manager = 0.0
        episode_reward_worker = 0.0
        manager_steps = 0

        # choose initial subgoal
        # we can do 1 subgoal right away
        m_a_id, subgoal_xyz = manager_select_subgoal(manager_net, m_obs, grid_size, epsilon=manager_epsilon)
        env.set_subgoal(np.array(subgoal_xyz))

        while not done:
            # manager only updates subgoal every manager_update_freq steps
            # but we might store transitions each time. We'll do a 
            # "macro-step" approach: after T worker actions, manager sees new state & gets reward.

            manager_s = m_obs
            manager_done = env.manager_done()  # typically just env done
            # We'll store manager transitions after T steps or if done

            # record old manager reward for later
            old_manager_reward = env.manager_reward()

            # run T worker steps (or until done)
            for _ in range(manager_update_freq):
                if env.done:
                    break
                w_s = w_obs
                action_worker = worker_select_action(worker_net, w_s, n_actions=6, epsilon=worker_epsilon)
                w_s_next, worker_r, w_done = env.worker_step(action_worker)
                w_obs = w_s_next
                episode_reward_worker += worker_r

                # store in worker replay
                worker_replay.push(w_s, action_worker, worker_r, w_s_next, w_done)

                # update worker
                worker_update(
                    worker_net,
                    worker_optimizer,
                    worker_replay,
                    batch_size=batch_size,
                    gamma=worker_gamma,
                    n_actions=6,
                    device=device
                )

                if w_done:
                    break

            # after T steps or done, manager sees new state
            m_obs_next = env._get_manager_obs()
            manager_r = env.manager_reward()  # new manager reward
            manager_done = env.manager_done()

            # The manager's "step" reward is the difference in the global measure or some shaping:
            # We'll do a simple approach: manager_r - old_manager_reward
            delta_manager_r = manager_r - old_manager_reward
            episode_reward_manager += delta_manager_r

            # store manager transition
            manager_replay.push(manager_s, m_a_id, delta_manager_r, m_obs_next, manager_done)

            # manager update
            manager_update(
                manager_net,
                manager_optimizer,
                manager_replay,
                batch_size=batch_size,
                gamma=manager_gamma,
                grid_size=grid_size,
                device=device
            )

            # next manager state
            m_obs = m_obs_next
            manager_steps += 1

            done = manager_done
            if not done:
                # pick a new subgoal
                m_a_id, subgoal_xyz = manager_select_subgoal(manager_net, m_obs, grid_size, epsilon=manager_epsilon)
                env.set_subgoal(np.array(subgoal_xyz))

        # end of episode
        # Decay epsilon
        manager_epsilon = max(manager_epsilon_end, manager_epsilon * manager_epsilon_decay)
        worker_epsilon = max(worker_epsilon_end, worker_epsilon * worker_epsilon_decay)

        episode_return = episode_reward_worker + episode_reward_manager

        writer.add_scalar("Episode/ManagerReturn", episode_reward_manager, ep)
        writer.add_scalar("Episode/WorkerReturn", episode_reward_worker, ep)
        writer.add_scalar("Episode/TotalReturn", episode_return, ep)
        writer.add_scalar("Epsilon/Manager", manager_epsilon, ep)
        writer.add_scalar("Epsilon/Worker", worker_epsilon, ep)
        writer.add_scalar("Manager/EpisodeSteps", manager_steps, ep)

        print(f"Episode {ep+1}/{num_episodes}, ManagerR={episode_reward_manager:.2f}, "
              f"WorkerR={episode_reward_worker:.2f}, EpsM={manager_epsilon:.2f}, EpsW={worker_epsilon:.2f}")

    writer.close()
    print("Training complete.")
    return manager_net, worker_net

########################################################
# 6) DEMO / GIF GENERATION (OPTIONAL)
########################################################

def create_3d_demo_gif(manager_net, worker_net, grid_size=8, max_steps=300, output_gif="feudal_milling_demo.gif"):
    """
    Runs a single episode with the trained manager & worker, 
    capturing frames of environment states. We'll do a 
    simple scatter or skip advanced 3D rendering for brevity.
    """
    env = Milling3DEnvFeudal(grid_size=grid_size, max_steps=max_steps)
    m_obs, w_obs = env.reset()
    frames = []

    # we won't do sub-step rendering in 3D for every step here, 
    # but let's do a naive 2D slice rendering or just record some text. 
    # For demonstration, let's create a text-based "frame" – not too fancy. 
    # If you want real 3D visuals, you'd replicate the environment's 3D scatter method 
    # and store as images. We'll do a textual approach to keep it self-contained.

    manager_epsilon = 0.0
    worker_epsilon = 0.0

    def snapshot_text(env):
        # create a text image for demonstration
        # but let's do a single slice z=0 to see environment
        # (In real usage, you'd do proper 3D scatter and convert to RGBA.)
        slice_2d = env.stock[:,:,0]
        shape_2d = env.shape[:,:,0]
        router = (env.router_pos[0], env.router_pos[1])
        lines = []
        for y in range(env.grid_size):
            row = []
            for x in range(env.grid_size):
                if (x,y) == (router[0], router[1]) and 0==env.router_pos[2]:
                    row.append("R")
                elif slice_2d[x,y] == 1 and shape_2d[x,y] == 1:
                    row.append("S") # shape uncut
                elif slice_2d[x,y] == 1 and shape_2d[x,y] == 0:
                    row.append("O") # outside stock
                else:
                    row.append(".") # empty
            lines.append("".join(row))
        text_repr = "\n".join(lines)
        return text_repr

    done = False
    manager_update_freq = 10

    # initial subgoal
    m_a_id, subgoal_xyz = manager_select_subgoal(manager_net, m_obs, grid_size, epsilon=manager_epsilon)
    env.set_subgoal(np.array(subgoal_xyz))

    step_count = 0
    while not done and step_count < max_steps:
        manager_s = m_obs
        old_mgr_r = env.manager_reward()

        # run T worker steps
        for _ in range(manager_update_freq):
            if env.done:
                break
            # record frame as text
            frame_txt = snapshot_text(env)
            frames.append(frame_txt)

            w_s = w_obs
            action_worker = worker_select_action(worker_net, w_s, epsilon=worker_epsilon)
            w_s_next, r_worker, done_worker = env.worker_step(action_worker)
            w_obs = w_s_next
            step_count += 1

            if done_worker:
                break

        m_obs_next = env._get_manager_obs()
        new_mgr_r = env.manager_reward()
        manager_done = env.manager_done()
        done = manager_done

        # pick new subgoal
        if not done:
            m_a_id, subgoal_xyz = manager_select_subgoal(manager_net, m_obs_next, grid_size, epsilon=manager_epsilon)
            env.set_subgoal(np.array(subgoal_xyz))

        m_obs = m_obs_next

    # final frame
    frames.append(snapshot_text(env))

    # Convert text frames to images for a naive "GIF"
    # We'll just do a white background with black text
    rendered_frames = []
    import PIL
    from PIL import Image, ImageDraw, ImageFont

    font = ImageFont.load_default()
    def text_to_image(txt):
        lines = txt.split("\n")
        w = max(len(line) for line in lines)
        h = len(lines)
        # each char let's say 10x15
        char_w, char_h = 10, 15
        img_w = char_w * w
        img_h = char_h * h
        img = Image.new("RGB", (img_w, img_h), color="white")
        d = ImageDraw.Draw(img)
        for i, line in enumerate(lines):
            d.text((0, i*char_h), line, font=font, fill=(0,0,0))
        return img

    for f_txt in frames:
        img = text_to_image(f_txt)
        rendered_frames.append(img)

    rendered_frames[0].save(
        output_gif,
        save_all=True,
        append_images=rendered_frames[1:],
        duration=500,
        loop=0
    )
    print(f"Demo GIF saved: {output_gif}")


########################################################
# 7) RUN EXAMPLE
########################################################

if __name__ == "__main__":
    manager_net, worker_net = train_feudal_milling(
        num_episodes=1000,   # increase for real training
        grid_size=8
    )
    create_3d_demo_gif(manager_net, worker_net, grid_size=8, max_steps=300, output_gif="feudal_milling_demo.gif")
    print("Done.")
# Out:
# Episode 1/1000, ManagerR=-4.69, WorkerR=-8.68, EpsM=0.99, EpsW=0.99
# Episode 2/1000, ManagerR=-4.54, WorkerR=-20.95, EpsM=0.99, EpsW=0.99
# Episode 3/1000, ManagerR=-3.66, WorkerR=-28.11, EpsM=0.99, EpsW=0.99
# Episode 4/1000, ManagerR=-3.89, WorkerR=-77.10, EpsM=0.98, EpsW=0.98
# Episode 5/1000, ManagerR=-4.61, WorkerR=-19.36, EpsM=0.98, EpsW=0.98
# Episode 6/1000, ManagerR=-3.97, WorkerR=-54.69, EpsM=0.97, EpsW=0.97
# Episode 7/1000, ManagerR=-4.61, WorkerR=-13.31, EpsM=0.97, EpsW=0.97
# Episode 8/1000, ManagerR=-2.93, WorkerR=-13.76, EpsM=0.96, EpsW=0.96
# Episode 9/1000, ManagerR=-4.51, WorkerR=-20.97, EpsM=0.96, EpsW=0.96
# Episode 10/1000, ManagerR=1.46, WorkerR=-54.31, EpsM=0.95, EpsW=0.95
# Episode 11/1000, ManagerR=-4.21, WorkerR=-31.37, EpsM=0.95, EpsW=0.95
# Episode 12/1000, ManagerR=-4.69, WorkerR=-7.39, EpsM=0.94, EpsW=0.94
# Episode 13/1000, ManagerR=-3.56, WorkerR=-40.10, EpsM=0.94, EpsW=0.94
# Episode 14/1000, ManagerR=-4.56, WorkerR=-12.18, EpsM=0.93, EpsW=0.93
# Episode 15/1000, ManagerR=-3.35, WorkerR=-27.37, EpsM=0.93, EpsW=0.93
# Episode 16/1000, ManagerR=-3.92, WorkerR=-29.41, EpsM=0.92, EpsW=0.92
# Episode 17/1000, ManagerR=-4.72, WorkerR=-14.90, EpsM=0.92, EpsW=0.92
# Episode 18/1000, ManagerR=-4.67, WorkerR=-13.73, EpsM=0.91, EpsW=0.91
# Episode 19/1000, ManagerR=-4.51, WorkerR=-14.58, EpsM=0.91, EpsW=0.91
# Episode 20/1000, ManagerR=1.88, WorkerR=-44.06, EpsM=0.90, EpsW=0.90
# Episode 21/1000, ManagerR=-3.71, WorkerR=-43.54, EpsM=0.90, EpsW=0.90
# Episode 22/1000, ManagerR=-3.71, WorkerR=-47.84, EpsM=0.90, EpsW=0.90
# Episode 23/1000, ManagerR=-4.04, WorkerR=-10.38, EpsM=0.89, EpsW=0.89
# Episode 24/1000, ManagerR=-4.60, WorkerR=-15.36, EpsM=0.89, EpsW=0.89
# Episode 25/1000, ManagerR=-4.82, WorkerR=-9.79, EpsM=0.88, EpsW=0.88
# Episode 26/1000, ManagerR=-4.42, WorkerR=-15.45, EpsM=0.88, EpsW=0.88
# Episode 27/1000, ManagerR=-3.77, WorkerR=-20.11, EpsM=0.87, EpsW=0.87
# Episode 28/1000, ManagerR=-4.43, WorkerR=-15.98, EpsM=0.87, EpsW=0.87
# Episode 29/1000, ManagerR=-3.12, WorkerR=-20.78, EpsM=0.86, EpsW=0.86
# Episode 30/1000, ManagerR=-3.69, WorkerR=-23.73, EpsM=0.86, EpsW=0.86
# Episode 31/1000, ManagerR=-4.50, WorkerR=-10.92, EpsM=0.86, EpsW=0.86
# Episode 32/1000, ManagerR=-4.13, WorkerR=-25.19, EpsM=0.85, EpsW=0.85
# Episode 33/1000, ManagerR=-3.82, WorkerR=-20.24, EpsM=0.85, EpsW=0.85
# Episode 34/1000, ManagerR=-3.43, WorkerR=-21.28, EpsM=0.84, EpsW=0.84
# Episode 35/1000, ManagerR=-4.64, WorkerR=-15.29, EpsM=0.84, EpsW=0.84
# Episode 36/1000, ManagerR=-3.43, WorkerR=-21.83, EpsM=0.83, EpsW=0.83
# Episode 37/1000, ManagerR=2.00, WorkerR=-36.38, EpsM=0.83, EpsW=0.83
# Episode 38/1000, ManagerR=-4.41, WorkerR=-21.80, EpsM=0.83, EpsW=0.83
# Episode 39/1000, ManagerR=-3.83, WorkerR=-38.48, EpsM=0.82, EpsW=0.82
# Episode 40/1000, ManagerR=-4.51, WorkerR=-10.15, EpsM=0.82, EpsW=0.82
# Episode 41/1000, ManagerR=-4.36, WorkerR=-15.30, EpsM=0.81, EpsW=0.81
# Episode 42/1000, ManagerR=-4.20, WorkerR=-36.28, EpsM=0.81, EpsW=0.81
# Episode 43/1000, ManagerR=-3.98, WorkerR=-11.83, EpsM=0.81, EpsW=0.81
# Episode 44/1000, ManagerR=-3.37, WorkerR=-23.44, EpsM=0.80, EpsW=0.80
# Episode 45/1000, ManagerR=-4.37, WorkerR=-14.44, EpsM=0.80, EpsW=0.80
# Episode 46/1000, ManagerR=-3.87, WorkerR=-53.66, EpsM=0.79, EpsW=0.79
# Episode 47/1000, ManagerR=-4.15, WorkerR=-29.22, EpsM=0.79, EpsW=0.79
# Episode 48/1000, ManagerR=-4.54, WorkerR=-16.89, EpsM=0.79, EpsW=0.79
# Episode 49/1000, ManagerR=-4.64, WorkerR=-15.38, EpsM=0.78, EpsW=0.78
# Episode 50/1000, ManagerR=-4.60, WorkerR=-4.60, EpsM=0.78, EpsW=0.78
# Episode 51/1000, ManagerR=-4.19, WorkerR=-23.49, EpsM=0.77, EpsW=0.77
# Episode 52/1000, ManagerR=-4.49, WorkerR=-26.54, EpsM=0.77, EpsW=0.77
# Episode 53/1000, ManagerR=-3.58, WorkerR=-0.72, EpsM=0.77, EpsW=0.77
# Episode 54/1000, ManagerR=-4.13, WorkerR=-25.30, EpsM=0.76, EpsW=0.76
# Episode 55/1000, ManagerR=-4.46, WorkerR=-11.77, EpsM=0.76, EpsW=0.76
# Episode 56/1000, ManagerR=-3.98, WorkerR=-19.07, EpsM=0.76, EpsW=0.76
# Episode 57/1000, ManagerR=-4.74, WorkerR=-15.88, EpsM=0.75, EpsW=0.75
# Episode 58/1000, ManagerR=-4.16, WorkerR=-31.73, EpsM=0.75, EpsW=0.75
# Episode 59/1000, ManagerR=-2.84, WorkerR=-50.92, EpsM=0.74, EpsW=0.74
# Episode 60/1000, ManagerR=-3.89, WorkerR=-22.27, EpsM=0.74, EpsW=0.74
# Episode 61/1000, ManagerR=-4.44, WorkerR=-7.66, EpsM=0.74, EpsW=0.74
# Episode 62/1000, ManagerR=2.21, WorkerR=-20.30, EpsM=0.73, EpsW=0.73
# Episode 63/1000, ManagerR=-4.36, WorkerR=-35.30, EpsM=0.73, EpsW=0.73
# Episode 64/1000, ManagerR=-3.92, WorkerR=-47.47, EpsM=0.73, EpsW=0.73
# Episode 65/1000, ManagerR=-4.56, WorkerR=-5.25, EpsM=0.72, EpsW=0.72
# Episode 66/1000, ManagerR=-4.27, WorkerR=-8.59, EpsM=0.72, EpsW=0.72
# Episode 67/1000, ManagerR=-4.31, WorkerR=-12.23, EpsM=0.71, EpsW=0.71
# Episode 68/1000, ManagerR=-3.98, WorkerR=-27.82, EpsM=0.71, EpsW=0.71
# Episode 69/1000, ManagerR=1.59, WorkerR=-74.87, EpsM=0.71, EpsW=0.71
# Episode 70/1000, ManagerR=-3.54, WorkerR=-36.33, EpsM=0.70, EpsW=0.70
# Episode 71/1000, ManagerR=-4.27, WorkerR=-9.82, EpsM=0.70, EpsW=0.70
# Episode 72/1000, ManagerR=-4.14, WorkerR=-10.22, EpsM=0.70, EpsW=0.70
# Episode 73/1000, ManagerR=-4.73, WorkerR=-14.05, EpsM=0.69, EpsW=0.69
# Episode 74/1000, ManagerR=-4.79, WorkerR=-13.04, EpsM=0.69, EpsW=0.69
# Episode 75/1000, ManagerR=-4.27, WorkerR=-4.50, EpsM=0.69, EpsW=0.69
# Episode 76/1000, ManagerR=-3.66, WorkerR=-24.72, EpsM=0.68, EpsW=0.68
# Episode 77/1000, ManagerR=-4.79, WorkerR=-8.47, EpsM=0.68, EpsW=0.68
# Episode 78/1000, ManagerR=-4.71, WorkerR=-11.58, EpsM=0.68, EpsW=0.68
# Episode 79/1000, ManagerR=1.94, WorkerR=-50.43, EpsM=0.67, EpsW=0.67
# Episode 80/1000, ManagerR=-4.00, WorkerR=-12.18, EpsM=0.67, EpsW=0.67
# Episode 81/1000, ManagerR=1.75, WorkerR=-50.34, EpsM=0.67, EpsW=0.67
# Episode 82/1000, ManagerR=-3.64, WorkerR=-57.32, EpsM=0.66, EpsW=0.66
# Episode 83/1000, ManagerR=-4.79, WorkerR=-7.61, EpsM=0.66, EpsW=0.66
# Episode 84/1000, ManagerR=-4.23, WorkerR=-4.20, EpsM=0.66, EpsW=0.66
# Episode 85/1000, ManagerR=-4.20, WorkerR=-41.26, EpsM=0.65, EpsW=0.65
# Episode 86/1000, ManagerR=-3.89, WorkerR=-22.30, EpsM=0.65, EpsW=0.65
# Episode 87/1000, ManagerR=-3.97, WorkerR=-53.86, EpsM=0.65, EpsW=0.65
# Episode 88/1000, ManagerR=-3.39, WorkerR=-72.59, EpsM=0.64, EpsW=0.64
# Episode 89/1000, ManagerR=-4.58, WorkerR=-5.67, EpsM=0.64, EpsW=0.64
# Episode 90/1000, ManagerR=-3.51, WorkerR=-22.05, EpsM=0.64, EpsW=0.64
# Episode 91/1000, ManagerR=-4.13, WorkerR=-37.21, EpsM=0.63, EpsW=0.63
# Episode 92/1000, ManagerR=-4.37, WorkerR=-15.59, EpsM=0.63, EpsW=0.63
# Episode 93/1000, ManagerR=-4.07, WorkerR=-2.06, EpsM=0.63, EpsW=0.63
# Episode 94/1000, ManagerR=-3.85, WorkerR=-58.25, EpsM=0.62, EpsW=0.62
# Episode 95/1000, ManagerR=-4.65, WorkerR=-6.73, EpsM=0.62, EpsW=0.62
# Episode 96/1000, ManagerR=1.27, WorkerR=-66.07, EpsM=0.62, EpsW=0.62
# Episode 97/1000, ManagerR=-4.16, WorkerR=-20.12, EpsM=0.61, EpsW=0.61
# Episode 98/1000, ManagerR=-3.87, WorkerR=-74.49, EpsM=0.61, EpsW=0.61
# Episode 99/1000, ManagerR=-4.46, WorkerR=-9.37, EpsM=0.61, EpsW=0.61
# Episode 100/1000, ManagerR=-3.98, WorkerR=-15.83, EpsM=0.61, EpsW=0.61
# Episode 101/1000, ManagerR=1.73, WorkerR=-60.01, EpsM=0.60, EpsW=0.60
# Episode 102/1000, ManagerR=1.57, WorkerR=-92.37, EpsM=0.60, EpsW=0.60
# Episode 103/1000, ManagerR=1.42, WorkerR=-75.80, EpsM=0.60, EpsW=0.60
# Episode 104/1000, ManagerR=-4.18, WorkerR=-26.12, EpsM=0.59, EpsW=0.59
# Episode 105/1000, ManagerR=-4.25, WorkerR=-15.01, EpsM=0.59, EpsW=0.59
# Episode 106/1000, ManagerR=-4.59, WorkerR=-6.75, EpsM=0.59, EpsW=0.59
# Episode 107/1000, ManagerR=1.34, WorkerR=-68.69, EpsM=0.58, EpsW=0.58
# Episode 108/1000, ManagerR=-4.74, WorkerR=-10.35, EpsM=0.58, EpsW=0.58
# Episode 109/1000, ManagerR=1.98, WorkerR=-38.15, EpsM=0.58, EpsW=0.58
# Episode 110/1000, ManagerR=-4.79, WorkerR=-11.28, EpsM=0.58, EpsW=0.58
# Episode 111/1000, ManagerR=-4.81, WorkerR=-9.13, EpsM=0.57, EpsW=0.57
# Episode 112/1000, ManagerR=0.86, WorkerR=-123.84, EpsM=0.57, EpsW=0.57
# Episode 113/1000, ManagerR=-4.46, WorkerR=-15.21, EpsM=0.57, EpsW=0.57
# Episode 114/1000, ManagerR=-4.29, WorkerR=-14.41, EpsM=0.56, EpsW=0.56
# Episode 115/1000, ManagerR=-3.97, WorkerR=-79.67, EpsM=0.56, EpsW=0.56
# Episode 116/1000, ManagerR=-3.50, WorkerR=-43.06, EpsM=0.56, EpsW=0.56
# Episode 117/1000, ManagerR=1.34, WorkerR=-79.61, EpsM=0.56, EpsW=0.56
# Episode 118/1000, ManagerR=-4.08, WorkerR=-25.06, EpsM=0.55, EpsW=0.55
# Episode 119/1000, ManagerR=1.34, WorkerR=-98.07, EpsM=0.55, EpsW=0.55
# Episode 120/1000, ManagerR=-4.08, WorkerR=-25.18, EpsM=0.55, EpsW=0.55
# Episode 121/1000, ManagerR=0.96, WorkerR=-104.18, EpsM=0.55, EpsW=0.55
# Episode 122/1000, ManagerR=-4.77, WorkerR=-9.77, EpsM=0.54, EpsW=0.54
# Episode 123/1000, ManagerR=-4.56, WorkerR=-6.36, EpsM=0.54, EpsW=0.54
# Episode 124/1000, ManagerR=-4.60, WorkerR=-3.90, EpsM=0.54, EpsW=0.54
# Episode 125/1000, ManagerR=-4.13, WorkerR=-19.15, EpsM=0.53, EpsW=0.53
# Episode 126/1000, ManagerR=-3.98, WorkerR=-31.27, EpsM=0.53, EpsW=0.53
# Episode 127/1000, ManagerR=-4.13, WorkerR=-44.58, EpsM=0.53, EpsW=0.53
# Episode 128/1000, ManagerR=-3.98, WorkerR=-79.61, EpsM=0.53, EpsW=0.53
# Episode 129/1000, ManagerR=1.11, WorkerR=-92.73, EpsM=0.52, EpsW=0.52
# Episode 130/1000, ManagerR=-4.35, WorkerR=-60.90, EpsM=0.52, EpsW=0.52
# Episode 131/1000, ManagerR=-4.54, WorkerR=-32.97, EpsM=0.52, EpsW=0.52
# Episode 132/1000, ManagerR=-4.56, WorkerR=-37.62, EpsM=0.52, EpsW=0.52
# Episode 133/1000, ManagerR=-3.54, WorkerR=-48.51, EpsM=0.51, EpsW=0.51
# Episode 134/1000, ManagerR=-3.75, WorkerR=-18.13, EpsM=0.51, EpsW=0.51
# Episode 135/1000, ManagerR=-4.46, WorkerR=-25.82, EpsM=0.51, EpsW=0.51
# Episode 136/1000, ManagerR=-4.08, WorkerR=-33.04, EpsM=0.51, EpsW=0.51
# Episode 137/1000, ManagerR=1.86, WorkerR=-48.53, EpsM=0.50, EpsW=0.50
# Episode 138/1000, ManagerR=-4.77, WorkerR=-14.27, EpsM=0.50, EpsW=0.50
# Episode 139/1000, ManagerR=1.73, WorkerR=-50.66, EpsM=0.50, EpsW=0.50
# Episode 140/1000, ManagerR=-4.61, WorkerR=-4.77, EpsM=0.50, EpsW=0.50
# Episode 141/1000, ManagerR=-4.12, WorkerR=-64.96, EpsM=0.49, EpsW=0.49
# Episode 142/1000, ManagerR=-4.06, WorkerR=-18.76, EpsM=0.49, EpsW=0.49
# Episode 143/1000, ManagerR=-3.56, WorkerR=-63.21, EpsM=0.49, EpsW=0.49
# Episode 144/1000, ManagerR=-4.82, WorkerR=-8.73, EpsM=0.49, EpsW=0.49
# Episode 145/1000, ManagerR=1.52, WorkerR=-91.99, EpsM=0.48, EpsW=0.48
# Episode 146/1000, ManagerR=1.75, WorkerR=-36.05, EpsM=0.48, EpsW=0.48
# Episode 147/1000, ManagerR=-3.97, WorkerR=-20.86, EpsM=0.48, EpsW=0.48
# Episode 148/1000, ManagerR=-4.64, WorkerR=-6.25, EpsM=0.48, EpsW=0.48
# Episode 149/1000, ManagerR=-4.54, WorkerR=-10.93, EpsM=0.47, EpsW=0.47
# Episode 150/1000, ManagerR=-4.79, WorkerR=-5.90, EpsM=0.47, EpsW=0.47
# Episode 151/1000, ManagerR=-4.00, WorkerR=-45.39, EpsM=0.47, EpsW=0.47
# Episode 152/1000, ManagerR=-4.67, WorkerR=-6.71, EpsM=0.47, EpsW=0.47
# Episode 153/1000, ManagerR=-4.74, WorkerR=-12.51, EpsM=0.46, EpsW=0.46
# Episode 154/1000, ManagerR=1.69, WorkerR=-69.18, EpsM=0.46, EpsW=0.46
# Episode 155/1000, ManagerR=-4.02, WorkerR=-50.25, EpsM=0.46, EpsW=0.46
# Episode 156/1000, ManagerR=-3.73, WorkerR=-59.69, EpsM=0.46, EpsW=0.46
# Episode 157/1000, ManagerR=1.36, WorkerR=-97.45, EpsM=0.46, EpsW=0.46
# Episode 158/1000, ManagerR=-4.74, WorkerR=-12.18, EpsM=0.45, EpsW=0.45
# Episode 159/1000, ManagerR=1.26, WorkerR=-63.54, EpsM=0.45, EpsW=0.45
# Episode 160/1000, ManagerR=1.98, WorkerR=-51.21, EpsM=0.45, EpsW=0.45
# Episode 161/1000, ManagerR=-4.54, WorkerR=-2.66, EpsM=0.45, EpsW=0.45
# Episode 162/1000, ManagerR=1.36, WorkerR=-94.29, EpsM=0.44, EpsW=0.44
# Episode 163/1000, ManagerR=1.32, WorkerR=-56.89, EpsM=0.44, EpsW=0.44
# Episode 164/1000, ManagerR=-4.36, WorkerR=-26.66, EpsM=0.44, EpsW=0.44
# Episode 165/1000, ManagerR=1.38, WorkerR=-59.28, EpsM=0.44, EpsW=0.44
# Episode 166/1000, ManagerR=1.57, WorkerR=-70.90, EpsM=0.44, EpsW=0.44
# Episode 167/1000, ManagerR=1.27, WorkerR=-57.27, EpsM=0.43, EpsW=0.43
# Episode 168/1000, ManagerR=-4.12, WorkerR=-65.30, EpsM=0.43, EpsW=0.43
# Episode 169/1000, ManagerR=-3.97, WorkerR=-74.87, EpsM=0.43, EpsW=0.43
# Episode 170/1000, ManagerR=1.40, WorkerR=-82.25, EpsM=0.43, EpsW=0.43
# Episode 171/1000, ManagerR=-4.74, WorkerR=-10.15, EpsM=0.42, EpsW=0.42
# Episode 172/1000, ManagerR=1.44, WorkerR=-61.45, EpsM=0.42, EpsW=0.42
# Episode 173/1000, ManagerR=1.67, WorkerR=-51.65, EpsM=0.42, EpsW=0.42
# Episode 174/1000, ManagerR=-3.64, WorkerR=-99.20, EpsM=0.42, EpsW=0.42
# Episode 175/1000, ManagerR=-4.79, WorkerR=-14.27, EpsM=0.42, EpsW=0.42
# Episode 176/1000, ManagerR=1.50, WorkerR=-80.10, EpsM=0.41, EpsW=0.41
# Episode 177/1000, ManagerR=-4.61, WorkerR=-23.71, EpsM=0.41, EpsW=0.41
# Episode 178/1000, ManagerR=-3.92, WorkerR=-76.74, EpsM=0.41, EpsW=0.41
# Episode 179/1000, ManagerR=1.00, WorkerR=-78.31, EpsM=0.41, EpsW=0.41
# Episode 180/1000, ManagerR=-3.33, WorkerR=-59.14, EpsM=0.41, EpsW=0.41
# Episode 181/1000, ManagerR=1.13, WorkerR=-76.18, EpsM=0.40, EpsW=0.40
# Episode 182/1000, ManagerR=1.13, WorkerR=-77.12, EpsM=0.40, EpsW=0.40
# Episode 183/1000, ManagerR=-3.64, WorkerR=-69.23, EpsM=0.40, EpsW=0.40
# Episode 184/1000, ManagerR=1.17, WorkerR=-67.46, EpsM=0.40, EpsW=0.40
# Episode 185/1000, ManagerR=-4.79, WorkerR=-5.26, EpsM=0.40, EpsW=0.40
# Episode 186/1000, ManagerR=1.17, WorkerR=-67.76, EpsM=0.39, EpsW=0.39
# Episode 187/1000, ManagerR=-4.50, WorkerR=-74.68, EpsM=0.39, EpsW=0.39
# Episode 188/1000, ManagerR=1.13, WorkerR=-109.82, EpsM=0.39, EpsW=0.39
# Episode 189/1000, ManagerR=-4.31, WorkerR=-33.41, EpsM=0.39, EpsW=0.39
# Episode 190/1000, ManagerR=0.96, WorkerR=-91.84, EpsM=0.39, EpsW=0.39
# Episode 191/1000, ManagerR=1.61, WorkerR=-49.63, EpsM=0.38, EpsW=0.38
# Episode 192/1000, ManagerR=0.56, WorkerR=-107.82, EpsM=0.38, EpsW=0.38
# Episode 193/1000, ManagerR=1.49, WorkerR=-91.95, EpsM=0.38, EpsW=0.38
# Episode 194/1000, ManagerR=-4.67, WorkerR=-30.72, EpsM=0.38, EpsW=0.38
# Episode 195/1000, ManagerR=-4.20, WorkerR=-103.51, EpsM=0.38, EpsW=0.38
# Episode 196/1000, ManagerR=-4.36, WorkerR=-20.46, EpsM=0.37, EpsW=0.37
# Episode 197/1000, ManagerR=1.44, WorkerR=-55.77, EpsM=0.37, EpsW=0.37
# Episode 198/1000, ManagerR=-4.79, WorkerR=-8.04, EpsM=0.37, EpsW=0.37
# Episode 199/1000, ManagerR=-3.64, WorkerR=-66.02, EpsM=0.37, EpsW=0.37
# Episode 200/1000, ManagerR=-3.97, WorkerR=-98.11, EpsM=0.37, EpsW=0.37
# Episode 201/1000, ManagerR=-4.54, WorkerR=-20.98, EpsM=0.37, EpsW=0.37
# Episode 202/1000, ManagerR=-3.87, WorkerR=-80.34, EpsM=0.36, EpsW=0.36
# Episode 203/1000, ManagerR=-4.02, WorkerR=-79.26, EpsM=0.36, EpsW=0.36
# Episode 204/1000, ManagerR=-4.15, WorkerR=-42.68, EpsM=0.36, EpsW=0.36
# Episode 205/1000, ManagerR=-4.12, WorkerR=-60.08, EpsM=0.36, EpsW=0.36
# Episode 206/1000, ManagerR=-4.41, WorkerR=-49.67, EpsM=0.36, EpsW=0.36
# Episode 207/1000, ManagerR=-3.96, WorkerR=-54.87, EpsM=0.35, EpsW=0.35
# Episode 208/1000, ManagerR=-3.92, WorkerR=-51.97, EpsM=0.35, EpsW=0.35
# Episode 209/1000, ManagerR=0.96, WorkerR=-95.94, EpsM=0.35, EpsW=0.35
# Episode 210/1000, ManagerR=-4.79, WorkerR=-10.71, EpsM=0.35, EpsW=0.35
# Episode 211/1000, ManagerR=-4.29, WorkerR=-30.47, EpsM=0.35, EpsW=0.35
# Episode 212/1000, ManagerR=1.00, WorkerR=-92.43, EpsM=0.35, EpsW=0.35
# Episode 213/1000, ManagerR=-4.54, WorkerR=-19.60, EpsM=0.34, EpsW=0.34
# Episode 214/1000, ManagerR=1.25, WorkerR=-74.78, EpsM=0.34, EpsW=0.34
# Episode 215/1000, ManagerR=-4.36, WorkerR=-8.85, EpsM=0.34, EpsW=0.34
# Episode 216/1000, ManagerR=1.29, WorkerR=-60.17, EpsM=0.34, EpsW=0.34
# Episode 217/1000, ManagerR=0.94, WorkerR=-100.17, EpsM=0.34, EpsW=0.34
# Episode 218/1000, ManagerR=1.16, WorkerR=-124.62, EpsM=0.34, EpsW=0.34
# Episode 219/1000, ManagerR=-4.85, WorkerR=-6.78, EpsM=0.33, EpsW=0.33
# Episode 220/1000, ManagerR=-3.91, WorkerR=-77.43, EpsM=0.33, EpsW=0.33
# Episode 221/1000, ManagerR=0.92, WorkerR=-69.25, EpsM=0.33, EpsW=0.33
# Episode 222/1000, ManagerR=-4.36, WorkerR=-78.79, EpsM=0.33, EpsW=0.33
# Episode 223/1000, ManagerR=1.34, WorkerR=-54.87, EpsM=0.33, EpsW=0.33
# Episode 224/1000, ManagerR=-4.67, WorkerR=-18.59, EpsM=0.33, EpsW=0.33
# Episode 225/1000, ManagerR=1.19, WorkerR=-78.10, EpsM=0.32, EpsW=0.32
# Episode 226/1000, ManagerR=1.19, WorkerR=-43.48, EpsM=0.32, EpsW=0.32
# Episode 227/1000, ManagerR=1.65, WorkerR=-36.89, EpsM=0.32, EpsW=0.32
# Episode 228/1000, ManagerR=-4.19, WorkerR=-61.72, EpsM=0.32, EpsW=0.32
# Episode 229/1000, ManagerR=1.15, WorkerR=-110.51, EpsM=0.32, EpsW=0.32
# Episode 230/1000, ManagerR=1.13, WorkerR=-59.74, EpsM=0.32, EpsW=0.32
# Episode 231/1000, ManagerR=0.98, WorkerR=-116.37, EpsM=0.31, EpsW=0.31
# Episode 232/1000, ManagerR=-4.43, WorkerR=-22.47, EpsM=0.31, EpsW=0.31
# Episode 233/1000, ManagerR=-4.25, WorkerR=-61.50, EpsM=0.31, EpsW=0.31
# Episode 234/1000, ManagerR=0.94, WorkerR=-104.92, EpsM=0.31, EpsW=0.31
# Episode 235/1000, ManagerR=1.59, WorkerR=-62.61, EpsM=0.31, EpsW=0.31
# Episode 236/1000, ManagerR=0.84, WorkerR=-111.09, EpsM=0.31, EpsW=0.31
# Episode 237/1000, ManagerR=0.84, WorkerR=-104.41, EpsM=0.30, EpsW=0.30
# Episode 238/1000, ManagerR=-3.74, WorkerR=-75.25, EpsM=0.30, EpsW=0.30
# Episode 239/1000, ManagerR=-4.54, WorkerR=-12.06, EpsM=0.30, EpsW=0.30
# Episode 240/1000, ManagerR=-3.79, WorkerR=-48.94, EpsM=0.30, EpsW=0.30
# Episode 241/1000, ManagerR=-4.37, WorkerR=-44.14, EpsM=0.30, EpsW=0.30
# Episode 242/1000, ManagerR=-3.89, WorkerR=-37.54, EpsM=0.30, EpsW=0.30
# Episode 243/1000, ManagerR=0.82, WorkerR=-95.17, EpsM=0.30, EpsW=0.30
# Episode 244/1000, ManagerR=-4.10, WorkerR=-75.95, EpsM=0.29, EpsW=0.29
# Episode 245/1000, ManagerR=-4.05, WorkerR=-31.93, EpsM=0.29, EpsW=0.29
# Episode 246/1000, ManagerR=1.06, WorkerR=-63.67, EpsM=0.29, EpsW=0.29
# Episode 247/1000, ManagerR=-4.56, WorkerR=-22.02, EpsM=0.29, EpsW=0.29
# Episode 248/1000, ManagerR=1.29, WorkerR=-79.07, EpsM=0.29, EpsW=0.29
# Episode 249/1000, ManagerR=1.32, WorkerR=-63.62, EpsM=0.29, EpsW=0.29
# Episode 250/1000, ManagerR=1.15, WorkerR=-74.84, EpsM=0.29, EpsW=0.29
# Episode 251/1000, ManagerR=1.17, WorkerR=-118.96, EpsM=0.28, EpsW=0.28
# Episode 252/1000, ManagerR=1.02, WorkerR=-118.53, EpsM=0.28, EpsW=0.28
# Episode 253/1000, ManagerR=-4.28, WorkerR=-84.39, EpsM=0.28, EpsW=0.28
# Episode 254/1000, ManagerR=-4.14, WorkerR=-107.65, EpsM=0.28, EpsW=0.28
# Episode 255/1000, ManagerR=-4.79, WorkerR=-10.11, EpsM=0.28, EpsW=0.28
# Episode 256/1000, ManagerR=-3.71, WorkerR=-80.50, EpsM=0.28, EpsW=0.28
# Episode 257/1000, ManagerR=-4.36, WorkerR=-69.11, EpsM=0.28, EpsW=0.28
# Episode 258/1000, ManagerR=1.23, WorkerR=-61.95, EpsM=0.27, EpsW=0.27
# Episode 259/1000, ManagerR=1.15, WorkerR=-96.08, EpsM=0.27, EpsW=0.27
# Episode 260/1000, ManagerR=-3.97, WorkerR=-86.86, EpsM=0.27, EpsW=0.27
# Episode 261/1000, ManagerR=1.21, WorkerR=-96.88, EpsM=0.27, EpsW=0.27
# Episode 262/1000, ManagerR=1.13, WorkerR=-81.73, EpsM=0.27, EpsW=0.27
# Episode 263/1000, ManagerR=1.23, WorkerR=-83.12, EpsM=0.27, EpsW=0.27
# Episode 264/1000, ManagerR=1.29, WorkerR=-68.00, EpsM=0.27, EpsW=0.27
# Episode 265/1000, ManagerR=1.46, WorkerR=-59.73, EpsM=0.26, EpsW=0.26
# Episode 266/1000, ManagerR=-4.41, WorkerR=-31.90, EpsM=0.26, EpsW=0.26
# Episode 267/1000, ManagerR=0.71, WorkerR=-119.93, EpsM=0.26, EpsW=0.26
# Episode 268/1000, ManagerR=-4.02, WorkerR=-90.90, EpsM=0.26, EpsW=0.26
# Episode 269/1000, ManagerR=-3.92, WorkerR=-28.56, EpsM=0.26, EpsW=0.26
# Episode 270/1000, ManagerR=1.44, WorkerR=-72.43, EpsM=0.26, EpsW=0.26
# Episode 271/1000, ManagerR=0.58, WorkerR=-92.66, EpsM=0.26, EpsW=0.26
# Episode 272/1000, ManagerR=1.44, WorkerR=-68.14, EpsM=0.26, EpsW=0.26
# Episode 273/1000, ManagerR=-4.38, WorkerR=-70.79, EpsM=0.25, EpsW=0.25
# Episode 274/1000, ManagerR=1.06, WorkerR=-99.25, EpsM=0.25, EpsW=0.25
# Episode 275/1000, ManagerR=1.57, WorkerR=-74.94, EpsM=0.25, EpsW=0.25
# Episode 276/1000, ManagerR=-4.74, WorkerR=-6.72, EpsM=0.25, EpsW=0.25
# Episode 277/1000, ManagerR=-4.48, WorkerR=-4.79, EpsM=0.25, EpsW=0.25
# Episode 278/1000, ManagerR=1.05, WorkerR=-108.14, EpsM=0.25, EpsW=0.25
# Episode 279/1000, ManagerR=-4.56, WorkerR=-12.77, EpsM=0.25, EpsW=0.25
# Episode 280/1000, ManagerR=1.48, WorkerR=-37.14, EpsM=0.25, EpsW=0.25
# Episode 281/1000, ManagerR=0.92, WorkerR=-116.86, EpsM=0.24, EpsW=0.24
# Episode 282/1000, ManagerR=1.29, WorkerR=-86.06, EpsM=0.24, EpsW=0.24
# Episode 283/1000, ManagerR=0.84, WorkerR=-39.90, EpsM=0.24, EpsW=0.24
# Episode 284/1000, ManagerR=-4.73, WorkerR=-11.02, EpsM=0.24, EpsW=0.24
# Episode 285/1000, ManagerR=-4.33, WorkerR=-28.56, EpsM=0.24, EpsW=0.24
# Episode 286/1000, ManagerR=1.16, WorkerR=-106.88, EpsM=0.24, EpsW=0.24
# Episode 287/1000, ManagerR=1.13, WorkerR=-103.02, EpsM=0.24, EpsW=0.24
# Episode 288/1000, ManagerR=1.32, WorkerR=-72.29, EpsM=0.24, EpsW=0.24
# Episode 289/1000, ManagerR=1.52, WorkerR=-78.73, EpsM=0.23, EpsW=0.23
# Episode 290/1000, ManagerR=0.95, WorkerR=-124.68, EpsM=0.23, EpsW=0.23
# Episode 291/1000, ManagerR=-4.77, WorkerR=-8.89, EpsM=0.23, EpsW=0.23
# Episode 292/1000, ManagerR=1.42, WorkerR=-52.67, EpsM=0.23, EpsW=0.23
# Episode 293/1000, ManagerR=1.44, WorkerR=-88.55, EpsM=0.23, EpsW=0.23
# Episode 294/1000, ManagerR=-4.05, WorkerR=-79.37, EpsM=0.23, EpsW=0.23
# Episode 295/1000, ManagerR=-4.46, WorkerR=-38.15, EpsM=0.23, EpsW=0.23
# Episode 296/1000, ManagerR=0.63, WorkerR=-99.44, EpsM=0.23, EpsW=0.23
# Episode 297/1000, ManagerR=-4.49, WorkerR=-14.74, EpsM=0.23, EpsW=0.23
# Episode 298/1000, ManagerR=0.93, WorkerR=-120.14, EpsM=0.22, EpsW=0.22
# Episode 299/1000, ManagerR=-4.59, WorkerR=-17.87, EpsM=0.22, EpsW=0.22
# Episode 300/1000, ManagerR=-4.05, WorkerR=-32.73, EpsM=0.22, EpsW=0.22
# Episode 301/1000, ManagerR=-4.28, WorkerR=-84.84, EpsM=0.22, EpsW=0.22
# Episode 302/1000, ManagerR=1.02, WorkerR=-75.89, EpsM=0.22, EpsW=0.22
# Episode 303/1000, ManagerR=1.41, WorkerR=-109.62, EpsM=0.22, EpsW=0.22
# Episode 304/1000, ManagerR=-3.97, WorkerR=-124.59, EpsM=0.22, EpsW=0.22
# Episode 305/1000, ManagerR=-4.02, WorkerR=-96.11, EpsM=0.22, EpsW=0.22
# Episode 306/1000, ManagerR=-4.79, WorkerR=-9.74, EpsM=0.22, EpsW=0.22
# Episode 307/1000, ManagerR=-4.61, WorkerR=-18.44, EpsM=0.21, EpsW=0.21
# Episode 308/1000, ManagerR=1.67, WorkerR=-67.45, EpsM=0.21, EpsW=0.21
# Episode 309/1000, ManagerR=-4.36, WorkerR=-30.31, EpsM=0.21, EpsW=0.21
# Episode 310/1000, ManagerR=-4.77, WorkerR=-5.91, EpsM=0.21, EpsW=0.21
# Episode 311/1000, ManagerR=1.09, WorkerR=-79.64, EpsM=0.21, EpsW=0.21
# Episode 312/1000, ManagerR=-4.77, WorkerR=-15.33, EpsM=0.21, EpsW=0.21
# Episode 313/1000, ManagerR=1.83, WorkerR=-52.36, EpsM=0.21, EpsW=0.21
# Episode 314/1000, ManagerR=-4.13, WorkerR=-70.05, EpsM=0.21, EpsW=0.21
# Episode 315/1000, ManagerR=0.79, WorkerR=-103.41, EpsM=0.21, EpsW=0.21
# Episode 316/1000, ManagerR=0.88, WorkerR=-111.78, EpsM=0.21, EpsW=0.21
# Episode 317/1000, ManagerR=-4.69, WorkerR=-47.56, EpsM=0.20, EpsW=0.20
# Episode 318/1000, ManagerR=-4.79, WorkerR=-7.62, EpsM=0.20, EpsW=0.20
# Episode 319/1000, ManagerR=0.80, WorkerR=-114.36, EpsM=0.20, EpsW=0.20
# Episode 320/1000, ManagerR=1.06, WorkerR=-100.26, EpsM=0.20, EpsW=0.20
# Episode 321/1000, ManagerR=-4.59, WorkerR=-28.43, EpsM=0.20, EpsW=0.20
# Episode 322/1000, ManagerR=-4.56, WorkerR=-36.53, EpsM=0.20, EpsW=0.20
# Episode 323/1000, ManagerR=1.06, WorkerR=-80.61, EpsM=0.20, EpsW=0.20
# Episode 324/1000, ManagerR=0.81, WorkerR=-124.82, EpsM=0.20, EpsW=0.20
# Episode 325/1000, ManagerR=-4.79, WorkerR=-9.77, EpsM=0.20, EpsW=0.20
# Episode 326/1000, ManagerR=0.84, WorkerR=-107.79, EpsM=0.20, EpsW=0.20
# Episode 327/1000, ManagerR=1.27, WorkerR=-73.18, EpsM=0.19, EpsW=0.19
# Episode 328/1000, ManagerR=-4.61, WorkerR=-8.84, EpsM=0.19, EpsW=0.19
# Episode 329/1000, ManagerR=1.11, WorkerR=-81.08, EpsM=0.19, EpsW=0.19
# Episode 330/1000, ManagerR=-4.56, WorkerR=-18.96, EpsM=0.19, EpsW=0.19
# Episode 331/1000, ManagerR=-4.74, WorkerR=-8.99, EpsM=0.19, EpsW=0.19
# Episode 332/1000, ManagerR=-3.68, WorkerR=-45.78, EpsM=0.19, EpsW=0.19
# Episode 333/1000, ManagerR=-4.13, WorkerR=-64.57, EpsM=0.19, EpsW=0.19
# Episode 334/1000, ManagerR=-4.31, WorkerR=-18.01, EpsM=0.19, EpsW=0.19
# Episode 335/1000, ManagerR=-4.35, WorkerR=-46.74, EpsM=0.19, EpsW=0.19
# Episode 336/1000, ManagerR=1.00, WorkerR=-107.13, EpsM=0.19, EpsW=0.19
# Episode 337/1000, ManagerR=1.70, WorkerR=-77.76, EpsM=0.18, EpsW=0.18
# Episode 338/1000, ManagerR=-4.28, WorkerR=-96.42, EpsM=0.18, EpsW=0.18
# Episode 339/1000, ManagerR=0.77, WorkerR=-99.43, EpsM=0.18, EpsW=0.18
# Episode 340/1000, ManagerR=0.90, WorkerR=-127.00, EpsM=0.18, EpsW=0.18
# Episode 341/1000, ManagerR=1.13, WorkerR=-104.09, EpsM=0.18, EpsW=0.18
# Episode 342/1000, ManagerR=0.57, WorkerR=-72.65, EpsM=0.18, EpsW=0.18
# Episode 343/1000, ManagerR=1.44, WorkerR=-93.73, EpsM=0.18, EpsW=0.18
# Episode 344/1000, ManagerR=0.96, WorkerR=-124.10, EpsM=0.18, EpsW=0.18
# Episode 345/1000, ManagerR=1.34, WorkerR=-99.12, EpsM=0.18, EpsW=0.18
# Episode 346/1000, ManagerR=1.38, WorkerR=-98.86, EpsM=0.18, EpsW=0.18
# Episode 347/1000, ManagerR=1.09, WorkerR=-103.98, EpsM=0.18, EpsW=0.18
# Episode 348/1000, ManagerR=1.09, WorkerR=-99.62, EpsM=0.17, EpsW=0.17
# Episode 349/1000, ManagerR=-4.60, WorkerR=-19.16, EpsM=0.17, EpsW=0.17
# Episode 350/1000, ManagerR=1.47, WorkerR=-87.00, EpsM=0.17, EpsW=0.17
# Episode 351/1000, ManagerR=0.71, WorkerR=-115.82, EpsM=0.17, EpsW=0.17
# Episode 352/1000, ManagerR=1.00, WorkerR=-77.45, EpsM=0.17, EpsW=0.17
# Episode 353/1000, ManagerR=-3.91, WorkerR=-55.64, EpsM=0.17, EpsW=0.17
# Episode 354/1000, ManagerR=-4.31, WorkerR=-30.27, EpsM=0.17, EpsW=0.17
# Episode 355/1000, ManagerR=1.03, WorkerR=-128.89, EpsM=0.17, EpsW=0.17
# Episode 356/1000, ManagerR=-4.05, WorkerR=-82.86, EpsM=0.17, EpsW=0.17
# Episode 357/1000, ManagerR=-4.20, WorkerR=-27.71, EpsM=0.17, EpsW=0.17
# Episode 358/1000, ManagerR=1.15, WorkerR=-89.14, EpsM=0.17, EpsW=0.17
# Episode 359/1000, ManagerR=0.86, WorkerR=-119.59, EpsM=0.17, EpsW=0.17
# Episode 360/1000, ManagerR=-4.59, WorkerR=-27.07, EpsM=0.16, EpsW=0.16
# Episode 361/1000, ManagerR=-3.79, WorkerR=-83.31, EpsM=0.16, EpsW=0.16
# Episode 362/1000, ManagerR=0.98, WorkerR=-100.26, EpsM=0.16, EpsW=0.16
# Episode 363/1000, ManagerR=-4.33, WorkerR=-48.64, EpsM=0.16, EpsW=0.16
# Episode 364/1000, ManagerR=0.82, WorkerR=-96.44, EpsM=0.16, EpsW=0.16
# Episode 365/1000, ManagerR=1.23, WorkerR=-109.74, EpsM=0.16, EpsW=0.16
# Episode 366/1000, ManagerR=-4.72, WorkerR=-16.59, EpsM=0.16, EpsW=0.16
# Episode 367/1000, ManagerR=0.98, WorkerR=-86.46, EpsM=0.16, EpsW=0.16
# Episode 368/1000, ManagerR=1.05, WorkerR=-137.79, EpsM=0.16, EpsW=0.16
# Episode 369/1000, ManagerR=1.18, WorkerR=-120.03, EpsM=0.16, EpsW=0.16
# Episode 370/1000, ManagerR=-4.50, WorkerR=-26.18, EpsM=0.16, EpsW=0.16
# Episode 371/1000, ManagerR=0.96, WorkerR=-78.29, EpsM=0.16, EpsW=0.16
# Episode 372/1000, ManagerR=-3.89, WorkerR=-103.91, EpsM=0.15, EpsW=0.15
# Episode 373/1000, ManagerR=0.46, WorkerR=-158.26, EpsM=0.15, EpsW=0.15
# Episode 374/1000, ManagerR=0.92, WorkerR=-107.25, EpsM=0.15, EpsW=0.15
# Episode 375/1000, ManagerR=0.77, WorkerR=-118.76, EpsM=0.15, EpsW=0.15
# Episode 376/1000, ManagerR=1.29, WorkerR=-126.23, EpsM=0.15, EpsW=0.15
# Episode 377/1000, ManagerR=1.00, WorkerR=-46.71, EpsM=0.15, EpsW=0.15
# Episode 378/1000, ManagerR=-4.67, WorkerR=-69.19, EpsM=0.15, EpsW=0.15
# Episode 379/1000, ManagerR=-3.97, WorkerR=-77.92, EpsM=0.15, EpsW=0.15
# Episode 380/1000, ManagerR=0.44, WorkerR=-119.36, EpsM=0.15, EpsW=0.15
# Episode 381/1000, ManagerR=-4.82, WorkerR=-10.11, EpsM=0.15, EpsW=0.15
# Episode 382/1000, ManagerR=-3.69, WorkerR=-53.93, EpsM=0.15, EpsW=0.15
# Episode 383/1000, ManagerR=-4.07, WorkerR=-88.40, EpsM=0.15, EpsW=0.15
# Episode 384/1000, ManagerR=0.65, WorkerR=-131.39, EpsM=0.15, EpsW=0.15
# Episode 385/1000, ManagerR=0.92, WorkerR=-97.74, EpsM=0.15, EpsW=0.15
# Episode 386/1000, ManagerR=0.81, WorkerR=-110.04, EpsM=0.14, EpsW=0.14
# Episode 387/1000, ManagerR=-4.38, WorkerR=-43.52, EpsM=0.14, EpsW=0.14
# Episode 388/1000, ManagerR=1.04, WorkerR=-108.50, EpsM=0.14, EpsW=0.14
# Episode 389/1000, ManagerR=0.62, WorkerR=-86.13, EpsM=0.14, EpsW=0.14
# Episode 390/1000, ManagerR=-4.51, WorkerR=-31.36, EpsM=0.14, EpsW=0.14
# Episode 391/1000, ManagerR=-4.20, WorkerR=-153.47, EpsM=0.14, EpsW=0.14
# Episode 392/1000, ManagerR=-4.59, WorkerR=-40.73, EpsM=0.14, EpsW=0.14
# Episode 393/1000, ManagerR=1.83, WorkerR=-57.84, EpsM=0.14, EpsW=0.14
# Episode 394/1000, ManagerR=-4.51, WorkerR=-57.92, EpsM=0.14, EpsW=0.14
# Episode 395/1000, ManagerR=-4.08, WorkerR=-34.05, EpsM=0.14, EpsW=0.14
# Episode 396/1000, ManagerR=-4.33, WorkerR=-66.65, EpsM=0.14, EpsW=0.14
# Episode 397/1000, ManagerR=0.49, WorkerR=-96.42, EpsM=0.14, EpsW=0.14
# Episode 398/1000, ManagerR=1.04, WorkerR=-107.93, EpsM=0.14, EpsW=0.14
# Episode 399/1000, ManagerR=-4.13, WorkerR=-62.28, EpsM=0.14, EpsW=0.14
# Episode 400/1000, ManagerR=-4.79, WorkerR=-7.00, EpsM=0.13, EpsW=0.13
# Episode 401/1000, ManagerR=1.42, WorkerR=-68.06, EpsM=0.13, EpsW=0.13
# Episode 402/1000, ManagerR=1.06, WorkerR=-82.83, EpsM=0.13, EpsW=0.13
# Episode 403/1000, ManagerR=0.98, WorkerR=-90.52, EpsM=0.13, EpsW=0.13
# Episode 404/1000, ManagerR=-4.07, WorkerR=-51.80, EpsM=0.13, EpsW=0.13
# Episode 405/1000, ManagerR=-4.25, WorkerR=-45.67, EpsM=0.13, EpsW=0.13
# Episode 406/1000, ManagerR=1.02, WorkerR=-66.82, EpsM=0.13, EpsW=0.13
# Episode 407/1000, ManagerR=0.67, WorkerR=-87.48, EpsM=0.13, EpsW=0.13
# Episode 408/1000, ManagerR=-3.97, WorkerR=-88.79, EpsM=0.13, EpsW=0.13
# Episode 409/1000, ManagerR=0.88, WorkerR=-84.07, EpsM=0.13, EpsW=0.13
# Episode 410/1000, ManagerR=-3.95, WorkerR=-71.36, EpsM=0.13, EpsW=0.13
# Episode 411/1000, ManagerR=0.86, WorkerR=-109.61, EpsM=0.13, EpsW=0.13
# Episode 412/1000, ManagerR=1.46, WorkerR=-69.55, EpsM=0.13, EpsW=0.13
# Episode 413/1000, ManagerR=0.81, WorkerR=-105.52, EpsM=0.13, EpsW=0.13
# Episode 414/1000, ManagerR=0.98, WorkerR=-69.67, EpsM=0.13, EpsW=0.13
# Episode 415/1000, ManagerR=-4.69, WorkerR=-6.75, EpsM=0.12, EpsW=0.12
# Episode 416/1000, ManagerR=0.88, WorkerR=-93.25, EpsM=0.12, EpsW=0.12
# Episode 417/1000, ManagerR=0.92, WorkerR=-69.85, EpsM=0.12, EpsW=0.12
# Episode 418/1000, ManagerR=0.92, WorkerR=-115.70, EpsM=0.12, EpsW=0.12
# Episode 419/1000, ManagerR=-4.59, WorkerR=-19.19, EpsM=0.12, EpsW=0.12
# Episode 420/1000, ManagerR=0.96, WorkerR=-95.60, EpsM=0.12, EpsW=0.12
# Episode 421/1000, ManagerR=1.06, WorkerR=-82.01, EpsM=0.12, EpsW=0.12
# Episode 422/1000, ManagerR=-4.36, WorkerR=-81.74, EpsM=0.12, EpsW=0.12
# Episode 423/1000, ManagerR=0.96, WorkerR=-66.58, EpsM=0.12, EpsW=0.12
# Episode 424/1000, ManagerR=0.63, WorkerR=-120.65, EpsM=0.12, EpsW=0.12
# Episode 425/1000, ManagerR=1.54, WorkerR=-100.21, EpsM=0.12, EpsW=0.12
# Episode 426/1000, ManagerR=-4.81, WorkerR=-13.75, EpsM=0.12, EpsW=0.12
# Episode 427/1000, ManagerR=1.21, WorkerR=-96.33, EpsM=0.12, EpsW=0.12
# Episode 428/1000, ManagerR=1.15, WorkerR=-89.32, EpsM=0.12, EpsW=0.12
# Episode 429/1000, ManagerR=1.00, WorkerR=-96.50, EpsM=0.12, EpsW=0.12
# Episode 430/1000, ManagerR=1.23, WorkerR=-78.09, EpsM=0.12, EpsW=0.12
# Episode 431/1000, ManagerR=-3.77, WorkerR=-87.60, EpsM=0.12, EpsW=0.12
# Episode 432/1000, ManagerR=1.34, WorkerR=-74.23, EpsM=0.11, EpsW=0.11
# Episode 433/1000, ManagerR=1.25, WorkerR=-73.22, EpsM=0.11, EpsW=0.11
# Episode 434/1000, ManagerR=-4.71, WorkerR=-8.48, EpsM=0.11, EpsW=0.11
# Episode 435/1000, ManagerR=0.86, WorkerR=-112.95, EpsM=0.11, EpsW=0.11
# Episode 436/1000, ManagerR=1.36, WorkerR=-84.05, EpsM=0.11, EpsW=0.11
# Episode 437/1000, ManagerR=-4.56, WorkerR=-21.07, EpsM=0.11, EpsW=0.11
# Episode 438/1000, ManagerR=-4.79, WorkerR=-8.36, EpsM=0.11, EpsW=0.11
# Episode 439/1000, ManagerR=1.46, WorkerR=-57.65, EpsM=0.11, EpsW=0.11
# Episode 440/1000, ManagerR=-4.37, WorkerR=-4.88, EpsM=0.11, EpsW=0.11
# Episode 441/1000, ManagerR=0.84, WorkerR=-106.00, EpsM=0.11, EpsW=0.11
# Episode 442/1000, ManagerR=0.71, WorkerR=-86.49, EpsM=0.11, EpsW=0.11
# Episode 443/1000, ManagerR=0.96, WorkerR=-98.60, EpsM=0.11, EpsW=0.11
# Episode 444/1000, ManagerR=0.96, WorkerR=-70.68, EpsM=0.11, EpsW=0.11
# Episode 445/1000, ManagerR=1.16, WorkerR=-79.16, EpsM=0.11, EpsW=0.11
# Episode 446/1000, ManagerR=-3.92, WorkerR=-99.36, EpsM=0.11, EpsW=0.11
# Episode 447/1000, ManagerR=0.67, WorkerR=-86.87, EpsM=0.11, EpsW=0.11
# Episode 448/1000, ManagerR=0.95, WorkerR=-81.82, EpsM=0.11, EpsW=0.11
# Episode 449/1000, ManagerR=-4.59, WorkerR=-19.02, EpsM=0.11, EpsW=0.11
# Episode 450/1000, ManagerR=-4.18, WorkerR=-87.81, EpsM=0.10, EpsW=0.10
# Episode 451/1000, ManagerR=0.73, WorkerR=-120.34, EpsM=0.10, EpsW=0.10
# Episode 452/1000, ManagerR=0.77, WorkerR=-140.37, EpsM=0.10, EpsW=0.10
# Episode 453/1000, ManagerR=1.32, WorkerR=-69.34, EpsM=0.10, EpsW=0.10
# Episode 454/1000, ManagerR=-4.33, WorkerR=-61.49, EpsM=0.10, EpsW=0.10
# Episode 455/1000, ManagerR=1.00, WorkerR=-107.37, EpsM=0.10, EpsW=0.10
# Episode 456/1000, ManagerR=-4.54, WorkerR=-24.82, EpsM=0.10, EpsW=0.10
# Episode 457/1000, ManagerR=1.19, WorkerR=-88.06, EpsM=0.10, EpsW=0.10
# Episode 458/1000, ManagerR=0.93, WorkerR=-71.51, EpsM=0.10, EpsW=0.10
# Episode 459/1000, ManagerR=0.79, WorkerR=-108.40, EpsM=0.10, EpsW=0.10
# Episode 460/1000, ManagerR=-4.33, WorkerR=-132.02, EpsM=0.10, EpsW=0.10
# Episode 461/1000, ManagerR=0.80, WorkerR=-131.58, EpsM=0.10, EpsW=0.10
# Episode 462/1000, ManagerR=1.00, WorkerR=-91.65, EpsM=0.10, EpsW=0.10
# Episode 463/1000, ManagerR=0.80, WorkerR=-101.73, EpsM=0.10, EpsW=0.10
# Episode 464/1000, ManagerR=1.19, WorkerR=-92.68, EpsM=0.10, EpsW=0.10
# Episode 465/1000, ManagerR=-4.02, WorkerR=-82.88, EpsM=0.10, EpsW=0.10
# Episode 466/1000, ManagerR=0.98, WorkerR=-143.96, EpsM=0.10, EpsW=0.10
# Episode 467/1000, ManagerR=-4.25, WorkerR=-44.83, EpsM=0.10, EpsW=0.10
# Episode 468/1000, ManagerR=-4.71, WorkerR=-13.82, EpsM=0.10, EpsW=0.10
# Episode 469/1000, ManagerR=1.04, WorkerR=-82.05, EpsM=0.10, EpsW=0.10
# Episode 470/1000, ManagerR=0.69, WorkerR=-81.02, EpsM=0.10, EpsW=0.10
# Episode 471/1000, ManagerR=0.64, WorkerR=-117.25, EpsM=0.10, EpsW=0.10
# Episode 472/1000, ManagerR=0.80, WorkerR=-113.40, EpsM=0.10, EpsW=0.10
# Episode 473/1000, ManagerR=-4.69, WorkerR=-11.95, EpsM=0.10, EpsW=0.10
# Episode 474/1000, ManagerR=-4.75, WorkerR=-6.85, EpsM=0.10, EpsW=0.10
# Episode 475/1000, ManagerR=1.00, WorkerR=-134.18, EpsM=0.10, EpsW=0.10
# Episode 476/1000, ManagerR=-4.74, WorkerR=-5.86, EpsM=0.10, EpsW=0.10
# Episode 477/1000, ManagerR=-4.81, WorkerR=-7.45, EpsM=0.10, EpsW=0.10
# Episode 478/1000, ManagerR=-4.82, WorkerR=-7.91, EpsM=0.10, EpsW=0.10
# Episode 479/1000, ManagerR=1.44, WorkerR=-77.64, EpsM=0.10, EpsW=0.10
# Episode 480/1000, ManagerR=-3.94, WorkerR=-84.62, EpsM=0.10, EpsW=0.10
# Episode 481/1000, ManagerR=-4.83, WorkerR=-7.39, EpsM=0.10, EpsW=0.10
# Episode 482/1000, ManagerR=-4.85, WorkerR=-7.35, EpsM=0.10, EpsW=0.10
# Episode 483/1000, ManagerR=0.79, WorkerR=-130.98, EpsM=0.10, EpsW=0.10
# Episode 484/1000, ManagerR=1.04, WorkerR=-64.48, EpsM=0.10, EpsW=0.10
# Episode 485/1000, ManagerR=0.88, WorkerR=-136.33, EpsM=0.10, EpsW=0.10
# Episode 486/1000, ManagerR=0.81, WorkerR=-66.86, EpsM=0.10, EpsW=0.10
# Episode 487/1000, ManagerR=0.77, WorkerR=-87.30, EpsM=0.10, EpsW=0.10
# Episode 488/1000, ManagerR=1.29, WorkerR=-47.71, EpsM=0.10, EpsW=0.10
# Episode 489/1000, ManagerR=-4.56, WorkerR=-86.59, EpsM=0.10, EpsW=0.10
# Episode 490/1000, ManagerR=1.44, WorkerR=-109.90, EpsM=0.10, EpsW=0.10
# Episode 491/1000, ManagerR=-3.81, WorkerR=-72.18, EpsM=0.10, EpsW=0.10
# Episode 492/1000, ManagerR=1.08, WorkerR=-118.74, EpsM=0.10, EpsW=0.10
# Episode 493/1000, ManagerR=1.02, WorkerR=-71.40, EpsM=0.10, EpsW=0.10
# Episode 494/1000, ManagerR=0.92, WorkerR=-78.92, EpsM=0.10, EpsW=0.10
# Episode 495/1000, ManagerR=1.36, WorkerR=-92.26, EpsM=0.10, EpsW=0.10
# Episode 496/1000, ManagerR=1.00, WorkerR=-115.21, EpsM=0.10, EpsW=0.10
# Episode 497/1000, ManagerR=0.77, WorkerR=-105.77, EpsM=0.10, EpsW=0.10
# Episode 498/1000, ManagerR=-4.20, WorkerR=-10.28, EpsM=0.10, EpsW=0.10
# Episode 499/1000, ManagerR=0.85, WorkerR=-126.93, EpsM=0.10, EpsW=0.10
# Episode 500/1000, ManagerR=0.72, WorkerR=-114.65, EpsM=0.10, EpsW=0.10
# Episode 501/1000, ManagerR=1.26, WorkerR=-91.89, EpsM=0.10, EpsW=0.10
# Episode 502/1000, ManagerR=1.09, WorkerR=-93.02, EpsM=0.10, EpsW=0.10
# Episode 503/1000, ManagerR=1.03, WorkerR=-114.93, EpsM=0.10, EpsW=0.10
# Episode 504/1000, ManagerR=0.73, WorkerR=-108.75, EpsM=0.10, EpsW=0.10
# Episode 505/1000, ManagerR=1.16, WorkerR=-106.12, EpsM=0.10, EpsW=0.10
# Episode 506/1000, ManagerR=0.80, WorkerR=-123.13, EpsM=0.10, EpsW=0.10
# Episode 507/1000, ManagerR=-4.13, WorkerR=-65.36, EpsM=0.10, EpsW=0.10
# Episode 508/1000, ManagerR=0.81, WorkerR=-117.26, EpsM=0.10, EpsW=0.10
# Episode 509/1000, ManagerR=1.31, WorkerR=-97.48, EpsM=0.10, EpsW=0.10
# Episode 510/1000, ManagerR=-4.61, WorkerR=-47.03, EpsM=0.10, EpsW=0.10
# Episode 511/1000, ManagerR=1.00, WorkerR=-95.25, EpsM=0.10, EpsW=0.10
# Episode 512/1000, ManagerR=1.02, WorkerR=-108.99, EpsM=0.10, EpsW=0.10
# Episode 513/1000, ManagerR=0.96, WorkerR=-87.72, EpsM=0.10, EpsW=0.10
# Episode 514/1000, ManagerR=-4.77, WorkerR=-9.29, EpsM=0.10, EpsW=0.10
# Episode 515/1000, ManagerR=0.90, WorkerR=-114.80, EpsM=0.10, EpsW=0.10
# Episode 516/1000, ManagerR=0.73, WorkerR=-82.80, EpsM=0.10, EpsW=0.10
# Episode 517/1000, ManagerR=-4.85, WorkerR=-7.16, EpsM=0.10, EpsW=0.10
# Episode 518/1000, ManagerR=-4.56, WorkerR=-23.49, EpsM=0.10, EpsW=0.10
# Episode 519/1000, ManagerR=1.19, WorkerR=-77.95, EpsM=0.10, EpsW=0.10
# Episode 520/1000, ManagerR=-4.61, WorkerR=-13.32, EpsM=0.10, EpsW=0.10
# Episode 521/1000, ManagerR=-4.49, WorkerR=-92.12, EpsM=0.10, EpsW=0.10
# Episode 522/1000, ManagerR=0.81, WorkerR=-114.74, EpsM=0.10, EpsW=0.10
# Episode 523/1000, ManagerR=0.82, WorkerR=-124.67, EpsM=0.10, EpsW=0.10
# Episode 524/1000, ManagerR=1.06, WorkerR=-92.95, EpsM=0.10, EpsW=0.10
# Episode 525/1000, ManagerR=1.02, WorkerR=-106.53, EpsM=0.10, EpsW=0.10
# Episode 526/1000, ManagerR=0.75, WorkerR=-154.38, EpsM=0.10, EpsW=0.10
# Episode 527/1000, ManagerR=-4.52, WorkerR=-36.64, EpsM=0.10, EpsW=0.10
# Episode 528/1000, ManagerR=0.81, WorkerR=-108.50, EpsM=0.10, EpsW=0.10
# Episode 529/1000, ManagerR=0.80, WorkerR=-91.53, EpsM=0.10, EpsW=0.10
# Episode 530/1000, ManagerR=1.17, WorkerR=-74.97, EpsM=0.10, EpsW=0.10
# Episode 531/1000, ManagerR=1.15, WorkerR=-84.91, EpsM=0.10, EpsW=0.10
# Episode 532/1000, ManagerR=1.09, WorkerR=-77.46, EpsM=0.10, EpsW=0.10
# Episode 533/1000, ManagerR=-4.56, WorkerR=-29.77, EpsM=0.10, EpsW=0.10
# Episode 534/1000, ManagerR=-4.05, WorkerR=-76.51, EpsM=0.10, EpsW=0.10
# Episode 535/1000, ManagerR=1.09, WorkerR=-85.35, EpsM=0.10, EpsW=0.10
# Episode 536/1000, ManagerR=0.98, WorkerR=-102.81, EpsM=0.10, EpsW=0.10
# Episode 537/1000, ManagerR=1.29, WorkerR=-63.48, EpsM=0.10, EpsW=0.10
# Episode 538/1000, ManagerR=1.06, WorkerR=-95.59, EpsM=0.10, EpsW=0.10
# Episode 539/1000, ManagerR=-4.79, WorkerR=-6.07, EpsM=0.10, EpsW=0.10
# Episode 540/1000, ManagerR=-4.79, WorkerR=-7.14, EpsM=0.10, EpsW=0.10
# Episode 541/1000, ManagerR=-4.23, WorkerR=-34.64, EpsM=0.10, EpsW=0.10
# Episode 542/1000, ManagerR=-4.79, WorkerR=-7.33, EpsM=0.10, EpsW=0.10
# Episode 543/1000, ManagerR=1.88, WorkerR=-71.87, EpsM=0.10, EpsW=0.10
# Episode 544/1000, ManagerR=-4.69, WorkerR=-13.05, EpsM=0.10, EpsW=0.10
# Episode 545/1000, ManagerR=1.09, WorkerR=-73.14, EpsM=0.10, EpsW=0.10
# Episode 546/1000, ManagerR=1.05, WorkerR=-126.17, EpsM=0.10, EpsW=0.10
# Episode 547/1000, ManagerR=-4.64, WorkerR=-33.09, EpsM=0.10, EpsW=0.10
# Episode 548/1000, ManagerR=0.90, WorkerR=-85.73, EpsM=0.10, EpsW=0.10
# Episode 549/1000, ManagerR=-4.75, WorkerR=-16.91, EpsM=0.10, EpsW=0.10
# Episode 550/1000, ManagerR=-4.74, WorkerR=-23.31, EpsM=0.10, EpsW=0.10
# Episode 551/1000, ManagerR=-4.33, WorkerR=-76.93, EpsM=0.10, EpsW=0.10
# Episode 552/1000, ManagerR=-4.85, WorkerR=-7.49, EpsM=0.10, EpsW=0.10
# Episode 553/1000, ManagerR=-4.81, WorkerR=-6.17, EpsM=0.10, EpsW=0.10
# Episode 554/1000, ManagerR=0.51, WorkerR=-109.87, EpsM=0.10, EpsW=0.10
# Episode 555/1000, ManagerR=0.54, WorkerR=-93.89, EpsM=0.10, EpsW=0.10
# Episode 556/1000, ManagerR=1.23, WorkerR=-71.11, EpsM=0.10, EpsW=0.10
# Episode 557/1000, ManagerR=0.84, WorkerR=-112.54, EpsM=0.10, EpsW=0.10
# Episode 558/1000, ManagerR=1.11, WorkerR=-91.34, EpsM=0.10, EpsW=0.10
# Episode 559/1000, ManagerR=1.36, WorkerR=-89.72, EpsM=0.10, EpsW=0.10
# Episode 560/1000, ManagerR=1.23, WorkerR=-88.29, EpsM=0.10, EpsW=0.10
# Episode 561/1000, ManagerR=-4.72, WorkerR=-54.10, EpsM=0.10, EpsW=0.10
# Episode 562/1000, ManagerR=-4.18, WorkerR=-44.86, EpsM=0.10, EpsW=0.10
# Episode 563/1000, ManagerR=-4.72, WorkerR=-13.10, EpsM=0.10, EpsW=0.10
# Episode 564/1000, ManagerR=1.04, WorkerR=-67.23, EpsM=0.10, EpsW=0.10
# Episode 565/1000, ManagerR=1.18, WorkerR=-111.44, EpsM=0.10, EpsW=0.10
# Episode 566/1000, ManagerR=0.95, WorkerR=-54.54, EpsM=0.10, EpsW=0.10
# Episode 567/1000, ManagerR=-4.02, WorkerR=-68.03, EpsM=0.10, EpsW=0.10
# Episode 568/1000, ManagerR=0.79, WorkerR=-107.98, EpsM=0.10, EpsW=0.10
# Episode 569/1000, ManagerR=1.25, WorkerR=-59.66, EpsM=0.10, EpsW=0.10
# Episode 570/1000, ManagerR=-3.89, WorkerR=-60.31, EpsM=0.10, EpsW=0.10
# Episode 571/1000, ManagerR=0.71, WorkerR=-92.39, EpsM=0.10, EpsW=0.10
# Episode 572/1000, ManagerR=1.44, WorkerR=-68.84, EpsM=0.10, EpsW=0.10
# Episode 573/1000, ManagerR=-4.79, WorkerR=-7.84, EpsM=0.10, EpsW=0.10
# Episode 574/1000, ManagerR=0.96, WorkerR=-102.50, EpsM=0.10, EpsW=0.10
# Episode 575/1000, ManagerR=0.95, WorkerR=-98.77, EpsM=0.10, EpsW=0.10
# Episode 576/1000, ManagerR=0.80, WorkerR=-82.24, EpsM=0.10, EpsW=0.10
# Episode 577/1000, ManagerR=0.73, WorkerR=-122.98, EpsM=0.10, EpsW=0.10
# Episode 578/1000, ManagerR=0.44, WorkerR=-146.96, EpsM=0.10, EpsW=0.10
# Episode 579/1000, ManagerR=0.84, WorkerR=-132.88, EpsM=0.10, EpsW=0.10
# Episode 580/1000, ManagerR=-4.64, WorkerR=-11.69, EpsM=0.10, EpsW=0.10
# Episode 581/1000, ManagerR=-4.64, WorkerR=-32.46, EpsM=0.10, EpsW=0.10
# Episode 582/1000, ManagerR=1.31, WorkerR=-87.27, EpsM=0.10, EpsW=0.10
# Episode 583/1000, ManagerR=-4.15, WorkerR=-104.89, EpsM=0.10, EpsW=0.10
# Episode 584/1000, ManagerR=0.69, WorkerR=-102.56, EpsM=0.10, EpsW=0.10
# Episode 585/1000, ManagerR=0.77, WorkerR=-109.65, EpsM=0.10, EpsW=0.10
# Episode 586/1000, ManagerR=1.18, WorkerR=-96.99, EpsM=0.10, EpsW=0.10
# Episode 587/1000, ManagerR=0.51, WorkerR=-128.75, EpsM=0.10, EpsW=0.10
# Episode 588/1000, ManagerR=-4.49, WorkerR=-83.20, EpsM=0.10, EpsW=0.10
# Episode 589/1000, ManagerR=0.48, WorkerR=-152.40, EpsM=0.10, EpsW=0.10
# Episode 590/1000, ManagerR=-4.56, WorkerR=-19.70, EpsM=0.10, EpsW=0.10
# Episode 591/1000, ManagerR=0.77, WorkerR=-82.80, EpsM=0.10, EpsW=0.10
# Episode 592/1000, ManagerR=1.04, WorkerR=-86.84, EpsM=0.10, EpsW=0.10
# Episode 593/1000, ManagerR=0.58, WorkerR=-169.58, EpsM=0.10, EpsW=0.10
# Episode 594/1000, ManagerR=-4.28, WorkerR=-20.02, EpsM=0.10, EpsW=0.10
# Episode 595/1000, ManagerR=-4.67, WorkerR=-18.84, EpsM=0.10, EpsW=0.10
# Episode 596/1000, ManagerR=0.85, WorkerR=-74.53, EpsM=0.10, EpsW=0.10
# Episode 597/1000, ManagerR=1.18, WorkerR=-78.64, EpsM=0.10, EpsW=0.10
# Episode 598/1000, ManagerR=-4.69, WorkerR=-16.65, EpsM=0.10, EpsW=0.10
# Episode 599/1000, ManagerR=-4.37, WorkerR=-62.85, EpsM=0.10, EpsW=0.10
# Episode 600/1000, ManagerR=-4.38, WorkerR=-53.24, EpsM=0.10, EpsW=0.10
# Episode 601/1000, ManagerR=-4.18, WorkerR=-65.52, EpsM=0.10, EpsW=0.10
# Episode 602/1000, ManagerR=0.86, WorkerR=-133.62, EpsM=0.10, EpsW=0.10
# Episode 603/1000, ManagerR=0.75, WorkerR=-78.87, EpsM=0.10, EpsW=0.10
# Episode 604/1000, ManagerR=0.87, WorkerR=-134.69, EpsM=0.10, EpsW=0.10
# Episode 605/1000, ManagerR=-4.46, WorkerR=-54.39, EpsM=0.10, EpsW=0.10
# Episode 606/1000, ManagerR=-4.72, WorkerR=-16.20, EpsM=0.10, EpsW=0.10
# Episode 607/1000, ManagerR=-4.51, WorkerR=-30.67, EpsM=0.10, EpsW=0.10
# Episode 608/1000, ManagerR=1.48, WorkerR=-65.13, EpsM=0.10, EpsW=0.10
# Episode 609/1000, ManagerR=0.59, WorkerR=-81.30, EpsM=0.10, EpsW=0.10
# Episode 610/1000, ManagerR=0.79, WorkerR=-76.87, EpsM=0.10, EpsW=0.10
# Episode 611/1000, ManagerR=0.84, WorkerR=-110.76, EpsM=0.10, EpsW=0.10
# Episode 612/1000, ManagerR=1.11, WorkerR=-69.43, EpsM=0.10, EpsW=0.10
# Episode 613/1000, ManagerR=1.09, WorkerR=-128.04, EpsM=0.10, EpsW=0.10
# Episode 614/1000, ManagerR=1.18, WorkerR=-88.36, EpsM=0.10, EpsW=0.10
# Episode 615/1000, ManagerR=0.95, WorkerR=-80.90, EpsM=0.10, EpsW=0.10
# Episode 616/1000, ManagerR=-4.59, WorkerR=-90.37, EpsM=0.10, EpsW=0.10
# Episode 617/1000, ManagerR=1.23, WorkerR=-43.58, EpsM=0.10, EpsW=0.10
# Episode 618/1000, ManagerR=-3.92, WorkerR=-50.79, EpsM=0.10, EpsW=0.10
# Episode 619/1000, ManagerR=0.63, WorkerR=-196.17, EpsM=0.10, EpsW=0.10
# Episode 620/1000, ManagerR=1.29, WorkerR=-79.58, EpsM=0.10, EpsW=0.10
# Episode 621/1000, ManagerR=0.77, WorkerR=-122.08, EpsM=0.10, EpsW=0.10
# Episode 622/1000, ManagerR=-4.13, WorkerR=-47.57, EpsM=0.10, EpsW=0.10
# Episode 623/1000, ManagerR=-4.35, WorkerR=-31.14, EpsM=0.10, EpsW=0.10
# Episode 624/1000, ManagerR=0.80, WorkerR=-121.56, EpsM=0.10, EpsW=0.10
# Episode 625/1000, ManagerR=1.40, WorkerR=-60.07, EpsM=0.10, EpsW=0.10
# Episode 626/1000, ManagerR=1.15, WorkerR=-66.29, EpsM=0.10, EpsW=0.10
# Episode 627/1000, ManagerR=1.04, WorkerR=-110.13, EpsM=0.10, EpsW=0.10
# Episode 628/1000, ManagerR=-4.02, WorkerR=-122.94, EpsM=0.10, EpsW=0.10
# Episode 629/1000, ManagerR=0.69, WorkerR=-126.00, EpsM=0.10, EpsW=0.10
# Episode 630/1000, ManagerR=-4.10, WorkerR=-101.99, EpsM=0.10, EpsW=0.10
# Episode 631/1000, ManagerR=1.36, WorkerR=-113.63, EpsM=0.10, EpsW=0.10
# Episode 632/1000, ManagerR=0.92, WorkerR=-72.00, EpsM=0.10, EpsW=0.10
# Episode 633/1000, ManagerR=-4.25, WorkerR=-65.83, EpsM=0.10, EpsW=0.10
# Episode 634/1000, ManagerR=0.98, WorkerR=-118.61, EpsM=0.10, EpsW=0.10
# Episode 635/1000, ManagerR=0.94, WorkerR=-79.41, EpsM=0.10, EpsW=0.10
# Episode 636/1000, ManagerR=1.34, WorkerR=-68.87, EpsM=0.10, EpsW=0.10
# Episode 637/1000, ManagerR=-4.54, WorkerR=-49.85, EpsM=0.10, EpsW=0.10
# Episode 638/1000, ManagerR=0.98, WorkerR=-123.01, EpsM=0.10, EpsW=0.10
# Episode 639/1000, ManagerR=-4.64, WorkerR=-9.52, EpsM=0.10, EpsW=0.10
# Episode 640/1000, ManagerR=-4.81, WorkerR=-8.05, EpsM=0.10, EpsW=0.10
# Episode 641/1000, ManagerR=1.11, WorkerR=-70.54, EpsM=0.10, EpsW=0.10
# Episode 642/1000, ManagerR=0.94, WorkerR=-98.28, EpsM=0.10, EpsW=0.10
# Episode 643/1000, ManagerR=1.00, WorkerR=-80.85, EpsM=0.10, EpsW=0.10
# Episode 644/1000, ManagerR=0.94, WorkerR=-84.84, EpsM=0.10, EpsW=0.10
# Episode 645/1000, ManagerR=0.69, WorkerR=-147.53, EpsM=0.10, EpsW=0.10
# Episode 646/1000, ManagerR=-4.60, WorkerR=-14.15, EpsM=0.10, EpsW=0.10
# Episode 647/1000, ManagerR=-4.61, WorkerR=-36.38, EpsM=0.10, EpsW=0.10
# Episode 648/1000, ManagerR=-4.41, WorkerR=-47.10, EpsM=0.10, EpsW=0.10
# Episode 649/1000, ManagerR=-4.49, WorkerR=-33.77, EpsM=0.10, EpsW=0.10
# Episode 650/1000, ManagerR=0.92, WorkerR=-67.94, EpsM=0.10, EpsW=0.10
# Episode 651/1000, ManagerR=1.19, WorkerR=-89.36, EpsM=0.10, EpsW=0.10
# Episode 652/1000, ManagerR=0.57, WorkerR=-165.13, EpsM=0.10, EpsW=0.10
# Episode 653/1000, ManagerR=0.40, WorkerR=-139.92, EpsM=0.10, EpsW=0.10
# Episode 654/1000, ManagerR=0.54, WorkerR=-122.48, EpsM=0.10, EpsW=0.10
# Episode 655/1000, ManagerR=-4.54, WorkerR=-46.92, EpsM=0.10, EpsW=0.10
# Episode 656/1000, ManagerR=0.79, WorkerR=-121.03, EpsM=0.10, EpsW=0.10
# Episode 657/1000, ManagerR=-4.28, WorkerR=-35.17, EpsM=0.10, EpsW=0.10
# Episode 658/1000, ManagerR=0.71, WorkerR=-154.21, EpsM=0.10, EpsW=0.10
# Episode 659/1000, ManagerR=1.00, WorkerR=-111.44, EpsM=0.10, EpsW=0.10
# Episode 660/1000, ManagerR=1.06, WorkerR=-85.81, EpsM=0.10, EpsW=0.10
# Episode 661/1000, ManagerR=-4.19, WorkerR=-48.14, EpsM=0.10, EpsW=0.10
# Episode 662/1000, ManagerR=0.90, WorkerR=-81.33, EpsM=0.10, EpsW=0.10
# Episode 663/1000, ManagerR=0.64, WorkerR=-91.72, EpsM=0.10, EpsW=0.10
# Episode 664/1000, ManagerR=-4.29, WorkerR=-52.07, EpsM=0.10, EpsW=0.10
# Episode 665/1000, ManagerR=-3.66, WorkerR=-85.98, EpsM=0.10, EpsW=0.10
# Episode 666/1000, ManagerR=-4.48, WorkerR=-26.58, EpsM=0.10, EpsW=0.10
# Episode 667/1000, ManagerR=-4.79, WorkerR=-4.62, EpsM=0.10, EpsW=0.10
# Episode 668/1000, ManagerR=0.90, WorkerR=-107.31, EpsM=0.10, EpsW=0.10
# Episode 669/1000, ManagerR=0.57, WorkerR=-96.52, EpsM=0.10, EpsW=0.10
# Episode 670/1000, ManagerR=-4.56, WorkerR=-8.41, EpsM=0.10, EpsW=0.10
# Episode 671/1000, ManagerR=1.65, WorkerR=-36.23, EpsM=0.10, EpsW=0.10
# Episode 672/1000, ManagerR=-3.71, WorkerR=-77.57, EpsM=0.10, EpsW=0.10
# Episode 673/1000, ManagerR=1.23, WorkerR=-68.15, EpsM=0.10, EpsW=0.10
# Episode 674/1000, ManagerR=1.18, WorkerR=-83.63, EpsM=0.10, EpsW=0.10
# Episode 675/1000, ManagerR=0.90, WorkerR=-102.11, EpsM=0.10, EpsW=0.10
# Episode 676/1000, ManagerR=-4.77, WorkerR=-4.96, EpsM=0.10, EpsW=0.10
# Episode 677/1000, ManagerR=1.04, WorkerR=-61.98, EpsM=0.10, EpsW=0.10
# Episode 678/1000, ManagerR=0.46, WorkerR=-126.16, EpsM=0.10, EpsW=0.10
# Episode 679/1000, ManagerR=1.00, WorkerR=-56.87, EpsM=0.10, EpsW=0.10
# Episode 680/1000, ManagerR=0.75, WorkerR=-125.75, EpsM=0.10, EpsW=0.10
# Episode 681/1000, ManagerR=1.11, WorkerR=-92.85, EpsM=0.10, EpsW=0.10
# ...
# Episode 776/1000, ManagerR=0.84, WorkerR=-108.34, EpsM=0.10, EpsW=0.10
# Episode 777/1000, ManagerR=1.71, WorkerR=-54.23, EpsM=0.10, EpsW=0.10
# Episode 778/1000, ManagerR=1.34, WorkerR=-76.87, EpsM=0.10, EpsW=0.10
# Episode 779/1000, ManagerR=1.23, WorkerR=-71.15, EpsM=0.10, EpsW=0.10
# Episode 780/1000, ManagerR=1.21, WorkerR=-87.77, EpsM=0.10, EpsW=0.10
# Episode 781/1000, ManagerR=0.50, WorkerR=-118.77, EpsM=0.10, EpsW=0.10
# Episode 782/1000, ManagerR=0.93, WorkerR=-118.92, EpsM=0.10, EpsW=0.10
# Episode 783/1000, ManagerR=-4.74, WorkerR=-5.12, EpsM=0.10, EpsW=0.10
# Episode 784/1000, ManagerR=1.19, WorkerR=-129.41, EpsM=0.10, EpsW=0.10
# Episode 785/1000, ManagerR=0.64, WorkerR=-124.38, EpsM=0.10, EpsW=0.10
# Episode 786/1000, ManagerR=0.71, WorkerR=-130.29, EpsM=0.10, EpsW=0.10
# Episode 787/1000, ManagerR=1.00, WorkerR=-56.54, EpsM=0.10, EpsW=0.10
# Episode 788/1000, ManagerR=0.86, WorkerR=-132.56, EpsM=0.10, EpsW=0.10
# Episode 789/1000, ManagerR=1.17, WorkerR=-71.01, EpsM=0.10, EpsW=0.10
# Episode 790/1000, ManagerR=1.08, WorkerR=-132.31, EpsM=0.10, EpsW=0.10
# Episode 791/1000, ManagerR=0.79, WorkerR=-131.27, EpsM=0.10, EpsW=0.10
# Episode 792/1000, ManagerR=0.90, WorkerR=-46.56, EpsM=0.10, EpsW=0.10
# Episode 793/1000, ManagerR=0.90, WorkerR=-109.52, EpsM=0.10, EpsW=0.10
# Episode 794/1000, ManagerR=0.65, WorkerR=-81.19, EpsM=0.10, EpsW=0.10
# Episode 795/1000, ManagerR=-4.59, WorkerR=-26.50, EpsM=0.10, EpsW=0.10
# Episode 796/1000, ManagerR=-4.05, WorkerR=-77.85, EpsM=0.10, EpsW=0.10
# Episode 797/1000, ManagerR=0.69, WorkerR=-87.32, EpsM=0.10, EpsW=0.10
# Episode 798/1000, ManagerR=1.08, WorkerR=-150.28, EpsM=0.10, EpsW=0.10
# Episode 799/1000, ManagerR=1.26, WorkerR=-121.89, EpsM=0.10, EpsW=0.10
# Episode 800/1000, ManagerR=-4.62, WorkerR=-9.01, EpsM=0.10, EpsW=0.10
# Episode 801/1000, ManagerR=0.54, WorkerR=-135.71, EpsM=0.10, EpsW=0.10
# Episode 802/1000, ManagerR=-4.28, WorkerR=-21.48, EpsM=0.10, EpsW=0.10
# Episode 803/1000, ManagerR=1.11, WorkerR=-82.08, EpsM=0.10, EpsW=0.10
# Episode 804/1000, ManagerR=0.90, WorkerR=-109.68, EpsM=0.10, EpsW=0.10
# Episode 805/1000, ManagerR=0.71, WorkerR=-101.52, EpsM=0.10, EpsW=0.10
# Episode 806/1000, ManagerR=1.05, WorkerR=-98.31, EpsM=0.10, EpsW=0.10
# Episode 807/1000, ManagerR=1.80, WorkerR=-62.02, EpsM=0.10, EpsW=0.10
# Episode 808/1000, ManagerR=1.39, WorkerR=-96.10, EpsM=0.10, EpsW=0.10
# Episode 809/1000, ManagerR=0.48, WorkerR=-90.07, EpsM=0.10, EpsW=0.10
# Episode 810/1000, ManagerR=0.57, WorkerR=-81.55, EpsM=0.10, EpsW=0.10
# Episode 811/1000, ManagerR=0.48, WorkerR=-92.70, EpsM=0.10, EpsW=0.10
# Episode 812/1000, ManagerR=0.69, WorkerR=-98.13, EpsM=0.10, EpsW=0.10
# Episode 813/1000, ManagerR=1.40, WorkerR=-69.75, EpsM=0.10, EpsW=0.10
# Episode 814/1000, ManagerR=1.08, WorkerR=-70.83, EpsM=0.10, EpsW=0.10
# Episode 815/1000, ManagerR=1.04, WorkerR=-92.50, EpsM=0.10, EpsW=0.10
# Episode 816/1000, ManagerR=0.98, WorkerR=-87.83, EpsM=0.10, EpsW=0.10
# Episode 817/1000, ManagerR=0.96, WorkerR=-37.35, EpsM=0.10, EpsW=0.10
# Episode 818/1000, ManagerR=1.09, WorkerR=-87.56, EpsM=0.10, EpsW=0.10
# Episode 819/1000, ManagerR=0.77, WorkerR=-79.66, EpsM=0.10, EpsW=0.10
# Episode 820/1000, ManagerR=1.11, WorkerR=-64.30, EpsM=0.10, EpsW=0.10
# Episode 821/1000, ManagerR=-4.56, WorkerR=-86.53, EpsM=0.10, EpsW=0.10
# Episode 822/1000, ManagerR=-4.19, WorkerR=-57.21, EpsM=0.10, EpsW=0.10
# Episode 823/1000, ManagerR=1.00, WorkerR=-98.15, EpsM=0.10, EpsW=0.10
# Episode 824/1000, ManagerR=1.31, WorkerR=-126.38, EpsM=0.10, EpsW=0.10
# Episode 825/1000, ManagerR=-4.54, WorkerR=-34.60, EpsM=0.10, EpsW=0.10
# Episode 826/1000, ManagerR=-4.38, WorkerR=-57.23, EpsM=0.10, EpsW=0.10
# Episode 827/1000, ManagerR=-4.23, WorkerR=-123.40, EpsM=0.10, EpsW=0.10
# Episode 828/1000, ManagerR=-4.50, WorkerR=-22.21, EpsM=0.10, EpsW=0.10
# Episode 829/1000, ManagerR=-4.56, WorkerR=-49.89, EpsM=0.10, EpsW=0.10
# Episode 830/1000, ManagerR=1.03, WorkerR=-138.33, EpsM=0.10, EpsW=0.10
# Episode 831/1000, ManagerR=0.46, WorkerR=-163.14, EpsM=0.10, EpsW=0.10
# Episode 832/1000, ManagerR=-3.89, WorkerR=-62.86, EpsM=0.10, EpsW=0.10
# Episode 833/1000, ManagerR=1.39, WorkerR=-64.39, EpsM=0.10, EpsW=0.10
# Episode 834/1000, ManagerR=-4.39, WorkerR=-55.35, EpsM=0.10, EpsW=0.10
# Episode 835/1000, ManagerR=-4.46, WorkerR=-71.46, EpsM=0.10, EpsW=0.10
# Episode 836/1000, ManagerR=-4.61, WorkerR=-6.26, EpsM=0.10, EpsW=0.10
# Episode 837/1000, ManagerR=1.34, WorkerR=-58.72, EpsM=0.10, EpsW=0.10
# Episode 838/1000, ManagerR=-3.71, WorkerR=-93.42, EpsM=0.10, EpsW=0.10
# Episode 839/1000, ManagerR=1.62, WorkerR=-89.62, EpsM=0.10, EpsW=0.10
# Episode 840/1000, ManagerR=-4.36, WorkerR=-34.49, EpsM=0.10, EpsW=0.10
# Episode 841/1000, ManagerR=1.41, WorkerR=-106.19, EpsM=0.10, EpsW=0.10
# Episode 842/1000, ManagerR=-4.31, WorkerR=-60.79, EpsM=0.10, EpsW=0.10
# Episode 843/1000, ManagerR=0.92, WorkerR=-77.39, EpsM=0.10, EpsW=0.10
# Episode 844/1000, ManagerR=0.88, WorkerR=-114.65, EpsM=0.10, EpsW=0.10
# Episode 845/1000, ManagerR=0.58, WorkerR=-141.52, EpsM=0.10, EpsW=0.10
# Episode 846/1000, ManagerR=-4.02, WorkerR=-85.86, EpsM=0.10, EpsW=0.10
# Episode 847/1000, ManagerR=-4.28, WorkerR=-36.16, EpsM=0.10, EpsW=0.10
# Episode 848/1000, ManagerR=1.00, WorkerR=-37.40, EpsM=0.10, EpsW=0.10
# Episode 849/1000, ManagerR=-4.59, WorkerR=-31.38, EpsM=0.10, EpsW=0.10
# Episode 850/1000, ManagerR=0.41, WorkerR=-36.09, EpsM=0.10, EpsW=0.10
# Episode 851/1000, ManagerR=-4.15, WorkerR=-106.43, EpsM=0.10, EpsW=0.10
# Episode 852/1000, ManagerR=-4.41, WorkerR=-104.10, EpsM=0.10, EpsW=0.10
# Episode 853/1000, ManagerR=-4.10, WorkerR=-63.89, EpsM=0.10, EpsW=0.10
# Episode 854/1000, ManagerR=0.58, WorkerR=-112.44, EpsM=0.10, EpsW=0.10
# Episode 855/1000, ManagerR=-4.31, WorkerR=-58.68, EpsM=0.10, EpsW=0.10
# Episode 856/1000, ManagerR=-3.79, WorkerR=-68.75, EpsM=0.10, EpsW=0.10
# Episode 857/1000, ManagerR=-4.43, WorkerR=-34.64, EpsM=0.10, EpsW=0.10
# Episode 858/1000, ManagerR=0.94, WorkerR=-102.84, EpsM=0.10, EpsW=0.10
# Episode 859/1000, ManagerR=1.05, WorkerR=-109.75, EpsM=0.10, EpsW=0.10
# Episode 860/1000, ManagerR=1.02, WorkerR=-127.34, EpsM=0.10, EpsW=0.10
# Episode 861/1000, ManagerR=1.11, WorkerR=-76.43, EpsM=0.10, EpsW=0.10
# Episode 862/1000, ManagerR=0.90, WorkerR=-106.40, EpsM=0.10, EpsW=0.10
# Episode 863/1000, ManagerR=-4.07, WorkerR=-79.22, EpsM=0.10, EpsW=0.10
# Episode 864/1000, ManagerR=0.94, WorkerR=-108.13, EpsM=0.10, EpsW=0.10
# Episode 865/1000, ManagerR=1.15, WorkerR=-91.11, EpsM=0.10, EpsW=0.10
# Episode 866/1000, ManagerR=1.23, WorkerR=-88.71, EpsM=0.10, EpsW=0.10
# Episode 867/1000, ManagerR=1.18, WorkerR=-87.39, EpsM=0.10, EpsW=0.10
# Episode 868/1000, ManagerR=-4.44, WorkerR=-72.38, EpsM=0.10, EpsW=0.10
# Episode 869/1000, ManagerR=0.57, WorkerR=-108.67, EpsM=0.10, EpsW=0.10
# Episode 870/1000, ManagerR=0.80, WorkerR=-113.53, EpsM=0.10, EpsW=0.10
# Episode 871/1000, ManagerR=1.42, WorkerR=-87.65, EpsM=0.10, EpsW=0.10
# Episode 872/1000, ManagerR=-4.02, WorkerR=-58.50, EpsM=0.10, EpsW=0.10
# Episode 873/1000, ManagerR=1.02, WorkerR=-122.44, EpsM=0.10, EpsW=0.10
# Episode 874/1000, ManagerR=1.06, WorkerR=-120.37, EpsM=0.10, EpsW=0.10
# Episode 875/1000, ManagerR=1.49, WorkerR=-83.82, EpsM=0.10, EpsW=0.10
# Episode 876/1000, ManagerR=1.34, WorkerR=-65.43, EpsM=0.10, EpsW=0.10
# Episode 877/1000, ManagerR=-4.61, WorkerR=-73.21, EpsM=0.10, EpsW=0.10
# Episode 878/1000, ManagerR=-4.20, WorkerR=-51.13, EpsM=0.10, EpsW=0.10
# Episode 879/1000, ManagerR=-4.54, WorkerR=-20.94, EpsM=0.10, EpsW=0.10
# Episode 880/1000, ManagerR=1.42, WorkerR=-74.02, EpsM=0.10, EpsW=0.10
# Episode 881/1000, ManagerR=-4.73, WorkerR=-15.68, EpsM=0.10, EpsW=0.10
# Episode 882/1000, ManagerR=1.19, WorkerR=-107.25, EpsM=0.10, EpsW=0.10
# Episode 883/1000, ManagerR=0.67, WorkerR=-123.25, EpsM=0.10, EpsW=0.10
# Episode 884/1000, ManagerR=0.98, WorkerR=-118.33, EpsM=0.10, EpsW=0.10
# Episode 885/1000, ManagerR=1.04, WorkerR=-120.92, EpsM=0.10, EpsW=0.10
# Episode 886/1000, ManagerR=-4.16, WorkerR=-72.10, EpsM=0.10, EpsW=0.10
# Episode 887/1000, ManagerR=1.34, WorkerR=-88.80, EpsM=0.10, EpsW=0.10
# Episode 888/1000, ManagerR=0.77, WorkerR=-125.99, EpsM=0.10, EpsW=0.10
# Episode 889/1000, ManagerR=-4.07, WorkerR=-60.42, EpsM=0.10, EpsW=0.10
# Episode 890/1000, ManagerR=0.85, WorkerR=-105.29, EpsM=0.10, EpsW=0.10
# Episode 891/1000, ManagerR=0.61, WorkerR=-129.68, EpsM=0.10, EpsW=0.10
# Episode 892/1000, ManagerR=-4.33, WorkerR=-72.90, EpsM=0.10, EpsW=0.10
# Episode 893/1000, ManagerR=-3.77, WorkerR=-97.10, EpsM=0.10, EpsW=0.10
# Episode 894/1000, ManagerR=0.98, WorkerR=-113.57, EpsM=0.10, EpsW=0.10
# Episode 895/1000, ManagerR=0.84, WorkerR=-134.64, EpsM=0.10, EpsW=0.10
# Episode 896/1000, ManagerR=0.93, WorkerR=-93.82, EpsM=0.10, EpsW=0.10
# Episode 897/1000, ManagerR=1.52, WorkerR=-59.72, EpsM=0.10, EpsW=0.10
# Episode 898/1000, ManagerR=0.95, WorkerR=-65.89, EpsM=0.10, EpsW=0.10
# Episode 899/1000, ManagerR=-4.46, WorkerR=-40.70, EpsM=0.10, EpsW=0.10
# Episode 900/1000, ManagerR=0.84, WorkerR=-81.15, EpsM=0.10, EpsW=0.10
# Episode 901/1000, ManagerR=1.04, WorkerR=-102.57, EpsM=0.10, EpsW=0.10
# Episode 902/1000, ManagerR=-4.54, WorkerR=-14.63, EpsM=0.10, EpsW=0.10
# Episode 903/1000, ManagerR=-4.69, WorkerR=-7.39, EpsM=0.10, EpsW=0.10
# Episode 904/1000, ManagerR=0.79, WorkerR=-111.80, EpsM=0.10, EpsW=0.10
# Episode 905/1000, ManagerR=1.31, WorkerR=-105.53, EpsM=0.10, EpsW=0.10
# Episode 906/1000, ManagerR=1.04, WorkerR=-77.77, EpsM=0.10, EpsW=0.10
# Episode 907/1000, ManagerR=0.52, WorkerR=-117.19, EpsM=0.10, EpsW=0.10
# Episode 908/1000, ManagerR=0.52, WorkerR=-108.67, EpsM=0.10, EpsW=0.10
# Episode 909/1000, ManagerR=-3.74, WorkerR=-97.87, EpsM=0.10, EpsW=0.10
# Episode 910/1000, ManagerR=0.52, WorkerR=-121.36, EpsM=0.10, EpsW=0.10
# Episode 911/1000, ManagerR=0.67, WorkerR=-101.59, EpsM=0.10, EpsW=0.10
# Episode 912/1000, ManagerR=-3.66, WorkerR=-71.76, EpsM=0.10, EpsW=0.10
# Episode 913/1000, ManagerR=1.06, WorkerR=-118.90, EpsM=0.10, EpsW=0.10
# Episode 914/1000, ManagerR=1.34, WorkerR=-99.60, EpsM=0.10, EpsW=0.10
# Episode 915/1000, ManagerR=0.59, WorkerR=-153.37, EpsM=0.10, EpsW=0.10
# Episode 916/1000, ManagerR=1.21, WorkerR=-87.46, EpsM=0.10, EpsW=0.10
# Episode 917/1000, ManagerR=-4.13, WorkerR=-40.42, EpsM=0.10, EpsW=0.10
# Episode 918/1000, ManagerR=0.75, WorkerR=-87.56, EpsM=0.10, EpsW=0.10
# Episode 919/1000, ManagerR=0.46, WorkerR=-117.53, EpsM=0.10, EpsW=0.10
# Episode 920/1000, ManagerR=0.90, WorkerR=-103.85, EpsM=0.10, EpsW=0.10
# Episode 921/1000, ManagerR=-4.67, WorkerR=-27.45, EpsM=0.10, EpsW=0.10
# Episode 922/1000, ManagerR=1.16, WorkerR=-119.00, EpsM=0.10, EpsW=0.10
# Episode 923/1000, ManagerR=1.02, WorkerR=-78.60, EpsM=0.10, EpsW=0.10
# Episode 924/1000, ManagerR=0.61, WorkerR=-97.46, EpsM=0.10, EpsW=0.10
# Episode 925/1000, ManagerR=-4.43, WorkerR=-10.60, EpsM=0.10, EpsW=0.10
# Episode 926/1000, ManagerR=1.47, WorkerR=-108.67, EpsM=0.10, EpsW=0.10
# Episode 927/1000, ManagerR=-3.95, WorkerR=-136.92, EpsM=0.10, EpsW=0.10
# Episode 928/1000, ManagerR=0.88, WorkerR=-115.89, EpsM=0.10, EpsW=0.10
# Episode 929/1000, ManagerR=0.98, WorkerR=-95.73, EpsM=0.10, EpsW=0.10
# Episode 930/1000, ManagerR=0.51, WorkerR=-143.43, EpsM=0.10, EpsW=0.10
# Episode 931/1000, ManagerR=1.19, WorkerR=-113.15, EpsM=0.10, EpsW=0.10
# Episode 932/1000, ManagerR=-4.51, WorkerR=-92.67, EpsM=0.10, EpsW=0.10
# Episode 933/1000, ManagerR=1.00, WorkerR=-108.39, EpsM=0.10, EpsW=0.10
# Episode 934/1000, ManagerR=0.69, WorkerR=-151.72, EpsM=0.10, EpsW=0.10
# Episode 935/1000, ManagerR=1.54, WorkerR=-86.38, EpsM=0.10, EpsW=0.10
# Episode 936/1000, ManagerR=0.81, WorkerR=-110.38, EpsM=0.10, EpsW=0.10
# Episode 937/1000, ManagerR=1.17, WorkerR=-81.31, EpsM=0.10, EpsW=0.10
# Episode 938/1000, ManagerR=-4.28, WorkerR=-122.91, EpsM=0.10, EpsW=0.10
# Episode 939/1000, ManagerR=0.88, WorkerR=-105.29, EpsM=0.10, EpsW=0.10
# Episode 940/1000, ManagerR=0.98, WorkerR=-99.12, EpsM=0.10, EpsW=0.10
# Episode 941/1000, ManagerR=0.42, WorkerR=-122.41, EpsM=0.10, EpsW=0.10
# Episode 942/1000, ManagerR=1.09, WorkerR=-102.06, EpsM=0.10, EpsW=0.10
# Episode 943/1000, ManagerR=-4.59, WorkerR=-36.42, EpsM=0.10, EpsW=0.10
# Episode 944/1000, ManagerR=0.65, WorkerR=-116.86, EpsM=0.10, EpsW=0.10
# Episode 945/1000, ManagerR=-4.12, WorkerR=-88.95, EpsM=0.10, EpsW=0.10
# Episode 946/1000, ManagerR=0.90, WorkerR=-112.93, EpsM=0.10, EpsW=0.10
# Episode 947/1000, ManagerR=1.21, WorkerR=-91.88, EpsM=0.10, EpsW=0.10
# Episode 948/1000, ManagerR=0.92, WorkerR=-115.99, EpsM=0.10, EpsW=0.10
# Episode 949/1000, ManagerR=1.03, WorkerR=-109.65, EpsM=0.10, EpsW=0.10
# Episode 950/1000, ManagerR=0.79, WorkerR=-95.63, EpsM=0.10, EpsW=0.10
# Episode 951/1000, ManagerR=0.75, WorkerR=-125.03, EpsM=0.10, EpsW=0.10
# Episode 952/1000, ManagerR=0.69, WorkerR=-96.12, EpsM=0.10, EpsW=0.10
# Episode 953/1000, ManagerR=0.75, WorkerR=-92.83, EpsM=0.10, EpsW=0.10
# Episode 954/1000, ManagerR=0.62, WorkerR=-116.25, EpsM=0.10, EpsW=0.10
# Episode 955/1000, ManagerR=1.11, WorkerR=-73.43, EpsM=0.10, EpsW=0.10
# Episode 956/1000, ManagerR=0.40, WorkerR=-118.80, EpsM=0.10, EpsW=0.10
# Episode 957/1000, ManagerR=-4.79, WorkerR=-7.44, EpsM=0.10, EpsW=0.10
# Episode 958/1000, ManagerR=-4.36, WorkerR=-47.39, EpsM=0.10, EpsW=0.10
# Episode 959/1000, ManagerR=1.13, WorkerR=-107.50, EpsM=0.10, EpsW=0.10
# Episode 960/1000, ManagerR=-4.69, WorkerR=-11.65, EpsM=0.10, EpsW=0.10
# Episode 961/1000, ManagerR=-4.15, WorkerR=-59.89, EpsM=0.10, EpsW=0.10
# Episode 962/1000, ManagerR=0.84, WorkerR=-72.67, EpsM=0.10, EpsW=0.10
# Episode 963/1000, ManagerR=0.77, WorkerR=-89.10, EpsM=0.10, EpsW=0.10
# Episode 964/1000, ManagerR=-4.46, WorkerR=-100.87, EpsM=0.10, EpsW=0.10
# Episode 965/1000, ManagerR=-4.58, WorkerR=-6.01, EpsM=0.10, EpsW=0.10
# Episode 966/1000, ManagerR=-4.54, WorkerR=-24.97, EpsM=0.10, EpsW=0.10
# Episode 967/1000, ManagerR=-4.06, WorkerR=-50.86, EpsM=0.10, EpsW=0.10
# Episode 968/1000, ManagerR=0.46, WorkerR=-125.90, EpsM=0.10, EpsW=0.10
# Episode 969/1000, ManagerR=1.31, WorkerR=-93.78, EpsM=0.10, EpsW=0.10
# Episode 970/1000, ManagerR=1.19, WorkerR=-68.80, EpsM=0.10, EpsW=0.10
# Episode 971/1000, ManagerR=0.90, WorkerR=-101.36, EpsM=0.10, EpsW=0.10
# Episode 972/1000, ManagerR=-4.06, WorkerR=-68.20, EpsM=0.10, EpsW=0.10
# Episode 973/1000, ManagerR=-4.36, WorkerR=-94.11, EpsM=0.10, EpsW=0.10
# Episode 974/1000, ManagerR=-4.27, WorkerR=-70.96, EpsM=0.10, EpsW=0.10
# Episode 975/1000, ManagerR=0.73, WorkerR=-121.42, EpsM=0.10, EpsW=0.10
# Episode 976/1000, ManagerR=-4.46, WorkerR=-18.31, EpsM=0.10, EpsW=0.10
# Episode 977/1000, ManagerR=-4.54, WorkerR=-15.61, EpsM=0.10, EpsW=0.10
# Episode 978/1000, ManagerR=-4.21, WorkerR=-98.06, EpsM=0.10, EpsW=0.10
# Episode 979/1000, ManagerR=0.71, WorkerR=-97.30, EpsM=0.10, EpsW=0.10
# Episode 980/1000, ManagerR=1.34, WorkerR=-119.94, EpsM=0.10, EpsW=0.10
# Episode 981/1000, ManagerR=1.09, WorkerR=-78.82, EpsM=0.10, EpsW=0.10
# Episode 982/1000, ManagerR=-4.02, WorkerR=-104.10, EpsM=0.10, EpsW=0.10
# Episode 983/1000, ManagerR=-4.06, WorkerR=-95.48, EpsM=0.10, EpsW=0.10
# Episode 984/1000, ManagerR=0.90, WorkerR=-91.10, EpsM=0.10, EpsW=0.10
# Episode 985/1000, ManagerR=-4.81, WorkerR=-8.74, EpsM=0.10, EpsW=0.10
# Episode 986/1000, ManagerR=0.88, WorkerR=-128.57, EpsM=0.10, EpsW=0.10
# Episode 987/1000, ManagerR=-4.64, WorkerR=-18.83, EpsM=0.10, EpsW=0.10
# Episode 988/1000, ManagerR=-4.85, WorkerR=-9.69, EpsM=0.10, EpsW=0.10
# Episode 989/1000, ManagerR=-4.67, WorkerR=-22.56, EpsM=0.10, EpsW=0.10
# Episode 990/1000, ManagerR=0.69, WorkerR=-134.08, EpsM=0.10, EpsW=0.10
# Episode 991/1000, ManagerR=-4.20, WorkerR=-101.15, EpsM=0.10, EpsW=0.10
# Episode 992/1000, ManagerR=0.79, WorkerR=-142.37, EpsM=0.10, EpsW=0.10
# Episode 993/1000, ManagerR=-4.72, WorkerR=-6.25, EpsM=0.10, EpsW=0.10
# Episode 994/1000, ManagerR=-4.82, WorkerR=-9.20, EpsM=0.10, EpsW=0.10
# Episode 995/1000, ManagerR=0.75, WorkerR=-124.21, EpsM=0.10, EpsW=0.10
# Episode 996/1000, ManagerR=-4.33, WorkerR=-58.19, EpsM=0.10, EpsW=0.10
# Episode 997/1000, ManagerR=1.11, WorkerR=-111.60, EpsM=0.10, EpsW=0.10
# Episode 998/1000, ManagerR=1.05, WorkerR=-86.53, EpsM=0.10, EpsW=0.10
# Episode 999/1000, ManagerR=1.34, WorkerR=-80.56, EpsM=0.10, EpsW=0.10
# Episode 1000/1000, ManagerR=0.52, WorkerR=-103.82, EpsM=0.10, EpsW=0.10
# Training complete.
# Demo GIF saved: feudal_milling_demo.gif
# Done.

# %%
#!/usr/bin/env python3
"""
Feudal RL Example (Line-Based Milling):
  - Worker chooses a destination coordinate in [0..grid_size^3-1].
  - We remove stock along the line from the current router position to the target.
    If shape or out-of-bounds is encountered, episode ends immediately in failure.
  - We track:
    - Worker moves (worker_move_count)
    - Fraction of outside stock removed
    - Total outside removed
  - We store separate experiences for Manager and Worker in their own replay buffers.
  - The manager picks subgoals every `manager_update_freq` worker steps.

Usage:
  python feudal_milling.py
Then:
  tensorboard --logdir=runs
"""

import os
import random
import datetime
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from torch.utils.tensorboard import SummaryWriter

########################################################################
# 1) 3D Milling Environment
########################################################################

class Milling3DEnvFeudal:
    """
    3D milling environment for a Feudal RL approach:
      - stock[x,y,z] = 1 => material present, 0 => removed
      - shape[x,y,z] = 1 => protected shape
      - router_pos => current router position in the grid
      - The worker picks an action in [0..grid_size^3 - 1], which we decode
        into (x,y,z). We remove stock along the path from current->target.
        If we encounter shape or out-of-bounds, fail immediately.
      - We track worker_move_count and initial_outside_count, so we can measure
        how many steps before failing/succeeding and how much outside stock was removed.
    """

    def __init__(
        self,
        grid_size=8,
        max_steps=200,
        penalty_cut_shape=10.0,
        reward_outside_cut=1.0,
        success_bonus=30.0,
        step_penalty=0.1,
        min_radius=2,
        max_radius=3
    ):
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.penalty_cut_shape = penalty_cut_shape
        self.reward_outside_cut = reward_outside_cut
        self.success_bonus = success_bonus
        self.step_penalty = step_penalty
        self.min_radius = min_radius
        self.max_radius = max_radius

        self.worker_move_count = 0
        self.initial_outside_count = 0

        # We'll call reset() immediately
        self.reset()

    def reset(self):
        # Create full stock
        self.stock = np.ones((self.grid_size, self.grid_size, self.grid_size), dtype=int)
        # Create shape
        self.shape = np.zeros((self.grid_size, self.grid_size, self.grid_size), dtype=int)

        # Random sphere in the center
        cx = self.grid_size // 2
        cy = self.grid_size // 2
        cz = self.grid_size // 2
        r = np.random.randint(self.min_radius, self.max_radius+1)
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                for z in range(self.grid_size):
                    dist_sq = (x - cx)**2 + (y - cy)**2 + (z - cz)**2
                    if dist_sq <= r**2:
                        self.shape[x,y,z] = 1

        self.router_pos = np.array([0,0,0], dtype=int)
        self.steps_taken = 0
        self.done = False
        self.worker_move_count = 0

        # manager subgoal for demonstration
        self.subgoal = np.array([cx, cy, cz], dtype=int)

        # track how many outside voxels we start with
        outside_mask = (self.shape == 0)
        self.initial_outside_count = np.sum(outside_mask)

        # Return manager obs, worker obs
        return self._get_manager_obs(), self._get_worker_obs()

    def set_subgoal(self, subgoal):
        """
        Called by the manager. We clamp it in [0..grid_size-1].
        """
        subgoal = np.clip(subgoal, 0, self.grid_size-1)
        self.subgoal = subgoal.astype(int)

    def worker_step(self, action_idx):
        """
        Worker picks an action in [0..grid_size^3 -1].
        We decode it => (x,y,z). Then we remove stock along the line from router_pos
        to (x,y,z). If shape or out-of-bounds is encountered, fail immediately.
        """
        if self.done:
            return self._get_worker_obs(), 0.0, True

        # Decode
        z = action_idx % self.grid_size
        y = (action_idx // self.grid_size) % self.grid_size
        x = (action_idx // (self.grid_size*self.grid_size)) % self.grid_size
        target_pos = np.array([x,y,z], dtype=int)

        path_voxels = line_3d_voxels(self.router_pos, target_pos)

        total_reward = 0.0
        failed = False

        for vx, vy, vz in path_voxels:
            # check out-of-bounds
            if not np.all((vx >= 0) & (vx < self.grid_size)):
                total_reward -= 999.0  # big penalty
                failed = True
                break
            # check shape
            if self.shape[vx,vy,vz] == 1:
                total_reward -= self.penalty_cut_shape
                failed = True
                break
            # remove stock if present
            if self.stock[vx,vy,vz] == 1:
                self.stock[vx,vy,vz] = 0
                total_reward += self.reward_outside_cut

            # small penalty for each voxel traversed
            total_reward -= self.step_penalty

        if not failed:
            # successfully moved to target
            self.router_pos = target_pos

            # check if all outside is removed
            outside_mask = (self.shape == 0)
            if np.sum(self.stock[outside_mask]) == 0:
                total_reward += self.success_bonus
                failed = True  # success end

        # negative distance to subgoal
        dist = np.linalg.norm(self.router_pos - self.subgoal)
        total_reward -= 0.1 * dist

        self.steps_taken += 1
        self.worker_move_count += 1

        if self.steps_taken >= self.max_steps:
            failed = True

        if failed:
            self.done = True

        return self._get_worker_obs(), total_reward, self.done

    def manager_reward(self):
        """
        Example manager reward: fraction outside removed vs. shape cut
        """
        shape_cut = (self.shape == 1) & (self.stock == 0)
        cut_count = np.sum(shape_cut)

        outside_mask = (self.shape == 0)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_outside_removed = outside_removed / (outside_total + 1e-8)

        r = 10.0 * frac_outside_removed - 5.0 * cut_count
        return r

    def manager_done(self):
        return self.done

    def fraction_outside_removed(self):
        """
        fraction of outside stock removed
        """
        outside_mask = (self.shape == 0)
        current_outside = np.sum(self.stock[outside_mask])
        removed = self.initial_outside_count - current_outside
        return removed / (self.initial_outside_count + 1e-8)

    def total_outside_removed(self):
        """
        returns how many outside voxels have been removed
        """
        outside_mask = (self.shape == 0)
        current_outside = np.sum(self.stock[outside_mask])
        removed = self.initial_outside_count - current_outside
        return removed

    def _get_manager_obs(self):
        """
        Manager sees the entire stock+shape plus router coords, flattened.
        """
        stock_f = self.stock.flatten().astype(np.float32)
        shape_f = self.shape.flatten().astype(np.float32)
        router_f = self.router_pos.astype(np.float32)
        return np.concatenate([stock_f, shape_f, router_f], axis=0)

    def _get_worker_obs(self):
        """
        Worker sees the entire stock+shape plus router coords & subgoal, flattened.
        """
        stock_f = self.stock.flatten().astype(np.float32)
        shape_f = self.shape.flatten().astype(np.float32)
        router_f = self.router_pos.astype(np.float32)
        subgoal_f = self.subgoal.astype(np.float32)
        return np.concatenate([stock_f, shape_f, router_f, subgoal_f], axis=0)


def line_3d_voxels(start, end):
    """
    Return a list of voxel coords in the line from start->end (3D).
    A naive float stepping approach to approximate a Bresenham path.
    """
    s = start.astype(float)
    e = end.astype(float)
    diff = e - s
    length = int(np.linalg.norm(diff))
    if length == 0:
        return [tuple(start)]
    steps = max(1, length*2)
    out = []
    for i in range(steps+1):
        t = i / steps
        p = s + diff * t
        coords = np.round(p).astype(int)
        out.append(tuple(coords))
    # deduplicate
    uniq = []
    seen = set()
    for c in out:
        if c not in seen:
            seen.add(c)
            uniq.append(c)
    return uniq

########################################################################
# 2) Manager & Worker Networks + Replay
########################################################################

class ManagerNet(nn.Module):
    def __init__(self, input_dim, grid_size=8, hidden_dim=256):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    def forward(self, x):
        return self.net(x)

class WorkerNet(nn.Module):
    def __init__(self, input_dim, grid_size=8, hidden_dim=256):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    def forward(self, x):
        return self.net(x)

class ManagerReplayBuffer:
    def __init__(self, capacity=50000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s, a, r, s_next, done):
        self.buffer.append((s, a, r, s_next, done))
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s,a,r,s_next,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(s_next), np.array(d)
    def __len__(self):
        return len(self.buffer)

class WorkerReplayBuffer:
    def __init__(self, capacity=50000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s, a, r, s_next, done):
        self.buffer.append((s, a, r, s_next, done))
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s,a,r,s_next,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(s_next), np.array(d)
    def __len__(self):
        return len(self.buffer)

########################################################################
# 3) Action Selection and Update Functions
########################################################################

def manager_select_subgoal(manager_net, manager_state, grid_size, epsilon=0.1):
    """
    Epsilon-greedy subgoal selection in [0..grid_size^3 - 1].
    """
    if random.random() < epsilon:
        subgoal_id = random.randint(0, grid_size**3 - 1)
    else:
        with torch.no_grad():
            inp = torch.FloatTensor(manager_state).unsqueeze(0)
            logits = manager_net(inp)  # shape [1, grid_size^3]
            subgoal_id = logits.argmax(dim=1).item()
    # decode subgoal_id -> (x,y,z)
    z = subgoal_id % grid_size
    y = (subgoal_id // grid_size) % grid_size
    x = (subgoal_id // (grid_size*grid_size)) % grid_size
    return subgoal_id, (x,y,z)

def worker_select_action(worker_net, worker_state, n_actions, epsilon=0.1):
    """
    Epsilon-greedy for the worker's coordinate choice in [0..grid_size^3-1].
    """
    if random.random() < epsilon:
        return random.randint(0, n_actions-1)
    else:
        with torch.no_grad():
            inp = torch.FloatTensor(worker_state).unsqueeze(0)
            logits = worker_net(inp)  # shape [1, n_actions]
            return logits.argmax(dim=1).item()

def manager_update(net, optimizer, replay, batch_size, gamma=0.9):
    if len(replay) < batch_size:
        return
    s, a, r, s_next, d = replay.sample(batch_size)
    s_t = torch.FloatTensor(s)
    a_t = torch.LongTensor(a)
    r_t = torch.FloatTensor(r)
    s_next_t = torch.FloatTensor(s_next)
    d_t = torch.BoolTensor(d)

    logits = net(s_t)  # shape [batch, grid_size^3]
    q_s_a = logits.gather(1, a_t.unsqueeze(1)).squeeze(1)

    with torch.no_grad():
        logits_next = net(s_next_t)
        max_q_next,_ = torch.max(logits_next, dim=1)
        max_q_next[d_t] = 0.0
    target = r_t + gamma * max_q_next

    loss = nn.MSELoss()(q_s_a, target)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

def worker_update(net, optimizer, replay, batch_size, gamma=0.9, n_actions=8**3):
    if len(replay) < batch_size:
        return
    s, a, r, s_next, d = replay.sample(batch_size)
    s_t = torch.FloatTensor(s)
    a_t = torch.LongTensor(a)
    r_t = torch.FloatTensor(r)
    s_next_t = torch.FloatTensor(s_next)
    d_t = torch.BoolTensor(d)

    logits = net(s_t)  # [batch, n_actions]
    q_s_a = logits.gather(1, a_t.unsqueeze(1)).squeeze(1)

    with torch.no_grad():
        logits_next = net(s_next_t)
        max_q_next,_ = torch.max(logits_next, dim=1)
        max_q_next[d_t] = 0.0
    target = r_t + gamma * max_q_next

    loss = nn.MSELoss()(q_s_a, target)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

########################################################################
# 4) Main Training Loop
########################################################################

def train_feudal_milling(
    num_episodes=50,
    grid_size=8,
    manager_update_freq=10,
    lr_manager=1e-3,
    lr_worker=1e-3,
    batch_size=32,
    manager_gamma=0.9,
    worker_gamma=0.9,
    manager_eps_start=1.0,
    manager_eps_end=0.1,
    manager_eps_decay=0.995,
    worker_eps_start=1.0,
    worker_eps_end=0.1,
    worker_eps_decay=0.995
):
    log_dir = os.path.join("runs", f"feudal_milling_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}")
    writer = SummaryWriter(log_dir=log_dir)

    # Create environment and get observation dims
    env = Milling3DEnvFeudal(grid_size=grid_size)
    manager_in_dim = env._get_manager_obs().shape[0]
    worker_in_dim = env._get_worker_obs().shape[0]

    # Networks
    manager_net = ManagerNet(manager_in_dim, grid_size=grid_size)
    worker_net = WorkerNet(worker_in_dim, grid_size=grid_size)

    # Optimizers
    manager_opt = optim.Adam(manager_net.parameters(), lr=lr_manager)
    worker_opt = optim.Adam(worker_net.parameters(), lr=lr_worker)

    # Replay Buffers
    manager_replay = ManagerReplayBuffer()
    worker_replay = WorkerReplayBuffer()

    # Epsilons
    manager_eps = manager_eps_start
    worker_eps = worker_eps_start

    for ep in range(num_episodes):
        m_obs, w_obs = env.reset()
        done = False
        manager_return = 0.0
        worker_return = 0.0

        old_mgr_r = env.manager_reward()
        sg_id, sg_xyz = manager_select_subgoal(manager_net, m_obs, grid_size, epsilon=manager_eps)
        env.set_subgoal(np.array(sg_xyz))

        while not done:
            manager_s = m_obs

            # run T worker steps
            for _ in range(manager_update_freq):
                if env.done:
                    break
                w_s = w_obs
                action_worker = worker_select_action(worker_net, w_s, env.grid_size**3, worker_eps)
                w_s_next, w_r, w_done = env.worker_step(action_worker)
                w_obs = w_s_next
                worker_return += w_r
                done = w_done

                # store worker experience
                worker_replay.push(w_s, action_worker, w_r, w_s_next, w_done)
                worker_update(worker_net, worker_opt, worker_replay, batch_size, gamma=worker_gamma)

                if done:
                    break

            m_obs_next = env._get_manager_obs()
            new_mgr_r = env.manager_reward()
            delta_r = new_mgr_r - old_mgr_r
            old_mgr_r = new_mgr_r
            manager_return += delta_r

            m_done = env.manager_done()
            done = m_done

            manager_replay.push(manager_s, sg_id, delta_r, m_obs_next, m_done)
            manager_update(manager_net, manager_opt, manager_replay, batch_size, gamma=manager_gamma)

            m_obs = m_obs_next

            if not done:
                sg_id, sg_xyz = manager_select_subgoal(manager_net, m_obs, grid_size, epsilon=manager_eps)
                env.set_subgoal(np.array(sg_xyz))

        # Episode end: update eps
        manager_eps = max(manager_eps_end, manager_eps * manager_eps_decay)
        worker_eps = max(worker_eps_end, worker_eps * worker_eps_decay)

        total_return = manager_return + worker_return
        frac_removed = env.fraction_outside_removed()
        total_removed = env.total_outside_removed()
        moves_before_end = env.worker_move_count

        # Log to TensorBoard
        writer.add_scalar("Episode/ManagerReturn", manager_return, ep)
        writer.add_scalar("Episode/WorkerReturn", worker_return, ep)
        writer.add_scalar("Episode/TotalReturn", total_return, ep)
        writer.add_scalar("Episode/OutsideRemovedFraction", frac_removed, ep)
        writer.add_scalar("Episode/OutsideRemovedCount", total_removed, ep)
        writer.add_scalar("Episode/WorkerMovesBeforeEnd", moves_before_end, ep)
        writer.add_scalar("Epsilon/Manager", manager_eps, ep)
        writer.add_scalar("Epsilon/Worker", worker_eps, ep)

        print(f"[Ep {ep+1}/{num_episodes}] "
              f"ManagerR={manager_return:.2f}, WorkerR={worker_return:.2f}, "
              f"Total={total_return:.2f}, Moves={moves_before_end}, "
              f"FracRemoved={frac_removed:.3f}, RemovedCount={total_removed}, "
              f"EpsM={manager_eps:.2f}, EpsW={worker_eps:.2f}")

    writer.close()
    print("Training complete.")
    return manager_net, worker_net

def main():
    train_feudal_milling(num_episodes=100000, grid_size=8)
    print("Done.")

if __name__ == "__main__":
    main()
# Out:
# [Ep 1/100000] ManagerR=0.39, WorkerR=1.47, Total=1.85, Moves=4, FracRemoved=0.039, RemovedCount=15, EpsM=0.99, EpsW=0.99
# [Ep 2/100000] ManagerR=0.15, WorkerR=-5.03, Total=-4.89, Moves=2, FracRemoved=0.015, RemovedCount=7, EpsM=0.99, EpsW=0.99
# [Ep 3/100000] ManagerR=0.21, WorkerR=-3.50, Total=-3.29, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.99, EpsW=0.99
# [Ep 4/100000] ManagerR=0.15, WorkerR=-4.60, Total=-4.45, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.98, EpsW=0.98
# [Ep 5/100000] ManagerR=0.13, WorkerR=-5.94, Total=-5.81, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.98, EpsW=0.98
# [Ep 6/100000] ManagerR=0.13, WorkerR=-5.55, Total=-5.42, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.97, EpsW=0.97
# [Ep 7/100000] ManagerR=0.52, WorkerR=8.60, Total=9.12, Moves=7, FracRemoved=0.052, RemovedCount=25, EpsM=0.97, EpsW=0.97
# [Ep 8/100000] ManagerR=0.19, WorkerR=-2.75, Total=-2.57, Moves=1, FracRemoved=0.019, RemovedCount=9, EpsM=0.96, EpsW=0.96
# [Ep 9/100000] ManagerR=0.28, WorkerR=-2.95, Total=-2.67, Moves=4, FracRemoved=0.028, RemovedCount=11, EpsM=0.96, EpsW=0.96
# [Ep 10/100000] ManagerR=0.29, WorkerR=0.84, Total=1.13, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.95, EpsW=0.95
# [Ep 11/100000] ManagerR=0.23, WorkerR=-2.60, Total=-2.37, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.95, EpsW=0.95
# [Ep 12/100000] ManagerR=0.17, WorkerR=-3.39, Total=-3.22, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.94, EpsW=0.94
# [Ep 13/100000] ManagerR=0.27, WorkerR=1.01, Total=1.28, Moves=2, FracRemoved=0.027, RemovedCount=13, EpsM=0.94, EpsW=0.94
# [Ep 14/100000] ManagerR=0.21, WorkerR=-3.29, Total=-3.08, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.93, EpsW=0.93
# [Ep 15/100000] ManagerR=0.15, WorkerR=-5.04, Total=-4.88, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.93, EpsW=0.93
# [Ep 16/100000] ManagerR=0.29, WorkerR=2.05, Total=2.35, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.92, EpsW=0.92
# [Ep 17/100000] ManagerR=0.17, WorkerR=-3.61, Total=-3.45, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.92, EpsW=0.92
# [Ep 18/100000] ManagerR=0.15, WorkerR=-5.37, Total=-5.21, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.91, EpsW=0.91
# [Ep 19/100000] ManagerR=0.88, WorkerR=20.74, Total=21.61, Moves=9, FracRemoved=0.088, RemovedCount=42, EpsM=0.91, EpsW=0.91
# [Ep 20/100000] ManagerR=0.17, WorkerR=-3.53, Total=-3.37, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.90, EpsW=0.90
# [Ep 21/100000] ManagerR=0.35, WorkerR=3.03, Total=3.38, Moves=3, FracRemoved=0.035, RemovedCount=17, EpsM=0.90, EpsW=0.90
# [Ep 22/100000] ManagerR=0.65, WorkerR=12.32, Total=12.96, Moves=7, FracRemoved=0.065, RemovedCount=31, EpsM=0.90, EpsW=0.90
# [Ep 23/100000] ManagerR=0.15, WorkerR=-3.90, Total=-3.75, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.89, EpsW=0.89
# [Ep 24/100000] ManagerR=0.50, WorkerR=8.11, Total=8.61, Moves=7, FracRemoved=0.050, RemovedCount=24, EpsM=0.89, EpsW=0.89
# [Ep 25/100000] ManagerR=0.21, WorkerR=-3.88, Total=-3.67, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.88, EpsW=0.88
# [Ep 26/100000] ManagerR=0.23, WorkerR=-3.56, Total=-3.32, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.88, EpsW=0.88
# [Ep 27/100000] ManagerR=0.23, WorkerR=-2.16, Total=-1.93, Moves=4, FracRemoved=0.023, RemovedCount=11, EpsM=0.87, EpsW=0.87
# [Ep 28/100000] ManagerR=0.23, WorkerR=-2.72, Total=-2.49, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.87, EpsW=0.87
# [Ep 29/100000] ManagerR=0.15, WorkerR=-3.92, Total=-3.78, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.86, EpsW=0.86
# [Ep 30/100000] ManagerR=0.50, WorkerR=8.15, Total=8.65, Moves=5, FracRemoved=0.050, RemovedCount=24, EpsM=0.86, EpsW=0.86
# [Ep 31/100000] ManagerR=0.10, WorkerR=-7.26, Total=-7.16, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.86, EpsW=0.86
# [Ep 32/100000] ManagerR=0.15, WorkerR=-4.56, Total=-4.41, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.85, EpsW=0.85
# [Ep 33/100000] ManagerR=0.21, WorkerR=-2.51, Total=-2.31, Moves=2, FracRemoved=0.021, RemovedCount=10, EpsM=0.85, EpsW=0.85
# [Ep 34/100000] ManagerR=0.17, WorkerR=-3.66, Total=-3.49, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.84, EpsW=0.84
# [Ep 35/100000] ManagerR=0.13, WorkerR=-6.25, Total=-6.12, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.84, EpsW=0.84
# [Ep 36/100000] ManagerR=0.15, WorkerR=-5.93, Total=-5.78, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.83, EpsW=0.83
# [Ep 37/100000] ManagerR=0.18, WorkerR=-4.64, Total=-4.46, Moves=1, FracRemoved=0.018, RemovedCount=7, EpsM=0.83, EpsW=0.83
# [Ep 38/100000] ManagerR=0.58, WorkerR=10.75, Total=11.34, Moves=7, FracRemoved=0.058, RemovedCount=28, EpsM=0.83, EpsW=0.83
# [Ep 39/100000] ManagerR=0.52, WorkerR=9.19, Total=9.71, Moves=5, FracRemoved=0.052, RemovedCount=25, EpsM=0.82, EpsW=0.82
# [Ep 40/100000] ManagerR=0.21, WorkerR=-3.82, Total=-3.61, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.82, EpsW=0.82
# [Ep 41/100000] ManagerR=0.13, WorkerR=-5.86, Total=-5.73, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.81, EpsW=0.81
# [Ep 42/100000] ManagerR=0.65, WorkerR=15.36, Total=16.01, Moves=4, FracRemoved=0.065, RemovedCount=31, EpsM=0.81, EpsW=0.81
# [Ep 43/100000] ManagerR=0.54, WorkerR=10.18, Total=10.73, Moves=4, FracRemoved=0.054, RemovedCount=26, EpsM=0.81, EpsW=0.81
# [Ep 44/100000] ManagerR=0.46, WorkerR=6.32, Total=6.78, Moves=6, FracRemoved=0.046, RemovedCount=22, EpsM=0.80, EpsW=0.80
# [Ep 45/100000] ManagerR=0.21, WorkerR=-2.56, Total=-2.35, Moves=2, FracRemoved=0.021, RemovedCount=10, EpsM=0.80, EpsW=0.80
# [Ep 46/100000] ManagerR=0.29, WorkerR=0.76, Total=1.05, Moves=3, FracRemoved=0.029, RemovedCount=14, EpsM=0.79, EpsW=0.79
# [Ep 47/100000] ManagerR=0.15, WorkerR=-4.53, Total=-4.38, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.79, EpsW=0.79
# [Ep 48/100000] ManagerR=0.90, WorkerR=16.91, Total=17.81, Moves=7, FracRemoved=0.090, RemovedCount=35, EpsM=0.79, EpsW=0.79
# [Ep 49/100000] ManagerR=0.15, WorkerR=-5.26, Total=-5.10, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.78, EpsW=0.78
# [Ep 50/100000] ManagerR=0.15, WorkerR=-5.93, Total=-5.78, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.78, EpsW=0.78
# [Ep 51/100000] ManagerR=0.15, WorkerR=-4.34, Total=-4.19, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.77, EpsW=0.77
# [Ep 52/100000] ManagerR=0.49, WorkerR=3.23, Total=3.72, Moves=4, FracRemoved=0.049, RemovedCount=19, EpsM=0.77, EpsW=0.77
# [Ep 53/100000] ManagerR=0.21, WorkerR=-3.50, Total=-3.29, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.77, EpsW=0.77
# [Ep 54/100000] ManagerR=0.18, WorkerR=-4.43, Total=-4.25, Moves=2, FracRemoved=0.018, RemovedCount=7, EpsM=0.76, EpsW=0.76
# [Ep 55/100000] ManagerR=0.15, WorkerR=-5.61, Total=-5.46, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.76, EpsW=0.76
# [Ep 56/100000] ManagerR=0.38, WorkerR=3.87, Total=4.25, Moves=5, FracRemoved=0.038, RemovedCount=18, EpsM=0.76, EpsW=0.76
# [Ep 57/100000] ManagerR=0.28, WorkerR=-0.80, Total=-0.52, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.75, EpsW=0.75
# [Ep 58/100000] ManagerR=0.15, WorkerR=-5.27, Total=-5.12, Moves=2, FracRemoved=0.015, RemovedCount=7, EpsM=0.75, EpsW=0.75
# [Ep 59/100000] ManagerR=0.31, WorkerR=-1.02, Total=-0.71, Moves=2, FracRemoved=0.031, RemovedCount=12, EpsM=0.74, EpsW=0.74
# [Ep 60/100000] ManagerR=0.46, WorkerR=7.01, Total=7.47, Moves=5, FracRemoved=0.046, RemovedCount=22, EpsM=0.74, EpsW=0.74
# [Ep 61/100000] ManagerR=0.21, WorkerR=-3.61, Total=-3.40, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.74, EpsW=0.74
# [Ep 62/100000] ManagerR=0.19, WorkerR=-2.54, Total=-2.35, Moves=1, FracRemoved=0.019, RemovedCount=9, EpsM=0.73, EpsW=0.73
# [Ep 63/100000] ManagerR=0.31, WorkerR=-0.96, Total=-0.65, Moves=2, FracRemoved=0.031, RemovedCount=12, EpsM=0.73, EpsW=0.73
# [Ep 64/100000] ManagerR=1.29, WorkerR=33.81, Total=35.10, Moves=15, FracRemoved=0.129, RemovedCount=62, EpsM=0.73, EpsW=0.73
# [Ep 65/100000] ManagerR=0.31, WorkerR=1.90, Total=2.21, Moves=3, FracRemoved=0.031, RemovedCount=15, EpsM=0.72, EpsW=0.72
# [Ep 66/100000] ManagerR=0.13, WorkerR=-6.01, Total=-5.88, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.72, EpsW=0.72
# [Ep 67/100000] ManagerR=0.10, WorkerR=-7.12, Total=-7.02, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.71, EpsW=0.71
# [Ep 68/100000] ManagerR=0.21, WorkerR=-3.61, Total=-3.40, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.71, EpsW=0.71
# [Ep 69/100000] ManagerR=0.79, WorkerR=20.24, Total=21.03, Moves=7, FracRemoved=0.079, RemovedCount=38, EpsM=0.71, EpsW=0.71
# [Ep 70/100000] ManagerR=0.25, WorkerR=-0.03, Total=0.22, Moves=2, FracRemoved=0.025, RemovedCount=12, EpsM=0.70, EpsW=0.70
# [Ep 71/100000] ManagerR=0.28, WorkerR=-0.65, Total=-0.36, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.70, EpsW=0.70
# [Ep 72/100000] ManagerR=0.15, WorkerR=-4.29, Total=-4.15, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.70, EpsW=0.70
# [Ep 73/100000] ManagerR=0.13, WorkerR=-5.96, Total=-5.83, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.69, EpsW=0.69
# [Ep 74/100000] ManagerR=0.81, WorkerR=19.32, Total=20.13, Moves=7, FracRemoved=0.081, RemovedCount=39, EpsM=0.69, EpsW=0.69
# [Ep 75/100000] ManagerR=0.15, WorkerR=-4.11, Total=-3.97, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.69, EpsW=0.69
# [Ep 76/100000] ManagerR=0.18, WorkerR=-4.41, Total=-4.23, Moves=1, FracRemoved=0.018, RemovedCount=7, EpsM=0.68, EpsW=0.68
# [Ep 77/100000] ManagerR=0.52, WorkerR=10.59, Total=11.11, Moves=4, FracRemoved=0.052, RemovedCount=25, EpsM=0.68, EpsW=0.68
# [Ep 78/100000] ManagerR=0.27, WorkerR=-0.16, Total=0.12, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.68, EpsW=0.68
# [Ep 79/100000] ManagerR=0.17, WorkerR=-3.44, Total=-3.27, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.67, EpsW=0.67
# [Ep 80/100000] ManagerR=0.17, WorkerR=-3.74, Total=-3.57, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.67, EpsW=0.67
# [Ep 81/100000] ManagerR=0.17, WorkerR=-3.59, Total=-3.42, Moves=1, FracRemoved=0.017, RemovedCount=8, EpsM=0.67, EpsW=0.67
# [Ep 82/100000] ManagerR=0.13, WorkerR=-6.38, Total=-6.25, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.66, EpsW=0.66
# [Ep 83/100000] ManagerR=0.15, WorkerR=-6.04, Total=-5.89, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.66, EpsW=0.66
# [Ep 84/100000] ManagerR=0.38, WorkerR=4.60, Total=4.97, Moves=3, FracRemoved=0.038, RemovedCount=18, EpsM=0.66, EpsW=0.66
# [Ep 85/100000] ManagerR=0.13, WorkerR=-5.19, Total=-5.07, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.65, EpsW=0.65
# [Ep 86/100000] ManagerR=0.13, WorkerR=-5.80, Total=-5.67, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.65, EpsW=0.65
# [Ep 87/100000] ManagerR=0.36, WorkerR=1.20, Total=1.56, Moves=2, FracRemoved=0.036, RemovedCount=14, EpsM=0.65, EpsW=0.65
# [Ep 88/100000] ManagerR=0.23, WorkerR=-2.63, Total=-2.40, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.64, EpsW=0.64
# [Ep 89/100000] ManagerR=0.15, WorkerR=-6.36, Total=-6.21, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.64, EpsW=0.64
# [Ep 90/100000] ManagerR=0.23, WorkerR=-1.66, Total=-1.43, Moves=2, FracRemoved=0.023, RemovedCount=11, EpsM=0.64, EpsW=0.64
# [Ep 91/100000] ManagerR=0.42, WorkerR=5.16, Total=5.58, Moves=3, FracRemoved=0.042, RemovedCount=20, EpsM=0.63, EpsW=0.63
# [Ep 92/100000] ManagerR=0.13, WorkerR=-6.36, Total=-6.23, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.63, EpsW=0.63
# [Ep 93/100000] ManagerR=0.13, WorkerR=-5.31, Total=-5.18, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.63, EpsW=0.63
# [Ep 94/100000] ManagerR=0.23, WorkerR=-2.43, Total=-2.20, Moves=3, FracRemoved=0.023, RemovedCount=11, EpsM=0.62, EpsW=0.62
# [Ep 95/100000] ManagerR=0.10, WorkerR=-6.91, Total=-6.81, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.62, EpsW=0.62
# [Ep 96/100000] ManagerR=0.36, WorkerR=0.32, Total=0.68, Moves=3, FracRemoved=0.036, RemovedCount=14, EpsM=0.62, EpsW=0.62
# [Ep 97/100000] ManagerR=0.57, WorkerR=6.14, Total=6.71, Moves=5, FracRemoved=0.057, RemovedCount=22, EpsM=0.61, EpsW=0.61
# [Ep 98/100000] ManagerR=0.29, WorkerR=0.50, Total=0.79, Moves=3, FracRemoved=0.029, RemovedCount=14, EpsM=0.61, EpsW=0.61
# [Ep 99/100000] ManagerR=0.15, WorkerR=-5.20, Total=-5.05, Moves=2, FracRemoved=0.015, RemovedCount=7, EpsM=0.61, EpsW=0.61
# [Ep 100/100000] ManagerR=0.17, WorkerR=-3.35, Total=-3.18, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.61, EpsW=0.61
# [Ep 101/100000] ManagerR=0.23, WorkerR=-5.57, Total=-5.34, Moves=3, FracRemoved=0.023, RemovedCount=9, EpsM=0.60, EpsW=0.60
# [Ep 102/100000] ManagerR=0.15, WorkerR=-5.88, Total=-5.73, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.60, EpsW=0.60
# [Ep 103/100000] ManagerR=0.18, WorkerR=-4.88, Total=-4.70, Moves=2, FracRemoved=0.018, RemovedCount=7, EpsM=0.60, EpsW=0.60
# [Ep 104/100000] ManagerR=0.27, WorkerR=0.69, Total=0.97, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.59, EpsW=0.59
# [Ep 105/100000] ManagerR=0.33, WorkerR=-2.97, Total=-2.64, Moves=7, FracRemoved=0.033, RemovedCount=13, EpsM=0.59, EpsW=0.59
# [Ep 106/100000] ManagerR=0.38, WorkerR=3.13, Total=3.50, Moves=5, FracRemoved=0.038, RemovedCount=18, EpsM=0.59, EpsW=0.59
# [Ep 107/100000] ManagerR=0.63, WorkerR=12.38, Total=13.01, Moves=7, FracRemoved=0.063, RemovedCount=30, EpsM=0.58, EpsW=0.58
# [Ep 108/100000] ManagerR=0.26, WorkerR=-2.60, Total=-2.34, Moves=2, FracRemoved=0.026, RemovedCount=10, EpsM=0.58, EpsW=0.58
# [Ep 109/100000] ManagerR=0.13, WorkerR=-6.31, Total=-6.18, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.58, EpsW=0.58
# [Ep 110/100000] ManagerR=0.33, WorkerR=1.20, Total=1.54, Moves=5, FracRemoved=0.033, RemovedCount=16, EpsM=0.58, EpsW=0.58
# [Ep 111/100000] ManagerR=0.23, WorkerR=-5.35, Total=-5.12, Moves=4, FracRemoved=0.023, RemovedCount=9, EpsM=0.57, EpsW=0.57
# [Ep 112/100000] ManagerR=0.23, WorkerR=-2.66, Total=-2.43, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.57, EpsW=0.57
# [Ep 113/100000] ManagerR=0.48, WorkerR=1.63, Total=2.11, Moves=10, FracRemoved=0.048, RemovedCount=23, EpsM=0.57, EpsW=0.57
# [Ep 114/100000] ManagerR=0.28, WorkerR=-1.24, Total=-0.96, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.56, EpsW=0.56
# [Ep 115/100000] ManagerR=0.18, WorkerR=-5.43, Total=-5.25, Moves=3, FracRemoved=0.018, RemovedCount=7, EpsM=0.56, EpsW=0.56
# [Ep 116/100000] ManagerR=0.18, WorkerR=-5.43, Total=-5.25, Moves=3, FracRemoved=0.018, RemovedCount=7, EpsM=0.56, EpsW=0.56
# [Ep 117/100000] ManagerR=0.59, WorkerR=4.64, Total=5.23, Moves=10, FracRemoved=0.059, RemovedCount=23, EpsM=0.56, EpsW=0.56
# [Ep 118/100000] ManagerR=0.15, WorkerR=-5.42, Total=-5.26, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.55, EpsW=0.55
# [Ep 119/100000] ManagerR=0.15, WorkerR=-4.11, Total=-3.97, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.55, EpsW=0.55
# [Ep 120/100000] ManagerR=0.13, WorkerR=-6.32, Total=-6.19, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.55, EpsW=0.55
# [Ep 121/100000] ManagerR=0.13, WorkerR=-6.96, Total=-6.83, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.55, EpsW=0.55
# [Ep 122/100000] ManagerR=0.21, WorkerR=-4.07, Total=-3.86, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.54, EpsW=0.54
# [Ep 123/100000] ManagerR=0.15, WorkerR=-5.11, Total=-4.96, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.54, EpsW=0.54
# [Ep 124/100000] ManagerR=0.28, WorkerR=-2.33, Total=-2.05, Moves=3, FracRemoved=0.028, RemovedCount=11, EpsM=0.54, EpsW=0.54
# [Ep 125/100000] ManagerR=0.31, WorkerR=-1.24, Total=-0.93, Moves=2, FracRemoved=0.031, RemovedCount=12, EpsM=0.53, EpsW=0.53
# [Ep 126/100000] ManagerR=0.15, WorkerR=-4.24, Total=-4.09, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.53, EpsW=0.53
# [Ep 127/100000] ManagerR=0.15, WorkerR=-4.43, Total=-4.28, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.53, EpsW=0.53
# [Ep 128/100000] ManagerR=0.13, WorkerR=-6.01, Total=-5.88, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.53, EpsW=0.53
# [Ep 129/100000] ManagerR=0.33, WorkerR=0.14, Total=0.48, Moves=2, FracRemoved=0.033, RemovedCount=13, EpsM=0.52, EpsW=0.52
# [Ep 130/100000] ManagerR=0.13, WorkerR=-5.48, Total=-5.35, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.52, EpsW=0.52
# [Ep 131/100000] ManagerR=0.28, WorkerR=-2.44, Total=-2.15, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.52, EpsW=0.52
# [Ep 132/100000] ManagerR=0.94, WorkerR=20.46, Total=21.39, Moves=12, FracRemoved=0.094, RemovedCount=45, EpsM=0.52, EpsW=0.52
# [Ep 133/100000] ManagerR=0.21, WorkerR=-3.98, Total=-3.77, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.51, EpsW=0.51
# [Ep 134/100000] ManagerR=0.21, WorkerR=-3.61, Total=-3.40, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.51, EpsW=0.51
# [Ep 135/100000] ManagerR=0.25, WorkerR=0.30, Total=0.55, Moves=2, FracRemoved=0.025, RemovedCount=12, EpsM=0.51, EpsW=0.51
# [Ep 136/100000] ManagerR=0.15, WorkerR=-5.41, Total=-5.25, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.51, EpsW=0.51
# [Ep 137/100000] ManagerR=0.13, WorkerR=-6.31, Total=-6.18, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.50, EpsW=0.50
# [Ep 138/100000] ManagerR=0.33, WorkerR=-0.59, Total=-0.25, Moves=3, FracRemoved=0.033, RemovedCount=13, EpsM=0.50, EpsW=0.50
# [Ep 139/100000] ManagerR=0.13, WorkerR=-6.77, Total=-6.64, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.50, EpsW=0.50
# [Ep 140/100000] ManagerR=0.26, WorkerR=-2.98, Total=-2.73, Moves=3, FracRemoved=0.026, RemovedCount=10, EpsM=0.50, EpsW=0.50
# [Ep 141/100000] ManagerR=0.33, WorkerR=-0.98, Total=-0.64, Moves=3, FracRemoved=0.033, RemovedCount=13, EpsM=0.49, EpsW=0.49
# [Ep 142/100000] ManagerR=0.65, WorkerR=10.02, Total=10.67, Moves=11, FracRemoved=0.065, RemovedCount=31, EpsM=0.49, EpsW=0.49
# [Ep 143/100000] ManagerR=0.27, WorkerR=0.75, Total=1.02, Moves=2, FracRemoved=0.027, RemovedCount=13, EpsM=0.49, EpsW=0.49
# [Ep 144/100000] ManagerR=0.27, WorkerR=-0.09, Total=0.19, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.49, EpsW=0.49
# [Ep 145/100000] ManagerR=0.38, WorkerR=0.17, Total=0.55, Moves=8, FracRemoved=0.038, RemovedCount=18, EpsM=0.48, EpsW=0.48
# [Ep 146/100000] ManagerR=0.21, WorkerR=-3.72, Total=-3.52, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.48, EpsW=0.48
# [Ep 147/100000] ManagerR=0.13, WorkerR=-6.27, Total=-6.14, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.48, EpsW=0.48
# [Ep 148/100000] ManagerR=0.90, WorkerR=17.51, Total=18.41, Moves=14, FracRemoved=0.090, RemovedCount=43, EpsM=0.48, EpsW=0.48
# [Ep 149/100000] ManagerR=0.33, WorkerR=-0.60, Total=-0.26, Moves=3, FracRemoved=0.033, RemovedCount=13, EpsM=0.47, EpsW=0.47
# [Ep 150/100000] ManagerR=0.13, WorkerR=-5.19, Total=-5.06, Moves=2, FracRemoved=0.013, RemovedCount=6, EpsM=0.47, EpsW=0.47
# [Ep 151/100000] ManagerR=0.23, WorkerR=-7.09, Total=-6.86, Moves=7, FracRemoved=0.023, RemovedCount=9, EpsM=0.47, EpsW=0.47
# [Ep 152/100000] ManagerR=0.31, WorkerR=1.35, Total=1.66, Moves=3, FracRemoved=0.031, RemovedCount=15, EpsM=0.47, EpsW=0.47
# [Ep 153/100000] ManagerR=0.21, WorkerR=-3.32, Total=-3.11, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.46, EpsW=0.46
# [Ep 154/100000] ManagerR=0.67, WorkerR=6.59, Total=7.25, Moves=15, FracRemoved=0.067, RemovedCount=26, EpsM=0.46, EpsW=0.46
# [Ep 155/100000] ManagerR=0.10, WorkerR=-6.92, Total=-6.82, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.46, EpsW=0.46
# [Ep 156/100000] ManagerR=0.40, WorkerR=-0.67, Total=-0.27, Moves=12, FracRemoved=0.040, RemovedCount=19, EpsM=0.46, EpsW=0.46
# [Ep 157/100000] ManagerR=0.56, WorkerR=10.38, Total=10.94, Moves=6, FracRemoved=0.056, RemovedCount=27, EpsM=0.46, EpsW=0.46
# [Ep 158/100000] ManagerR=0.23, WorkerR=-1.84, Total=-1.61, Moves=5, FracRemoved=0.023, RemovedCount=11, EpsM=0.45, EpsW=0.45
# [Ep 159/100000] ManagerR=1.09, WorkerR=21.98, Total=23.07, Moves=16, FracRemoved=0.109, RemovedCount=52, EpsM=0.45, EpsW=0.45
# [Ep 160/100000] ManagerR=0.52, WorkerR=9.25, Total=9.77, Moves=5, FracRemoved=0.052, RemovedCount=25, EpsM=0.45, EpsW=0.45
# [Ep 161/100000] ManagerR=0.15, WorkerR=-5.22, Total=-5.06, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.45, EpsW=0.45
# [Ep 162/100000] ManagerR=0.15, WorkerR=-4.92, Total=-4.76, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.44, EpsW=0.44
# [Ep 163/100000] ManagerR=0.28, WorkerR=-1.09, Total=-0.81, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.44, EpsW=0.44
# [Ep 164/100000] ManagerR=0.17, WorkerR=-3.35, Total=-3.18, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.44, EpsW=0.44
# [Ep 165/100000] ManagerR=0.59, WorkerR=4.85, Total=5.44, Moves=7, FracRemoved=0.059, RemovedCount=23, EpsM=0.44, EpsW=0.44
# [Ep 166/100000] ManagerR=0.21, WorkerR=-3.73, Total=-3.53, Moves=3, FracRemoved=0.021, RemovedCount=8, EpsM=0.44, EpsW=0.44
# [Ep 167/100000] ManagerR=0.18, WorkerR=-4.29, Total=-4.11, Moves=2, FracRemoved=0.018, RemovedCount=7, EpsM=0.43, EpsW=0.43
# [Ep 168/100000] ManagerR=0.23, WorkerR=-1.82, Total=-1.60, Moves=2, FracRemoved=0.023, RemovedCount=11, EpsM=0.43, EpsW=0.43
# [Ep 169/100000] ManagerR=0.44, WorkerR=0.30, Total=0.73, Moves=6, FracRemoved=0.044, RemovedCount=17, EpsM=0.43, EpsW=0.43
# [Ep 170/100000] ManagerR=0.23, WorkerR=-3.08, Total=-2.85, Moves=4, FracRemoved=0.023, RemovedCount=11, EpsM=0.43, EpsW=0.43
# [Ep 171/100000] ManagerR=0.13, WorkerR=-6.74, Total=-6.62, Moves=3, FracRemoved=0.013, RemovedCount=6, EpsM=0.42, EpsW=0.42
# [Ep 172/100000] ManagerR=0.18, WorkerR=-4.69, Total=-4.51, Moves=1, FracRemoved=0.018, RemovedCount=7, EpsM=0.42, EpsW=0.42
# [Ep 173/100000] ManagerR=0.62, WorkerR=8.79, Total=9.41, Moves=5, FracRemoved=0.062, RemovedCount=24, EpsM=0.42, EpsW=0.42
# [Ep 174/100000] ManagerR=0.17, WorkerR=-4.49, Total=-4.32, Moves=3, FracRemoved=0.017, RemovedCount=8, EpsM=0.42, EpsW=0.42
# [Ep 175/100000] ManagerR=0.73, WorkerR=16.39, Total=17.12, Moves=9, FracRemoved=0.073, RemovedCount=35, EpsM=0.42, EpsW=0.42
# [Ep 176/100000] ManagerR=0.57, WorkerR=6.03, Total=6.60, Moves=6, FracRemoved=0.057, RemovedCount=22, EpsM=0.41, EpsW=0.41
# [Ep 177/100000] ManagerR=0.25, WorkerR=-1.20, Total=-0.95, Moves=3, FracRemoved=0.025, RemovedCount=12, EpsM=0.41, EpsW=0.41
# [Ep 178/100000] ManagerR=0.13, WorkerR=-6.02, Total=-5.89, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.41, EpsW=0.41
# [Ep 179/100000] ManagerR=0.10, WorkerR=-6.25, Total=-6.14, Moves=1, FracRemoved=0.010, RemovedCount=5, EpsM=0.41, EpsW=0.41
# [Ep 180/100000] ManagerR=0.10, WorkerR=-7.19, Total=-7.08, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.41, EpsW=0.41
# [Ep 181/100000] ManagerR=0.15, WorkerR=-5.12, Total=-4.97, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.40, EpsW=0.40
# [Ep 182/100000] ManagerR=0.13, WorkerR=-6.00, Total=-5.87, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.40, EpsW=0.40
# [Ep 183/100000] ManagerR=0.15, WorkerR=-5.72, Total=-5.57, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.40, EpsW=0.40
# [Ep 184/100000] ManagerR=0.27, WorkerR=-0.74, Total=-0.47, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.40, EpsW=0.40
# [Ep 185/100000] ManagerR=0.46, WorkerR=3.25, Total=3.72, Moves=4, FracRemoved=0.046, RemovedCount=18, EpsM=0.40, EpsW=0.40
# [Ep 186/100000] ManagerR=0.18, WorkerR=-5.23, Total=-5.05, Moves=2, FracRemoved=0.018, RemovedCount=7, EpsM=0.39, EpsW=0.39
# [Ep 187/100000] ManagerR=0.29, WorkerR=-1.45, Total=-1.15, Moves=4, FracRemoved=0.029, RemovedCount=14, EpsM=0.39, EpsW=0.39
# [Ep 188/100000] ManagerR=0.42, WorkerR=4.09, Total=4.51, Moves=5, FracRemoved=0.042, RemovedCount=20, EpsM=0.39, EpsW=0.39
# [Ep 189/100000] ManagerR=0.48, WorkerR=6.36, Total=6.84, Moves=5, FracRemoved=0.048, RemovedCount=23, EpsM=0.39, EpsW=0.39
# [Ep 190/100000] ManagerR=0.18, WorkerR=-4.40, Total=-4.22, Moves=2, FracRemoved=0.018, RemovedCount=7, EpsM=0.39, EpsW=0.39
# [Ep 191/100000] ManagerR=0.08, WorkerR=-8.23, Total=-8.15, Moves=1, FracRemoved=0.008, RemovedCount=3, EpsM=0.38, EpsW=0.38
# [Ep 192/100000] ManagerR=0.31, WorkerR=-3.48, Total=-3.18, Moves=5, FracRemoved=0.031, RemovedCount=12, EpsM=0.38, EpsW=0.38
# [Ep 193/100000] ManagerR=0.17, WorkerR=-4.30, Total=-4.13, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.38, EpsW=0.38
# [Ep 194/100000] ManagerR=0.15, WorkerR=-4.40, Total=-4.25, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.38, EpsW=0.38
# [Ep 195/100000] ManagerR=0.15, WorkerR=-6.00, Total=-5.84, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.38, EpsW=0.38
# [Ep 196/100000] ManagerR=0.23, WorkerR=-5.05, Total=-4.81, Moves=4, FracRemoved=0.023, RemovedCount=9, EpsM=0.37, EpsW=0.37
# [Ep 197/100000] ManagerR=0.40, WorkerR=1.11, Total=1.51, Moves=10, FracRemoved=0.040, RemovedCount=19, EpsM=0.37, EpsW=0.37
# [Ep 198/100000] ManagerR=0.36, WorkerR=1.10, Total=1.46, Moves=3, FracRemoved=0.036, RemovedCount=14, EpsM=0.37, EpsW=0.37
# [Ep 199/100000] ManagerR=0.59, WorkerR=7.95, Total=8.54, Moves=4, FracRemoved=0.059, RemovedCount=23, EpsM=0.37, EpsW=0.37
# [Ep 200/100000] ManagerR=0.26, WorkerR=-5.20, Total=-4.94, Moves=6, FracRemoved=0.026, RemovedCount=10, EpsM=0.37, EpsW=0.37
# [Ep 201/100000] ManagerR=0.28, WorkerR=-2.11, Total=-1.83, Moves=3, FracRemoved=0.028, RemovedCount=11, EpsM=0.37, EpsW=0.37
# [Ep 202/100000] ManagerR=0.64, WorkerR=1.00, Total=1.64, Moves=13, FracRemoved=0.064, RemovedCount=25, EpsM=0.36, EpsW=0.36
# [Ep 203/100000] ManagerR=0.39, WorkerR=-0.94, Total=-0.55, Moves=6, FracRemoved=0.039, RemovedCount=15, EpsM=0.36, EpsW=0.36
# [Ep 204/100000] ManagerR=0.67, WorkerR=4.07, Total=4.74, Moves=12, FracRemoved=0.067, RemovedCount=26, EpsM=0.36, EpsW=0.36
# [Ep 205/100000] ManagerR=0.23, WorkerR=-4.87, Total=-4.64, Moves=6, FracRemoved=0.023, RemovedCount=9, EpsM=0.36, EpsW=0.36
# [Ep 206/100000] ManagerR=0.10, WorkerR=-5.97, Total=-5.86, Moves=1, FracRemoved=0.010, RemovedCount=5, EpsM=0.36, EpsW=0.36
# [Ep 207/100000] ManagerR=0.15, WorkerR=-7.50, Total=-7.35, Moves=3, FracRemoved=0.015, RemovedCount=6, EpsM=0.35, EpsW=0.35
# [Ep 208/100000] ManagerR=0.15, WorkerR=-6.50, Total=-6.35, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.35, EpsW=0.35
# [Ep 209/100000] ManagerR=0.46, WorkerR=4.86, Total=5.32, Moves=9, FracRemoved=0.046, RemovedCount=22, EpsM=0.35, EpsW=0.35
# [Ep 210/100000] ManagerR=0.28, WorkerR=-4.53, Total=-4.25, Moves=5, FracRemoved=0.028, RemovedCount=11, EpsM=0.35, EpsW=0.35
# [Ep 211/100000] ManagerR=0.15, WorkerR=-4.27, Total=-4.12, Moves=1, FracRemoved=0.015, RemovedCount=7, EpsM=0.35, EpsW=0.35
# [Ep 212/100000] ManagerR=0.13, WorkerR=-6.21, Total=-6.09, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.35, EpsW=0.35
# [Ep 213/100000] ManagerR=0.71, WorkerR=12.12, Total=12.83, Moves=10, FracRemoved=0.071, RemovedCount=34, EpsM=0.34, EpsW=0.34
# [Ep 214/100000] ManagerR=0.50, WorkerR=8.79, Total=9.29, Moves=7, FracRemoved=0.050, RemovedCount=24, EpsM=0.34, EpsW=0.34
# [Ep 215/100000] ManagerR=0.10, WorkerR=-7.38, Total=-7.28, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.34, EpsW=0.34
# [Ep 216/100000] ManagerR=0.17, WorkerR=-4.13, Total=-3.97, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.34, EpsW=0.34
# [Ep 217/100000] ManagerR=0.31, WorkerR=-1.22, Total=-0.92, Moves=3, FracRemoved=0.031, RemovedCount=12, EpsM=0.34, EpsW=0.34
# [Ep 218/100000] ManagerR=0.31, WorkerR=-0.30, Total=0.01, Moves=2, FracRemoved=0.031, RemovedCount=12, EpsM=0.34, EpsW=0.34
# [Ep 219/100000] ManagerR=0.41, WorkerR=1.43, Total=1.85, Moves=4, FracRemoved=0.041, RemovedCount=16, EpsM=0.33, EpsW=0.33
# [Ep 220/100000] ManagerR=0.36, WorkerR=-2.18, Total=-1.82, Moves=6, FracRemoved=0.036, RemovedCount=14, EpsM=0.33, EpsW=0.33
# [Ep 221/100000] ManagerR=0.06, WorkerR=-7.97, Total=-7.91, Moves=1, FracRemoved=0.006, RemovedCount=3, EpsM=0.33, EpsW=0.33
# [Ep 222/100000] ManagerR=0.31, WorkerR=-0.00, Total=0.31, Moves=6, FracRemoved=0.031, RemovedCount=15, EpsM=0.33, EpsW=0.33
# [Ep 223/100000] ManagerR=0.13, WorkerR=-6.17, Total=-6.04, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.33, EpsW=0.33
# [Ep 224/100000] ManagerR=0.46, WorkerR=0.98, Total=1.44, Moves=6, FracRemoved=0.046, RemovedCount=18, EpsM=0.33, EpsW=0.33
# [Ep 225/100000] ManagerR=0.31, WorkerR=1.46, Total=1.77, Moves=3, FracRemoved=0.031, RemovedCount=15, EpsM=0.32, EpsW=0.32
# [Ep 226/100000] ManagerR=0.38, WorkerR=4.01, Total=4.39, Moves=3, FracRemoved=0.038, RemovedCount=18, EpsM=0.32, EpsW=0.32
# [Ep 227/100000] ManagerR=0.67, WorkerR=11.34, Total=12.01, Moves=11, FracRemoved=0.067, RemovedCount=32, EpsM=0.32, EpsW=0.32
# [Ep 228/100000] ManagerR=0.13, WorkerR=-6.88, Total=-6.75, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.32, EpsW=0.32
# [Ep 229/100000] ManagerR=0.26, WorkerR=-2.48, Total=-2.23, Moves=3, FracRemoved=0.026, RemovedCount=10, EpsM=0.32, EpsW=0.32
# [Ep 230/100000] ManagerR=0.13, WorkerR=-6.33, Total=-6.20, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.32, EpsW=0.32
# [Ep 231/100000] ManagerR=0.50, WorkerR=4.77, Total=5.27, Moves=11, FracRemoved=0.050, RemovedCount=24, EpsM=0.31, EpsW=0.31
# [Ep 232/100000] ManagerR=0.13, WorkerR=-6.44, Total=-6.31, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.31, EpsW=0.31
# [Ep 233/100000] ManagerR=1.00, WorkerR=18.96, Total=19.96, Moves=16, FracRemoved=0.100, RemovedCount=48, EpsM=0.31, EpsW=0.31
# [Ep 234/100000] ManagerR=0.40, WorkerR=0.84, Total=1.24, Moves=7, FracRemoved=0.040, RemovedCount=19, EpsM=0.31, EpsW=0.31
# [Ep 235/100000] ManagerR=0.44, WorkerR=0.12, Total=0.56, Moves=12, FracRemoved=0.044, RemovedCount=21, EpsM=0.31, EpsW=0.31
# [Ep 236/100000] ManagerR=0.49, WorkerR=3.80, Total=4.28, Moves=7, FracRemoved=0.049, RemovedCount=19, EpsM=0.31, EpsW=0.31
# [Ep 237/100000] ManagerR=0.29, WorkerR=-0.00, Total=0.29, Moves=4, FracRemoved=0.029, RemovedCount=14, EpsM=0.30, EpsW=0.30
# [Ep 238/100000] ManagerR=0.31, WorkerR=1.16, Total=1.47, Moves=4, FracRemoved=0.031, RemovedCount=15, EpsM=0.30, EpsW=0.30
# [Ep 239/100000] ManagerR=0.54, WorkerR=4.01, Total=4.55, Moves=10, FracRemoved=0.054, RemovedCount=21, EpsM=0.30, EpsW=0.30
# [Ep 240/100000] ManagerR=0.19, WorkerR=-3.28, Total=-3.09, Moves=2, FracRemoved=0.019, RemovedCount=9, EpsM=0.30, EpsW=0.30
# [Ep 241/100000] ManagerR=0.21, WorkerR=-2.15, Total=-1.94, Moves=3, FracRemoved=0.021, RemovedCount=10, EpsM=0.30, EpsW=0.30
# [Ep 242/100000] ManagerR=0.19, WorkerR=-2.36, Total=-2.17, Moves=1, FracRemoved=0.019, RemovedCount=9, EpsM=0.30, EpsW=0.30
# [Ep 243/100000] ManagerR=1.21, WorkerR=30.62, Total=31.83, Moves=22, FracRemoved=0.121, RemovedCount=58, EpsM=0.30, EpsW=0.30
# [Ep 244/100000] ManagerR=0.27, WorkerR=0.58, Total=0.85, Moves=2, FracRemoved=0.027, RemovedCount=13, EpsM=0.29, EpsW=0.29
# [Ep 245/100000] ManagerR=0.27, WorkerR=-0.03, Total=0.24, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.29, EpsW=0.29
# [Ep 246/100000] ManagerR=0.28, WorkerR=-4.74, Total=-4.46, Moves=6, FracRemoved=0.028, RemovedCount=11, EpsM=0.29, EpsW=0.29
# [Ep 247/100000] ManagerR=0.13, WorkerR=-6.27, Total=-6.14, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.29, EpsW=0.29
# [Ep 248/100000] ManagerR=0.21, WorkerR=-3.72, Total=-3.52, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.29, EpsW=0.29
# [Ep 249/100000] ManagerR=0.23, WorkerR=-3.18, Total=-2.95, Moves=2, FracRemoved=0.023, RemovedCount=9, EpsM=0.29, EpsW=0.29
# [Ep 250/100000] ManagerR=0.57, WorkerR=2.86, Total=3.43, Moves=10, FracRemoved=0.057, RemovedCount=22, EpsM=0.29, EpsW=0.29
# [Ep 251/100000] ManagerR=0.15, WorkerR=-5.85, Total=-5.69, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.28, EpsW=0.28
# [Ep 252/100000] ManagerR=0.58, WorkerR=4.50, Total=5.08, Moves=14, FracRemoved=0.058, RemovedCount=28, EpsM=0.28, EpsW=0.28
# [Ep 253/100000] ManagerR=1.52, WorkerR=20.49, Total=22.01, Moves=42, FracRemoved=0.152, RemovedCount=73, EpsM=0.28, EpsW=0.28
# [Ep 254/100000] ManagerR=0.41, WorkerR=1.92, Total=2.33, Moves=3, FracRemoved=0.041, RemovedCount=16, EpsM=0.28, EpsW=0.28
# [Ep 255/100000] ManagerR=0.59, WorkerR=3.02, Total=3.61, Moves=11, FracRemoved=0.059, RemovedCount=23, EpsM=0.28, EpsW=0.28
# [Ep 256/100000] ManagerR=0.57, WorkerR=4.45, Total=5.02, Moves=9, FracRemoved=0.057, RemovedCount=22, EpsM=0.28, EpsW=0.28
# [Ep 257/100000] ManagerR=0.39, WorkerR=0.27, Total=0.65, Moves=6, FracRemoved=0.039, RemovedCount=15, EpsM=0.28, EpsW=0.28
# [Ep 258/100000] ManagerR=0.13, WorkerR=-7.46, Total=-7.34, Moves=4, FracRemoved=0.013, RemovedCount=6, EpsM=0.27, EpsW=0.27
# [Ep 259/100000] ManagerR=0.33, WorkerR=0.66, Total=0.99, Moves=6, FracRemoved=0.033, RemovedCount=16, EpsM=0.27, EpsW=0.27
# [Ep 260/100000] ManagerR=0.41, WorkerR=1.06, Total=1.47, Moves=7, FracRemoved=0.041, RemovedCount=16, EpsM=0.27, EpsW=0.27
# [Ep 261/100000] ManagerR=0.17, WorkerR=-3.79, Total=-3.63, Moves=2, FracRemoved=0.017, RemovedCount=8, EpsM=0.27, EpsW=0.27
# [Ep 262/100000] ManagerR=0.28, WorkerR=-7.47, Total=-7.19, Moves=19, FracRemoved=0.028, RemovedCount=11, EpsM=0.27, EpsW=0.27
# [Ep 263/100000] ManagerR=0.38, WorkerR=-2.71, Total=-2.33, Moves=14, FracRemoved=0.038, RemovedCount=18, EpsM=0.27, EpsW=0.27
# [Ep 264/100000] ManagerR=0.31, WorkerR=-4.41, Total=-4.10, Moves=6, FracRemoved=0.031, RemovedCount=12, EpsM=0.27, EpsW=0.27
# [Ep 265/100000] ManagerR=0.31, WorkerR=-1.25, Total=-0.94, Moves=4, FracRemoved=0.031, RemovedCount=12, EpsM=0.26, EpsW=0.26
# [Ep 266/100000] ManagerR=0.31, WorkerR=-0.92, Total=-0.62, Moves=5, FracRemoved=0.031, RemovedCount=12, EpsM=0.26, EpsW=0.26
# [Ep 267/100000] ManagerR=0.81, WorkerR=17.97, Total=18.78, Moves=11, FracRemoved=0.081, RemovedCount=39, EpsM=0.26, EpsW=0.26
# [Ep 268/100000] ManagerR=0.61, WorkerR=5.48, Total=6.08, Moves=11, FracRemoved=0.061, RemovedCount=29, EpsM=0.26, EpsW=0.26
# [Ep 269/100000] ManagerR=0.31, WorkerR=-11.85, Total=-11.54, Moves=18, FracRemoved=0.031, RemovedCount=12, EpsM=0.26, EpsW=0.26
# [Ep 270/100000] ManagerR=0.13, WorkerR=-8.10, Total=-7.97, Moves=4, FracRemoved=0.013, RemovedCount=5, EpsM=0.26, EpsW=0.26
# [Ep 271/100000] ManagerR=0.44, WorkerR=5.30, Total=5.74, Moves=8, FracRemoved=0.044, RemovedCount=21, EpsM=0.26, EpsW=0.26
# [Ep 272/100000] ManagerR=0.88, WorkerR=16.81, Total=17.68, Moves=20, FracRemoved=0.088, RemovedCount=42, EpsM=0.26, EpsW=0.26
# [Ep 273/100000] ManagerR=0.46, WorkerR=7.35, Total=7.81, Moves=4, FracRemoved=0.046, RemovedCount=22, EpsM=0.25, EpsW=0.25
# [Ep 274/100000] ManagerR=0.44, WorkerR=2.09, Total=2.53, Moves=11, FracRemoved=0.044, RemovedCount=21, EpsM=0.25, EpsW=0.25
# [Ep 275/100000] ManagerR=0.61, WorkerR=1.23, Total=1.83, Moves=24, FracRemoved=0.061, RemovedCount=29, EpsM=0.25, EpsW=0.25
# [Ep 276/100000] ManagerR=0.44, WorkerR=2.82, Total=3.26, Moves=8, FracRemoved=0.044, RemovedCount=21, EpsM=0.25, EpsW=0.25
# [Ep 277/100000] ManagerR=0.63, WorkerR=0.57, Total=1.20, Moves=23, FracRemoved=0.063, RemovedCount=30, EpsM=0.25, EpsW=0.25
# [Ep 278/100000] ManagerR=0.38, WorkerR=2.17, Total=2.55, Moves=7, FracRemoved=0.038, RemovedCount=18, EpsM=0.25, EpsW=0.25
# [Ep 279/100000] ManagerR=0.31, WorkerR=-1.65, Total=-1.34, Moves=4, FracRemoved=0.031, RemovedCount=12, EpsM=0.25, EpsW=0.25
# [Ep 280/100000] ManagerR=0.13, WorkerR=-6.17, Total=-6.04, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.25, EpsW=0.25
# [Ep 281/100000] ManagerR=0.15, WorkerR=-7.16, Total=-7.01, Moves=4, FracRemoved=0.015, RemovedCount=6, EpsM=0.24, EpsW=0.24
# [Ep 282/100000] ManagerR=0.51, WorkerR=2.18, Total=2.69, Moves=9, FracRemoved=0.051, RemovedCount=20, EpsM=0.24, EpsW=0.24
# [Ep 283/100000] ManagerR=0.61, WorkerR=-0.37, Total=0.23, Moves=25, FracRemoved=0.061, RemovedCount=29, EpsM=0.24, EpsW=0.24
# [Ep 284/100000] ManagerR=1.15, WorkerR=8.93, Total=10.07, Moves=32, FracRemoved=0.115, RemovedCount=55, EpsM=0.24, EpsW=0.24
# [Ep 285/100000] ManagerR=0.71, WorkerR=2.86, Total=3.57, Moves=22, FracRemoved=0.071, RemovedCount=34, EpsM=0.24, EpsW=0.24
# [Ep 286/100000] ManagerR=0.21, WorkerR=-7.46, Total=-7.26, Moves=9, FracRemoved=0.021, RemovedCount=8, EpsM=0.24, EpsW=0.24
# [Ep 287/100000] ManagerR=0.56, WorkerR=5.78, Total=6.35, Moves=10, FracRemoved=0.056, RemovedCount=27, EpsM=0.24, EpsW=0.24
# [Ep 288/100000] ManagerR=0.41, WorkerR=-1.13, Total=-0.72, Moves=8, FracRemoved=0.041, RemovedCount=16, EpsM=0.24, EpsW=0.24
# [Ep 289/100000] ManagerR=0.31, WorkerR=-1.33, Total=-1.02, Moves=4, FracRemoved=0.031, RemovedCount=12, EpsM=0.23, EpsW=0.23
# [Ep 290/100000] ManagerR=0.31, WorkerR=-2.75, Total=-2.44, Moves=6, FracRemoved=0.031, RemovedCount=12, EpsM=0.23, EpsW=0.23
# [Ep 291/100000] ManagerR=0.13, WorkerR=-6.48, Total=-6.36, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.23, EpsW=0.23
# [Ep 292/100000] ManagerR=0.33, WorkerR=-0.68, Total=-0.34, Moves=3, FracRemoved=0.033, RemovedCount=13, EpsM=0.23, EpsW=0.23
# [Ep 293/100000] ManagerR=0.46, WorkerR=-5.57, Total=-5.11, Moves=15, FracRemoved=0.046, RemovedCount=18, EpsM=0.23, EpsW=0.23
# [Ep 294/100000] ManagerR=1.11, WorkerR=8.71, Total=9.82, Moves=32, FracRemoved=0.111, RemovedCount=53, EpsM=0.23, EpsW=0.23
# [Ep 295/100000] ManagerR=0.44, WorkerR=-1.29, Total=-0.85, Moves=16, FracRemoved=0.044, RemovedCount=17, EpsM=0.23, EpsW=0.23
# [Ep 296/100000] ManagerR=0.48, WorkerR=-16.24, Total=-15.76, Moves=29, FracRemoved=0.048, RemovedCount=23, EpsM=0.23, EpsW=0.23
# [Ep 297/100000] ManagerR=0.13, WorkerR=-8.47, Total=-8.35, Moves=6, FracRemoved=0.013, RemovedCount=5, EpsM=0.23, EpsW=0.23
# [Ep 298/100000] ManagerR=0.13, WorkerR=-6.35, Total=-6.23, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 299/100000] ManagerR=0.44, WorkerR=2.30, Total=2.74, Moves=8, FracRemoved=0.044, RemovedCount=21, EpsM=0.22, EpsW=0.22
# [Ep 300/100000] ManagerR=0.13, WorkerR=-6.60, Total=-6.47, Moves=3, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 301/100000] ManagerR=0.13, WorkerR=-6.42, Total=-6.30, Moves=2, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 302/100000] ManagerR=0.13, WorkerR=-6.14, Total=-6.01, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 303/100000] ManagerR=0.25, WorkerR=-6.03, Total=-5.78, Moves=8, FracRemoved=0.025, RemovedCount=12, EpsM=0.22, EpsW=0.22
# [Ep 304/100000] ManagerR=0.13, WorkerR=-5.60, Total=-5.47, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 305/100000] ManagerR=0.13, WorkerR=-6.35, Total=-6.23, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 306/100000] ManagerR=0.13, WorkerR=-6.31, Total=-6.18, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.22, EpsW=0.22
# [Ep 307/100000] ManagerR=0.13, WorkerR=-6.31, Total=-6.18, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.21, EpsW=0.21
# [Ep 308/100000] ManagerR=1.61, WorkerR=20.15, Total=21.75, Moves=50, FracRemoved=0.161, RemovedCount=77, EpsM=0.21, EpsW=0.21
# [Ep 309/100000] ManagerR=0.42, WorkerR=4.50, Total=4.92, Moves=9, FracRemoved=0.042, RemovedCount=20, EpsM=0.21, EpsW=0.21
# [Ep 310/100000] ManagerR=0.21, WorkerR=-3.94, Total=-3.73, Moves=2, FracRemoved=0.021, RemovedCount=8, EpsM=0.21, EpsW=0.21
# [Ep 311/100000] ManagerR=0.21, WorkerR=-5.14, Total=-4.94, Moves=3, FracRemoved=0.021, RemovedCount=8, EpsM=0.21, EpsW=0.21
# [Ep 312/100000] ManagerR=0.13, WorkerR=-5.33, Total=-5.20, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.21, EpsW=0.21
# [Ep 313/100000] ManagerR=0.54, WorkerR=6.94, Total=7.48, Moves=7, FracRemoved=0.054, RemovedCount=26, EpsM=0.21, EpsW=0.21
# [Ep 314/100000] ManagerR=0.13, WorkerR=-6.17, Total=-6.04, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.21, EpsW=0.21
# [Ep 315/100000] ManagerR=0.41, WorkerR=-0.49, Total=-0.08, Moves=8, FracRemoved=0.041, RemovedCount=16, EpsM=0.21, EpsW=0.21
# [Ep 316/100000] ManagerR=0.23, WorkerR=-5.99, Total=-5.76, Moves=4, FracRemoved=0.023, RemovedCount=9, EpsM=0.21, EpsW=0.21
# [Ep 317/100000] ManagerR=0.25, WorkerR=-3.89, Total=-3.64, Moves=9, FracRemoved=0.025, RemovedCount=12, EpsM=0.20, EpsW=0.20
# [Ep 318/100000] ManagerR=0.08, WorkerR=-8.00, Total=-7.92, Moves=1, FracRemoved=0.008, RemovedCount=3, EpsM=0.20, EpsW=0.20
# [Ep 319/100000] ManagerR=0.08, WorkerR=-8.00, Total=-7.92, Moves=1, FracRemoved=0.008, RemovedCount=3, EpsM=0.20, EpsW=0.20
# [Ep 320/100000] ManagerR=0.08, WorkerR=-8.00, Total=-7.92, Moves=1, FracRemoved=0.008, RemovedCount=3, EpsM=0.20, EpsW=0.20
# [Ep 321/100000] ManagerR=0.15, WorkerR=-5.30, Total=-5.15, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.20, EpsW=0.20
# [Ep 322/100000] ManagerR=0.31, WorkerR=-3.85, Total=-3.54, Moves=8, FracRemoved=0.031, RemovedCount=15, EpsM=0.20, EpsW=0.20
# [Ep 323/100000] ManagerR=0.13, WorkerR=-6.17, Total=-6.04, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.20, EpsW=0.20
# [Ep 324/100000] ManagerR=0.39, WorkerR=-0.22, Total=0.16, Moves=9, FracRemoved=0.039, RemovedCount=15, EpsM=0.20, EpsW=0.20
# [Ep 325/100000] ManagerR=0.54, WorkerR=-1.51, Total=-0.97, Moves=20, FracRemoved=0.054, RemovedCount=26, EpsM=0.20, EpsW=0.20
# [Ep 326/100000] ManagerR=0.59, WorkerR=2.37, Total=2.96, Moves=12, FracRemoved=0.059, RemovedCount=23, EpsM=0.20, EpsW=0.20
# [Ep 327/100000] ManagerR=0.40, WorkerR=1.52, Total=1.92, Moves=7, FracRemoved=0.040, RemovedCount=19, EpsM=0.19, EpsW=0.19
# [Ep 328/100000] ManagerR=1.06, WorkerR=9.75, Total=10.81, Moves=34, FracRemoved=0.106, RemovedCount=51, EpsM=0.19, EpsW=0.19
# [Ep 329/100000] ManagerR=0.28, WorkerR=-2.05, Total=-1.77, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.19, EpsW=0.19
# [Ep 330/100000] ManagerR=0.49, WorkerR=-3.34, Total=-2.85, Moves=21, FracRemoved=0.049, RemovedCount=19, EpsM=0.19, EpsW=0.19
# [Ep 331/100000] ManagerR=0.13, WorkerR=-9.57, Total=-9.44, Moves=11, FracRemoved=0.013, RemovedCount=5, EpsM=0.19, EpsW=0.19
# [Ep 332/100000] ManagerR=0.13, WorkerR=-6.27, Total=-6.14, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.19, EpsW=0.19
# [Ep 333/100000] ManagerR=0.93, WorkerR=6.95, Total=7.88, Moves=16, FracRemoved=0.093, RemovedCount=36, EpsM=0.19, EpsW=0.19
# [Ep 334/100000] ManagerR=1.02, WorkerR=3.17, Total=4.19, Moves=37, FracRemoved=0.102, RemovedCount=49, EpsM=0.19, EpsW=0.19
# [Ep 335/100000] ManagerR=1.29, WorkerR=-3.91, Total=-2.61, Moves=60, FracRemoved=0.129, RemovedCount=62, EpsM=0.19, EpsW=0.19
# [Ep 336/100000] ManagerR=0.41, WorkerR=-19.15, Total=-18.74, Moves=19, FracRemoved=0.041, RemovedCount=16, EpsM=0.19, EpsW=0.19
# [Ep 337/100000] ManagerR=0.10, WorkerR=-5.92, Total=-5.82, Moves=1, FracRemoved=0.010, RemovedCount=5, EpsM=0.18, EpsW=0.18
# [Ep 338/100000] ManagerR=0.28, WorkerR=-1.91, Total=-1.63, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.18, EpsW=0.18
# [Ep 339/100000] ManagerR=0.10, WorkerR=-6.43, Total=-6.32, Moves=1, FracRemoved=0.010, RemovedCount=5, EpsM=0.18, EpsW=0.18
# [Ep 340/100000] ManagerR=0.10, WorkerR=-6.43, Total=-6.32, Moves=1, FracRemoved=0.010, RemovedCount=5, EpsM=0.18, EpsW=0.18
# [Ep 341/100000] ManagerR=0.28, WorkerR=-1.91, Total=-1.63, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.18, EpsW=0.18
# [Ep 342/100000] ManagerR=0.13, WorkerR=-5.53, Total=-5.40, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.18, EpsW=0.18
# [Ep 343/100000] ManagerR=0.46, WorkerR=5.40, Total=5.86, Moves=5, FracRemoved=0.046, RemovedCount=22, EpsM=0.18, EpsW=0.18
# [Ep 344/100000] ManagerR=0.28, WorkerR=-2.01, Total=-1.73, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.18, EpsW=0.18
# [Ep 345/100000] ManagerR=0.46, WorkerR=-4.55, Total=-4.09, Moves=7, FracRemoved=0.046, RemovedCount=18, EpsM=0.18, EpsW=0.18
# [Ep 346/100000] ManagerR=1.03, WorkerR=3.76, Total=4.79, Moves=24, FracRemoved=0.103, RemovedCount=40, EpsM=0.18, EpsW=0.18
# [Ep 347/100000] ManagerR=0.10, WorkerR=-8.80, Total=-8.70, Moves=3, FracRemoved=0.010, RemovedCount=4, EpsM=0.18, EpsW=0.18
# [Ep 348/100000] ManagerR=0.10, WorkerR=-7.13, Total=-7.03, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.17, EpsW=0.17
# [Ep 349/100000] ManagerR=0.72, WorkerR=3.16, Total=3.88, Moves=13, FracRemoved=0.072, RemovedCount=28, EpsM=0.17, EpsW=0.17
# [Ep 350/100000] ManagerR=0.69, WorkerR=-0.49, Total=0.20, Moves=27, FracRemoved=0.069, RemovedCount=33, EpsM=0.17, EpsW=0.17
# [Ep 351/100000] ManagerR=0.10, WorkerR=-7.13, Total=-7.03, Moves=1, FracRemoved=0.010, RemovedCount=4, EpsM=0.17, EpsW=0.17
# [Ep 352/100000] ManagerR=0.81, WorkerR=4.66, Total=5.47, Moves=25, FracRemoved=0.081, RemovedCount=39, EpsM=0.17, EpsW=0.17
# [Ep 353/100000] ManagerR=0.65, WorkerR=-7.36, Total=-6.71, Moves=29, FracRemoved=0.065, RemovedCount=31, EpsM=0.17, EpsW=0.17
# [Ep 354/100000] ManagerR=0.27, WorkerR=0.49, Total=0.76, Moves=3, FracRemoved=0.027, RemovedCount=13, EpsM=0.17, EpsW=0.17
# [Ep 355/100000] ManagerR=0.21, WorkerR=-14.55, Total=-14.35, Moves=25, FracRemoved=0.021, RemovedCount=8, EpsM=0.17, EpsW=0.17
# [Ep 356/100000] ManagerR=0.21, WorkerR=-4.40, Total=-4.20, Moves=3, FracRemoved=0.021, RemovedCount=8, EpsM=0.17, EpsW=0.17
# [Ep 357/100000] ManagerR=0.23, WorkerR=-4.95, Total=-4.71, Moves=6, FracRemoved=0.023, RemovedCount=9, EpsM=0.17, EpsW=0.17
# [Ep 358/100000] ManagerR=0.15, WorkerR=-5.96, Total=-5.81, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.17, EpsW=0.17
# [Ep 359/100000] ManagerR=0.21, WorkerR=-10.02, Total=-9.82, Moves=10, FracRemoved=0.021, RemovedCount=8, EpsM=0.17, EpsW=0.17
# [Ep 360/100000] ManagerR=0.51, WorkerR=3.05, Total=3.56, Moves=7, FracRemoved=0.051, RemovedCount=20, EpsM=0.16, EpsW=0.16
# [Ep 361/100000] ManagerR=0.29, WorkerR=0.96, Total=1.26, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.16, EpsW=0.16
# [Ep 362/100000] ManagerR=0.71, WorkerR=8.86, Total=9.57, Moves=15, FracRemoved=0.071, RemovedCount=34, EpsM=0.16, EpsW=0.16
# [Ep 363/100000] ManagerR=0.31, WorkerR=-2.16, Total=-1.85, Moves=11, FracRemoved=0.031, RemovedCount=15, EpsM=0.16, EpsW=0.16
# [Ep 364/100000] ManagerR=0.54, WorkerR=-0.75, Total=-0.21, Moves=18, FracRemoved=0.054, RemovedCount=26, EpsM=0.16, EpsW=0.16
# [Ep 365/100000] ManagerR=0.25, WorkerR=-2.41, Total=-2.16, Moves=4, FracRemoved=0.025, RemovedCount=12, EpsM=0.16, EpsW=0.16
# [Ep 366/100000] ManagerR=0.54, WorkerR=9.24, Total=9.79, Moves=6, FracRemoved=0.054, RemovedCount=26, EpsM=0.16, EpsW=0.16
# [Ep 367/100000] ManagerR=0.79, WorkerR=-2.48, Total=-1.68, Moves=43, FracRemoved=0.079, RemovedCount=38, EpsM=0.16, EpsW=0.16
# [Ep 368/100000] ManagerR=0.33, WorkerR=-4.07, Total=-3.73, Moves=10, FracRemoved=0.033, RemovedCount=13, EpsM=0.16, EpsW=0.16
# [Ep 369/100000] ManagerR=0.27, WorkerR=-5.71, Total=-5.44, Moves=9, FracRemoved=0.027, RemovedCount=13, EpsM=0.16, EpsW=0.16
# [Ep 370/100000] ManagerR=0.33, WorkerR=-6.37, Total=-6.04, Moves=9, FracRemoved=0.033, RemovedCount=13, EpsM=0.16, EpsW=0.16
# [Ep 371/100000] ManagerR=0.54, WorkerR=-2.35, Total=-1.81, Moves=15, FracRemoved=0.054, RemovedCount=21, EpsM=0.16, EpsW=0.16
# [Ep 372/100000] ManagerR=0.57, WorkerR=6.72, Total=7.28, Moves=5, FracRemoved=0.057, RemovedCount=22, EpsM=0.15, EpsW=0.15
# [Ep 373/100000] ManagerR=0.36, WorkerR=-1.35, Total=-0.99, Moves=4, FracRemoved=0.036, RemovedCount=14, EpsM=0.15, EpsW=0.15
# [Ep 374/100000] ManagerR=0.27, WorkerR=0.52, Total=0.79, Moves=2, FracRemoved=0.027, RemovedCount=13, EpsM=0.15, EpsW=0.15
# [Ep 375/100000] ManagerR=0.21, WorkerR=-5.41, Total=-5.20, Moves=7, FracRemoved=0.021, RemovedCount=8, EpsM=0.15, EpsW=0.15
# [Ep 376/100000] ManagerR=0.27, WorkerR=-3.51, Total=-3.24, Moves=11, FracRemoved=0.027, RemovedCount=13, EpsM=0.15, EpsW=0.15
# [Ep 377/100000] ManagerR=0.39, WorkerR=-9.51, Total=-9.12, Moves=13, FracRemoved=0.039, RemovedCount=15, EpsM=0.15, EpsW=0.15
# [Ep 378/100000] ManagerR=0.31, WorkerR=-5.94, Total=-5.63, Moves=6, FracRemoved=0.031, RemovedCount=12, EpsM=0.15, EpsW=0.15
# [Ep 379/100000] ManagerR=0.48, WorkerR=0.56, Total=1.04, Moves=12, FracRemoved=0.048, RemovedCount=23, EpsM=0.15, EpsW=0.15
# [Ep 380/100000] ManagerR=0.72, WorkerR=3.45, Total=4.17, Moves=14, FracRemoved=0.072, RemovedCount=28, EpsM=0.15, EpsW=0.15
# [Ep 381/100000] ManagerR=0.29, WorkerR=-9.01, Total=-8.72, Moves=18, FracRemoved=0.029, RemovedCount=14, EpsM=0.15, EpsW=0.15
# [Ep 382/100000] ManagerR=0.21, WorkerR=-19.07, Total=-18.87, Moves=22, FracRemoved=0.021, RemovedCount=8, EpsM=0.15, EpsW=0.15
# [Ep 383/100000] ManagerR=0.93, WorkerR=7.94, Total=8.87, Moves=18, FracRemoved=0.093, RemovedCount=36, EpsM=0.15, EpsW=0.15
# [Ep 384/100000] ManagerR=0.46, WorkerR=7.05, Total=7.51, Moves=5, FracRemoved=0.046, RemovedCount=22, EpsM=0.15, EpsW=0.15
# [Ep 385/100000] ManagerR=0.54, WorkerR=3.95, Total=4.49, Moves=5, FracRemoved=0.054, RemovedCount=21, EpsM=0.15, EpsW=0.15
# [Ep 386/100000] ManagerR=0.57, WorkerR=-6.31, Total=-5.74, Moves=15, FracRemoved=0.057, RemovedCount=22, EpsM=0.14, EpsW=0.14
# [Ep 387/100000] ManagerR=0.75, WorkerR=3.02, Total=3.77, Moves=30, FracRemoved=0.075, RemovedCount=36, EpsM=0.14, EpsW=0.14
# [Ep 388/100000] ManagerR=0.28, WorkerR=-1.38, Total=-1.10, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 389/100000] ManagerR=0.28, WorkerR=-1.38, Total=-1.10, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 390/100000] ManagerR=0.29, WorkerR=1.70, Total=1.99, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.14, EpsW=0.14
# [Ep 391/100000] ManagerR=0.71, WorkerR=11.57, Total=12.28, Moves=18, FracRemoved=0.071, RemovedCount=34, EpsM=0.14, EpsW=0.14
# [Ep 392/100000] ManagerR=0.13, WorkerR=-6.25, Total=-6.13, Moves=1, FracRemoved=0.013, RemovedCount=5, EpsM=0.14, EpsW=0.14
# [Ep 393/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 394/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 395/100000] ManagerR=0.21, WorkerR=-1.90, Total=-1.69, Moves=2, FracRemoved=0.021, RemovedCount=10, EpsM=0.14, EpsW=0.14
# [Ep 396/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 397/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.14, EpsW=0.14
# [Ep 398/100000] ManagerR=0.46, WorkerR=5.26, Total=5.72, Moves=6, FracRemoved=0.046, RemovedCount=22, EpsM=0.14, EpsW=0.14
# [Ep 399/100000] ManagerR=0.61, WorkerR=10.82, Total=11.43, Moves=7, FracRemoved=0.061, RemovedCount=29, EpsM=0.14, EpsW=0.14
# [Ep 400/100000] ManagerR=0.21, WorkerR=-3.55, Total=-3.35, Moves=1, FracRemoved=0.021, RemovedCount=8, EpsM=0.13, EpsW=0.13
# [Ep 401/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.13, EpsW=0.13
# [Ep 402/100000] ManagerR=0.29, WorkerR=1.40, Total=1.70, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.13, EpsW=0.13
# [Ep 403/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.13, EpsW=0.13
# [Ep 404/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.13, EpsW=0.13
# [Ep 405/100000] ManagerR=0.28, WorkerR=-1.77, Total=-1.49, Moves=2, FracRemoved=0.028, RemovedCount=11, EpsM=0.13, EpsW=0.13
# [Ep 406/100000] ManagerR=0.21, WorkerR=-1.45, Total=-1.24, Moves=2, FracRemoved=0.021, RemovedCount=10, EpsM=0.13, EpsW=0.13
# [Ep 407/100000] ManagerR=0.29, WorkerR=1.40, Total=1.70, Moves=2, FracRemoved=0.029, RemovedCount=14, EpsM=0.13, EpsW=0.13
# [Ep 408/100000] ManagerR=0.33, WorkerR=-2.24, Total=-1.90, Moves=5, FracRemoved=0.033, RemovedCount=13, EpsM=0.13, EpsW=0.13
# [Ep 409/100000] ManagerR=0.13, WorkerR=-5.43, Total=-5.31, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.13, EpsW=0.13
# [Ep 410/100000] ManagerR=0.46, WorkerR=3.31, Total=3.78, Moves=4, FracRemoved=0.046, RemovedCount=18, EpsM=0.13, EpsW=0.13
# [Ep 411/100000] ManagerR=0.33, WorkerR=-1.72, Total=-1.39, Moves=4, FracRemoved=0.033, RemovedCount=13, EpsM=0.13, EpsW=0.13
# [Ep 412/100000] ManagerR=0.41, WorkerR=2.01, Total=2.42, Moves=3, FracRemoved=0.041, RemovedCount=16, EpsM=0.13, EpsW=0.13
# [Ep 413/100000] ManagerR=0.19, WorkerR=-5.19, Total=-5.00, Moves=6, FracRemoved=0.019, RemovedCount=9, EpsM=0.13, EpsW=0.13
# [Ep 414/100000] ManagerR=0.54, WorkerR=4.81, Total=5.35, Moves=4, FracRemoved=0.054, RemovedCount=21, EpsM=0.13, EpsW=0.13
# [Ep 415/100000] ManagerR=0.29, WorkerR=-5.06, Total=-4.77, Moves=12, FracRemoved=0.029, RemovedCount=14, EpsM=0.12, EpsW=0.12
# [Ep 416/100000] ManagerR=0.57, WorkerR=4.44, Total=5.01, Moves=6, FracRemoved=0.057, RemovedCount=22, EpsM=0.12, EpsW=0.12
# [Ep 417/100000] ManagerR=0.73, WorkerR=8.57, Total=9.31, Moves=14, FracRemoved=0.073, RemovedCount=35, EpsM=0.12, EpsW=0.12
# [Ep 418/100000] ManagerR=0.13, WorkerR=-8.88, Total=-8.75, Moves=8, FracRemoved=0.013, RemovedCount=6, EpsM=0.12, EpsW=0.12
# [Ep 419/100000] ManagerR=0.51, WorkerR=-3.63, Total=-3.12, Moves=13, FracRemoved=0.051, RemovedCount=20, EpsM=0.12, EpsW=0.12
# [Ep 420/100000] ManagerR=0.27, WorkerR=-1.05, Total=-0.78, Moves=4, FracRemoved=0.027, RemovedCount=13, EpsM=0.12, EpsW=0.12
# [Ep 421/100000] ManagerR=0.13, WorkerR=-5.23, Total=-5.11, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.12, EpsW=0.12
# [Ep 422/100000] ManagerR=0.75, WorkerR=7.57, Total=8.32, Moves=8, FracRemoved=0.075, RemovedCount=29, EpsM=0.12, EpsW=0.12
# [Ep 423/100000] ManagerR=0.31, WorkerR=-8.57, Total=-8.26, Moves=10, FracRemoved=0.031, RemovedCount=12, EpsM=0.12, EpsW=0.12
# [Ep 424/100000] ManagerR=0.75, WorkerR=-0.17, Total=0.58, Moves=14, FracRemoved=0.075, RemovedCount=29, EpsM=0.12, EpsW=0.12
# [Ep 425/100000] ManagerR=0.13, WorkerR=-5.05, Total=-4.92, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.12, EpsW=0.12
# [Ep 426/100000] ManagerR=0.13, WorkerR=-5.05, Total=-4.92, Moves=1, FracRemoved=0.013, RemovedCount=6, EpsM=0.12, EpsW=0.12
# [Ep 427/100000] ManagerR=0.75, WorkerR=-4.46, Total=-3.72, Moves=16, FracRemoved=0.075, RemovedCount=29, EpsM=0.12, EpsW=0.12
# [Ep 428/100000] ManagerR=0.15, WorkerR=-5.19, Total=-5.04, Moves=2, FracRemoved=0.015, RemovedCount=6, EpsM=0.12, EpsW=0.12
# [Ep 429/100000] ManagerR=0.21, WorkerR=-7.11, Total=-6.90, Moves=6, FracRemoved=0.021, RemovedCount=8, EpsM=0.12, EpsW=0.12
# [Ep 430/100000] ManagerR=1.02, WorkerR=17.09, Total=18.11, Moves=32, FracRemoved=0.102, RemovedCount=49, EpsM=0.12, EpsW=0.12
# [Ep 431/100000] ManagerR=0.72, WorkerR=-3.69, Total=-2.97, Moves=22, FracRemoved=0.072, RemovedCount=28, EpsM=0.12, EpsW=0.12
# [Ep 432/100000] ManagerR=1.23, WorkerR=12.50, Total=13.74, Moves=45, FracRemoved=0.123, RemovedCount=59, EpsM=0.11, EpsW=0.11
# [Ep 433/100000] ManagerR=0.44, WorkerR=-1.50, Total=-1.07, Moves=9, FracRemoved=0.044, RemovedCount=17, EpsM=0.11, EpsW=0.11
# [Ep 434/100000] ManagerR=0.15, WorkerR=-5.35, Total=-5.20, Moves=1, FracRemoved=0.015, RemovedCount=6, EpsM=0.11, EpsW=0.11
# [Ep 435/100000] ManagerR=1.00, WorkerR=1.12, Total=2.12, Moves=38, FracRemoved=0.100, RemovedCount=48, EpsM=0.11, EpsW=0.11
# [Ep 436/100000] ManagerR=0.84, WorkerR=3.40, Total=4.23, Moves=24, FracRemoved=0.084, RemovedCount=40, EpsM=0.11, EpsW=0.11
# [Ep 437/100000] ManagerR=0.71, WorkerR=13.60, Total=14.31, Moves=8, FracRemoved=0.071, RemovedCount=34, EpsM=0.11, EpsW=0.11
# [Ep 438/100000] ManagerR=0.36, WorkerR=-13.33, Total=-12.97, Moves=10, FracRemoved=0.036, RemovedCount=14, EpsM=0.11, EpsW=0.11
# [Ep 439/100000] ManagerR=0.98, WorkerR=15.06, Total=16.04, Moves=20, FracRemoved=0.098, RemovedCount=47, EpsM=0.11, EpsW=0.11
# [Ep 440/100000] ManagerR=0.75, WorkerR=-5.56, Total=-4.81, Moves=38, FracRemoved=0.075, RemovedCount=36, EpsM=0.11, EpsW=0.11
# [Ep 441/100000] ManagerR=0.46, WorkerR=-0.80, Total=-0.33, Moves=9, FracRemoved=0.046, RemovedCount=18, EpsM=0.11, EpsW=0.11
# [Ep 442/100000] ManagerR=0.85, WorkerR=-10.88, Total=-10.03, Moves=38, FracRemoved=0.085, RemovedCount=33, EpsM=0.11, EpsW=0.11
# [Ep 443/100000] ManagerR=0.27, WorkerR=0.32, Total=0.59, Moves=2, FracRemoved=0.027, RemovedCount=13, EpsM=0.11, EpsW=0.11
# [Ep 444/100000] ManagerR=0.77, WorkerR=-4.53, Total=-3.76, Moves=26, FracRemoved=0.077, RemovedCount=30, EpsM=0.11, EpsW=0.11
# [Ep 445/100000] ManagerR=0.56, WorkerR=-2.19, Total=-1.63, Moves=22, FracRemoved=0.056, RemovedCount=27, EpsM=0.11, EpsW=0.11
# [Ep 446/100000] ManagerR=0.67, WorkerR=3.33, Total=4.00, Moves=22, FracRemoved=0.067, RemovedCount=32, EpsM=0.11, EpsW=0.11
# [Ep 447/100000] ManagerR=0.40, WorkerR=4.93, Total=5.33, Moves=3, FracRemoved=0.040, RemovedCount=19, EpsM=0.11, EpsW=0.11
# [Ep 448/100000] ManagerR=0.33, WorkerR=0.78, Total=1.11, Moves=2, FracRemoved=0.033, RemovedCount=13, EpsM=0.11, EpsW=0.11
# [Ep 449/100000] ManagerR=0.35, WorkerR=-3.09, Total=-2.73, Moves=13, FracRemoved=0.035, RemovedCount=17, EpsM=0.11, EpsW=0.11
# [Ep 450/100000] ManagerR=0.75, WorkerR=12.94, Total=13.69, Moves=5, FracRemoved=0.075, RemovedCount=29, EpsM=0.10, EpsW=0.10
# [Ep 451/100000] ManagerR=0.46, WorkerR=6.29, Total=6.74, Moves=4, FracRemoved=0.046, RemovedCount=22, EpsM=0.10, EpsW=0.10
# [Ep 452/100000] ManagerR=0.65, WorkerR=-0.25, Total=0.40, Moves=16, FracRemoved=0.065, RemovedCount=31, EpsM=0.10, EpsW=0.10
# [Ep 453/100000] ManagerR=1.38, WorkerR=-13.65, Total=-12.27, Moves=69, FracRemoved=0.138, RemovedCount=66, EpsM=0.10, EpsW=0.10
# [Ep 454/100000] ManagerR=0.75, WorkerR=14.87, Total=15.62, Moves=16, FracRemoved=0.075, RemovedCount=36, EpsM=0.10, EpsW=0.10
# [Ep 455/100000] ManagerR=0.15, WorkerR=-10.44, Total=-10.29, Moves=8, FracRemoved=0.015, RemovedCount=7, EpsM=0.10, EpsW=0.10
# [Ep 456/100000] ManagerR=0.21, WorkerR=-5.26, Total=-5.06, Moves=3, FracRemoved=0.021, RemovedCount=8, EpsM=0.10, EpsW=0.10
# [Ep 457/100000] ManagerR=0.10, WorkerR=-11.20, Total=-11.10, Moves=7, FracRemoved=0.010, RemovedCount=4, EpsM=0.10, EpsW=0.10
# [Ep 458/100000] ManagerR=0.15, WorkerR=-9.09, Total=-8.94, Moves=9, FracRemoved=0.015, RemovedCount=7, EpsM=0.10, EpsW=0.10
# [Ep 459/100000] ManagerR=0.29, WorkerR=-2.39, Total=-2.10, Moves=8, FracRemoved=0.029, RemovedCount=14, EpsM=0.10, EpsW=0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 526
#     523     print("Done.")
#     525 if __name__ == "__main__":
# --> 526     main()
#
# Cell In[1], line 522, in main()
#     521 def main():
# --> 522     train_feudal_milling(num_episodes=100000, grid_size=8)
#     523     print("Done.")
#
# Cell In[1], line 469, in train_feudal_milling(num_episodes, grid_size, manager_update_freq, lr_manager, lr_worker, batch_size, manager_gamma, worker_gamma, manager_eps_start, manager_eps_end, manager_eps_decay, worker_eps_start, worker_eps_end, worker_eps_decay)
#     467 # store worker experience
#     468 worker_replay.push(w_s, action_worker, w_r, w_s_next, w_done)
# --> 469 worker_update(worker_net, worker_opt, worker_replay, batch_size, gamma=worker_gamma)
#     471 if done:
#     472     break
#
# Cell In[1], line 397, in worker_update(net, optimizer, replay, batch_size, gamma, n_actions)
#     395 optimizer.zero_grad()
#     396 loss.backward()
# --> 397 optimizer.step()
#
# File ~/Development/Yale/cpsc776/cpsc776_demo/.venv/lib/python3.9/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File ~/Development/Yale/cpsc776/cpsc776_demo/.venv/lib/python3.9/site-packages/torch/optim/optimizer.py:94, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
# ---> 94     torch.set_grad_enabled(prev_grad)
#      95 return ret
#
# File ~/Development/Yale/cpsc776/cpsc776_demo/.venv/lib/python3.9/site-packages/torch/autograd/grad_mode.py:187, in set_grad_enabled.__init__(self, mode)
#     185 self.prev = torch.is_grad_enabled()
#     186 self.mode = mode
# --> 187 torch._C._set_grad_enabled(mode)
#
# KeyboardInterrupt:

# %%
# !tensorboard --logdir runs
# Out:
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.19.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
