# %%
#!/usr/bin/env python3
"""
Feudal RL: 3D Sculpting + Demo using Trained Models
---------------------------------------------------
We train a hierarchical RL agent in a 3D voxel environment. The manager picks
subgoals (x,y,z) in [0..grid_size-1], and the worker carves small steps among
±x, ±y, ±z. The environment terminates if the agent cuts into the shape or
goes out-of-bounds.

At the end, we store the trained models in Python variables
(manager_model, worker_model) so we can reuse them, and we run a final "demo"
episode using those models to create a 3D voxel GIF.

Usage:
  python feudal_3d_sculpt.py
"""

import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import imageio

# ------------------------------------------------
# 1) ENVIRONMENT
# ------------------------------------------------
class Sculpt3DEnv:
    def __init__(self, grid_size=8, max_steps=200, manager_update_freq=10):
        """
        3D sculpt environment:
         - NxNxN 'stock' array (True => material present)
         - NxNxN 'shape' array (True => protected shape)
         - A router that starts at (0,0,0).
         - Manager picks subgoals in [0..N^3 -1].
         - Worker picks 6 discrete steps: ±x, ±y, ±z.
        :param grid_size: NxNxN dimension
        :param max_steps: max worker steps per episode
        :param manager_update_freq: number of worker steps per manager subgoal
        """
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.manager_update_freq = manager_update_freq
        self.reset()

    def reset(self):
        # Initialize stock to True (material present)
        self.stock = np.ones((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        # Create shape (True => shape)
        self.shape = np.zeros((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        cx, cy, cz = self.grid_size//2, self.grid_size//2, self.grid_size//2
        r = self.grid_size // 3
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                for z in range(self.grid_size):
                    dx, dy, dz = x-cx, y-cy, z-cz
                    dist = dx*dx + dy*dy + dz*dz
                    if dist <= r*r:
                        self.shape[x,y,z] = True

        self.router_pos = np.array([0,0,0], dtype=int)
        self.steps_taken = 0
        self.done = False
        # Manager subgoal
        self.subgoal = np.array([cx,cy,cz], dtype=int)

        return self._get_manager_obs(), self._get_worker_obs()

    def set_subgoal(self, coord):
        coord = np.clip(coord, 0, self.grid_size-1)
        self.subgoal = coord

    def worker_step(self, action):
        """
        action in [0..5]: 0=+x,1=-x,2=+y,3=-y,4=+z,5=-z
        If shape is cut or out-of-bounds => done with penalty.
        If outside stock is removed => small reward.
        """
        if self.done:
            return self._get_worker_obs(), 0.0, True
        move = np.array([0,0,0], dtype=int)
        if action==0: move = np.array([1,0,0])
        elif action==1: move = np.array([-1,0,0])
        elif action==2: move = np.array([0,1,0])
        elif action==3: move = np.array([0,-1,0])
        elif action==4: move = np.array([0,0,1])
        elif action==5: move = np.array([0,0,-1])

        oldp = self.router_pos.copy()
        newp = oldp+move
        reward = 0.0
        # check OOB
        if not np.all((newp>=0)&(newp<self.grid_size)):
            reward -= 5.0
            self.done=True
        else:
            path = [oldp, newp]
            for (vx,vy,vz) in path:
                if self.shape[vx,vy,vz]:
                    reward -= 5.0
                    self.done=True
                    break
                if self.stock[vx,vy,vz]:
                    self.stock[vx,vy,vz] = False
                    reward += 1.0
            if not self.done:
                self.router_pos = newp

        self.steps_taken+=1
        if self.steps_taken>=self.max_steps:
            self.done=True

        return self._get_worker_obs(), reward, self.done

    def manager_reward(self):
        """
        fraction_outside_removed
        difference-based approach
        """
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        return frac_removed

    def manager_done(self):
        return self.done

    def _get_manager_obs(self):
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        rx,ry,rz = self.router_pos
        return np.array([frac_removed, rx, ry, rz], dtype=float)

    def _get_worker_obs(self):
        rx,ry,rz = self.router_pos
        sx,sy,sz = self.subgoal
        return np.array([rx,ry,rz, sx,sy,sz], dtype=float)

# ------------------------------------------------
# 2) NETWORKS
# ------------------------------------------------
class ManagerNet(nn.Module):
    def __init__(self, input_dim, grid_size=8, hidden_dim=128):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    def forward(self, x):
        return self.net(x)

class WorkerNet(nn.Module):
    def __init__(self, input_dim=6, hidden_dim=128, n_actions=6):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, n_actions)
        )
    def forward(self, x):
        return self.net(x)

# ------------------------------------------------
# 3) REPLAY BUFFERS
# ------------------------------------------------
class ManagerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s,a,r,s_next,d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self,batch_size):
        batch = random.sample(self.buffer,batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)

class WorkerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self,s,a,r,s_next,d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self,batch_size):
        batch = random.sample(self.buffer,batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)

# ------------------------------------------------
# 4) TRAINING
# ------------------------------------------------
def feudal_train(env,
                 manager_episodes=50,
                 batch_size=32,
                 manager_lr=1e-3,
                 worker_lr=1e-3,
                 gamma_manager=0.9,
                 gamma_worker=0.9,
                 manager_eps_start=1.0,
                 worker_eps_start=1.0,
                 eps_min=0.1,
                 eps_decay=0.995):
    device = "cpu"  # or "cuda" if GPU available
    manager_obs_dim = len(env._get_manager_obs())
    worker_obs_dim  = len(env._get_worker_obs())

    manager_model = ManagerNet(manager_obs_dim, grid_size=env.grid_size, hidden_dim=128).to(device)
    worker_model  = WorkerNet(worker_obs_dim, 128, 6).to(device)

    manager_opt = optim.Adam(manager_model.parameters(), lr=manager_lr)
    worker_opt  = optim.Adam(worker_model.parameters(),  lr=worker_lr)

    manager_replay = ManagerReplayBuffer(5000)
    worker_replay  = WorkerReplayBuffer(5000)

    manager_eps = manager_eps_start
    worker_eps  = worker_eps_start

    for ep in range(manager_episodes):
        m_obs, w_obs = env.reset()
        done=False
        manager_return = 0.0

        while not done:
            # manager picks subgoal
            manager_s = m_obs
            n_subgoals = env.grid_size**3
            if random.random()<manager_eps:
                subgoal_id = random.randint(0,n_subgoals-1)
            else:
                with torch.no_grad():
                    inp = torch.FloatTensor(manager_s).unsqueeze(0)
                    q_vals = manager_model(inp)
                    subgoal_id = q_vals.argmax(dim=1).item()

            # decode subgoal
            z = subgoal_id%env.grid_size
            y = (subgoal_id//env.grid_size)%env.grid_size
            x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
            env.set_subgoal(np.array([x,y,z]))
            old_manager_r = env.manager_reward()

            # worker steps
            for _ in range(env.manager_update_freq):
                if env.done:
                    break
                worker_s = w_obs
                if random.random()<worker_eps:
                    action_worker = random.randint(0,5)
                else:
                    with torch.no_grad():
                        inp = torch.FloatTensor(worker_s).unsqueeze(0)
                        q_vals = worker_model(inp)
                        action_worker = q_vals.argmax(dim=1).item()

                w_obs_next, w_r, w_done = env.worker_step(action_worker)
                worker_replay.push(worker_s, action_worker, w_r, w_obs_next, w_done)
                w_obs = w_obs_next
                done = w_done

                if len(worker_replay)>=batch_size:
                    s_arr,a_arr,r_arr,ns_arr,d_arr = worker_replay.sample(batch_size)
                    s_t = torch.FloatTensor(s_arr)
                    a_t = torch.LongTensor(a_arr)
                    r_t = torch.FloatTensor(r_arr)
                    ns_t= torch.FloatTensor(ns_arr)
                    d_t = torch.BoolTensor(d_arr)

                    q_vals = worker_model(s_t)
                    q_s_a = q_vals.gather(1,a_t.unsqueeze(1)).squeeze(1)
                    with torch.no_grad():
                        q_next = worker_model(ns_t)
                        max_q_next,_=torch.max(q_next, dim=1)
                        max_q_next[d_t]=0.0
                    target = r_t + gamma_worker*max_q_next
                    lossW = nn.MSELoss()(q_s_a, target)
                    worker_opt.zero_grad()
                    lossW.backward()
                    worker_opt.step()

                if done:
                    break

            m_obs_next = env._get_manager_obs()
            new_manager_r= env.manager_reward()
            delta_r = new_manager_r - old_manager_r
            manager_return += delta_r
            manager_done = env.manager_done()
            manager_replay.push(manager_s, subgoal_id, delta_r, m_obs_next, manager_done)
            m_obs = m_obs_next
            done = manager_done

            if len(manager_replay)>=batch_size:
                s_arr,a_arr,r_arr,ns_arr,d_arr = manager_replay.sample(batch_size)
                s_t = torch.FloatTensor(s_arr)
                a_t = torch.LongTensor(a_arr)
                r_t = torch.FloatTensor(r_arr)
                ns_t= torch.FloatTensor(ns_arr)
                d_t = torch.BoolTensor(d_arr)

                q_manager = manager_model(s_t)
                q_s_a = q_manager.gather(1,a_t.unsqueeze(1)).squeeze(1)
                with torch.no_grad():
                    q_next = manager_model(ns_t)
                    max_q_next, _ = torch.max(q_next, dim=1)
                    max_q_next[d_t]=0.0
                target = r_t + gamma_manager*max_q_next
                lossM = nn.MSELoss()(q_s_a,target)
                manager_opt.zero_grad()
                lossM.backward()
                manager_opt.step()

        manager_eps = max(eps_min, manager_eps*eps_decay)
        worker_eps  = max(eps_min, worker_eps*eps_decay)
        print(f"Ep {ep+1}/{manager_episodes}, manager_return={manager_return:.2f}, epsM={manager_eps:.2f}, epsW={worker_eps:.2f}")

    print("Feudal training complete.")
    return manager_model, worker_model

# ------------------------------------------------
# 5) DEMO WITH 3D VOXEL RENDERING
# ------------------------------------------------
def create_3d_demo_gif(manager_model, worker_model, env, output_gif="feudal_3d_sculpt_demo.gif"):
    """
    Use the trained manager_model and worker_model in a single episode (no exploration).
    Capture frames with a 3D voxel rendering each step. Then compile into a GIF.
    """
    frames = []
    manager_eps=0.0
    worker_eps=0.0
    m_obs, w_obs = env.reset()
    done=False

    while not done:
        # Manager picks subgoal greedily
        with torch.no_grad():
            inp = torch.FloatTensor(m_obs).unsqueeze(0)
            q_vals = manager_model(inp)
            subgoal_id = q_vals.argmax(dim=1).item()

        # decode subgoal
        z = subgoal_id%env.grid_size
        y = (subgoal_id//env.grid_size)%env.grid_size
        x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
        env.set_subgoal(np.array([x,y,z]))

        # up to env.manager_update_freq steps
        for _ in range(env.manager_update_freq):
            if env.done:
                break
            # Worker picks move greedily
            with torch.no_grad():
                inp = torch.FloatTensor(w_obs).unsqueeze(0)
                q_worker = worker_model(inp)
                act = q_worker.argmax(dim=1).item()

            w_obs_next, w_r, w_done = env.worker_step(act)
            w_obs = w_obs_next
            frames.append(render_3d_voxel(env))  # capture a 3D snapshot
            if w_done:
                break

        m_obs_next = env._get_manager_obs()
        done = env.manager_done()
        m_obs = m_obs_next

    # compile frames into a gif
    imageio.mimsave(output_gif, frames, fps=2)
    print(f"Demo run saved to {output_gif}")

def render_3d_voxel(env):
    """
    Return a single RGB frame as a numpy array from a 3D voxel plot:
     - shape in bright color
     - stock in partial alpha
     - removed => alpha=0
     - router => single bright voxel
    """
    import io
    from matplotlib.backends.backend_agg import FigureCanvasAgg

    n = env.grid_size
    shape = env.shape
    stock= env.stock

    # RGBA array
    data_color = np.zeros((n,n,n,4), dtype=float)
    for x in range(n):
        for y in range(n):
            for z in range(n):
                if shape[x,y,z] and stock[x,y,z]:
                    # shape voxel => bright red
                    data_color[x,y,z] = [1.0, 0.2,0.2,1.0]
                elif not shape[x,y,z] and stock[x,y,z]:
                    # outside => partial alpha grey
                    data_color[x,y,z] = [0.6,0.6,0.6,0.4]
                else:
                    # removed => alpha=0
                    data_color[x,y,z] = [1,1,1,0]

    # router => bright green
    rx,ry,rz = env.router_pos
    data_color[rx,ry,rz] = [0.0,1.0,0.0,1.0]

    filled = (data_color[:,:,:,3]>0.0)

    fig=plt.figure(figsize=(6,5))
    ax=fig.add_subplot(111, projection='3d')
    ax.voxels(filled, facecolors=data_color, edgecolor=None)

    ax.set_xlim(0,n)
    ax.set_ylim(0,n)
    ax.set_zlim(0,n)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title("3D Sculpt")

    canvas = FigureCanvasAgg(fig)
    canvas.draw()
    width,height = fig.canvas.get_width_height()
    buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
    buf = buf.reshape(height,width,3)
    plt.close(fig)
    return buf

# ------------------------------------------------
# 6) MAIN
# ------------------------------------------------
def main():
    # 1) Create environment
    env = Sculpt3DEnv(grid_size=8, max_steps=10000, manager_update_freq=5)

    # 2) Train feudal RL (manager, worker)
    manager_model, worker_model = feudal_train(env, manager_episodes=1000)

    # manager_model, worker_model are now stored in variables we can re-use.

    # 3) Use the final model to run a "demo" episode, capturing frames 
    #    with the 3D voxel rendering for each step, then compile into a GIF.
    print("Running final demo with the trained model, saving to feudal_3d_sculpt_demo.gif ...")
    create_3d_demo_gif(manager_model, worker_model, env, "feudal_3d_sculpt_demo.gif")

    print("All done. The final manager_model and worker_model are stored as Python variables.")

if __name__=="__main__":
    main()
# Out:
# Ep 1/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 2/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 3/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 4/1000, manager_return=0.01, epsM=0.98, epsW=0.98
# Ep 5/1000, manager_return=0.01, epsM=0.98, epsW=0.98
# Ep 6/1000, manager_return=0.01, epsM=0.97, epsW=0.97
# Ep 7/1000, manager_return=0.01, epsM=0.97, epsW=0.97
# Ep 8/1000, manager_return=0.02, epsM=0.96, epsW=0.96
# Ep 9/1000, manager_return=0.00, epsM=0.96, epsW=0.96
# Ep 10/1000, manager_return=0.00, epsM=0.95, epsW=0.95
# Ep 11/1000, manager_return=0.02, epsM=0.95, epsW=0.95
# Ep 12/1000, manager_return=0.00, epsM=0.94, epsW=0.94
# Ep 13/1000, manager_return=0.00, epsM=0.94, epsW=0.94
# Ep 14/1000, manager_return=0.02, epsM=0.93, epsW=0.93
# Ep 15/1000, manager_return=0.00, epsM=0.93, epsW=0.93
# Ep 16/1000, manager_return=0.01, epsM=0.92, epsW=0.92
# Ep 17/1000, manager_return=0.00, epsM=0.92, epsW=0.92
# Ep 18/1000, manager_return=0.00, epsM=0.91, epsW=0.91
# Ep 19/1000, manager_return=0.01, epsM=0.91, epsW=0.91
# Ep 20/1000, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 21/1000, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 22/1000, manager_return=0.02, epsM=0.90, epsW=0.90
# Ep 23/1000, manager_return=0.00, epsM=0.89, epsW=0.89
# Ep 24/1000, manager_return=0.00, epsM=0.89, epsW=0.89
# Ep 25/1000, manager_return=0.01, epsM=0.88, epsW=0.88
# Ep 26/1000, manager_return=0.01, epsM=0.88, epsW=0.88
# Ep 27/1000, manager_return=0.00, epsM=0.87, epsW=0.87
# Ep 28/1000, manager_return=0.01, epsM=0.87, epsW=0.87
# Ep 29/1000, manager_return=0.01, epsM=0.86, epsW=0.86
# Ep 30/1000, manager_return=0.01, epsM=0.86, epsW=0.86
# Ep 31/1000, manager_return=0.02, epsM=0.86, epsW=0.86
# Ep 32/1000, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 33/1000, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 34/1000, manager_return=0.00, epsM=0.84, epsW=0.84
# Ep 35/1000, manager_return=0.00, epsM=0.84, epsW=0.84
# Ep 36/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 37/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 38/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 84/1000, manager_return=0.01, epsM=0.66, epsW=0.66
# Ep 85/1000, manager_return=0.00, epsM=0.65, epsW=0.65
# Ep 86/1000, manager_return=0.00, epsM=0.65, epsW=0.65
# Ep 87/1000, manager_return=0.00, epsM=0.65, epsW=0.65
# Ep 88/1000, manager_return=0.00, epsM=0.64, epsW=0.64
# Ep 89/1000, manager_return=0.00, epsM=0.64, epsW=0.64
# Ep 90/1000, manager_return=0.00, epsM=0.64, epsW=0.64
# Ep 91/1000, manager_return=0.06, epsM=0.63, epsW=0.63
# Ep 92/1000, manager_return=0.00, epsM=0.63, epsW=0.63
# Ep 93/1000, manager_return=0.00, epsM=0.63, epsW=0.63
# Ep 94/1000, manager_return=0.00, epsM=0.62, epsW=0.62
# Ep 95/1000, manager_return=0.02, epsM=0.62, epsW=0.62
# Ep 96/1000, manager_return=0.00, epsM=0.62, epsW=0.62
# Ep 97/1000, manager_return=0.01, epsM=0.61, epsW=0.61
# Ep 98/1000, manager_return=0.04, epsM=0.61, epsW=0.61
# Ep 99/1000, manager_return=0.00, epsM=0.61, epsW=0.61
# Ep 100/1000, manager_return=0.01, epsM=0.61, epsW=0.61
# Ep 101/1000, manager_return=0.01, epsM=0.60, epsW=0.60
# Ep 102/1000, manager_return=0.01, epsM=0.60, epsW=0.60
# Ep 103/1000, manager_return=0.00, epsM=0.60, epsW=0.60
# Ep 104/1000, manager_return=0.02, epsM=0.59, epsW=0.59
# Ep 105/1000, manager_return=0.04, epsM=0.59, epsW=0.59
# Ep 106/1000, manager_return=0.03, epsM=0.59, epsW=0.59
# Ep 107/1000, manager_return=0.03, epsM=0.58, epsW=0.58
# Ep 108/1000, manager_return=0.01, epsM=0.58, epsW=0.58
# Ep 109/1000, manager_return=0.06, epsM=0.58, epsW=0.58
# Ep 110/1000, manager_return=0.00, epsM=0.58, epsW=0.58
# Ep 111/1000, manager_return=0.00, epsM=0.57, epsW=0.57
# Ep 112/1000, manager_return=0.00, epsM=0.57, epsW=0.57
# Ep 113/1000, manager_return=0.01, epsM=0.57, epsW=0.57
# Ep 114/1000, manager_return=0.05, epsM=0.56, epsW=0.56
# Ep 115/1000, manager_return=0.02, epsM=0.56, epsW=0.56
# Ep 116/1000, manager_return=0.08, epsM=0.56, epsW=0.56
# Ep 117/1000, manager_return=0.00, epsM=0.56, epsW=0.56
# Ep 118/1000, manager_return=0.00, epsM=0.55, epsW=0.55
# Ep 119/1000, manager_return=0.00, epsM=0.55, epsW=0.55
# Ep 120/1000, manager_return=0.01, epsM=0.55, epsW=0.55
# Ep 121/1000, manager_return=0.00, epsM=0.55, epsW=0.55
# Ep 122/1000, manager_return=0.00, epsM=0.54, epsW=0.54
# Ep 123/1000, manager_return=0.01, epsM=0.54, epsW=0.54
# Ep 124/1000, manager_return=0.01, epsM=0.54, epsW=0.54
# Ep 125/1000, manager_return=0.01, epsM=0.53, epsW=0.53
# Ep 126/1000, manager_return=0.03, epsM=0.53, epsW=0.53
# Ep 127/1000, manager_return=0.00, epsM=0.53, epsW=0.53
# Ep 128/1000, manager_return=0.00, epsM=0.53, epsW=0.53
# Ep 129/1000, manager_return=0.02, epsM=0.52, epsW=0.52
# Ep 310/1000, manager_return=0.02, epsM=0.21, epsW=0.21
# Ep 311/1000, manager_return=0.02, epsM=0.21, epsW=0.21
# Ep 312/1000, manager_return=0.03, epsM=0.21, epsW=0.21
# Ep 313/1000, manager_return=0.02, epsM=0.21, epsW=0.21
# Ep 314/1000, manager_return=0.01, epsM=0.21, epsW=0.21
# Ep 315/1000, manager_return=0.01, epsM=0.21, epsW=0.21
# Ep 316/1000, manager_return=0.01, epsM=0.21, epsW=0.21
# Ep 317/1000, manager_return=0.02, epsM=0.20, epsW=0.20
# Ep 318/1000, manager_return=0.01, epsM=0.20, epsW=0.20
# Ep 319/1000, manager_return=0.03, epsM=0.20, epsW=0.20
# Ep 320/1000, manager_return=0.02, epsM=0.20, epsW=0.20
# Ep 321/1000, manager_return=0.02, epsM=0.20, epsW=0.20
# Ep 322/1000, manager_return=0.01, epsM=0.20, epsW=0.20
# Ep 323/1000, manager_return=0.02, epsM=0.20, epsW=0.20
# Ep 324/1000, manager_return=0.03, epsM=0.20, epsW=0.20
# Ep 325/1000, manager_return=0.01, epsM=0.20, epsW=0.20
# Ep 326/1000, manager_return=0.04, epsM=0.20, epsW=0.20
# Ep 327/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 328/1000, manager_return=0.03, epsM=0.19, epsW=0.19
# Ep 329/1000, manager_return=0.08, epsM=0.19, epsW=0.19
# Ep 330/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 331/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 332/1000, manager_return=0.03, epsM=0.19, epsW=0.19
# Ep 333/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 334/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 335/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 336/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 337/1000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 338/1000, manager_return=0.03, epsM=0.18, epsW=0.18
# Ep 339/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 340/1000, manager_return=0.04, epsM=0.18, epsW=0.18
# Ep 341/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 342/1000, manager_return=0.09, epsM=0.18, epsW=0.18
# Ep 343/1000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 344/1000, manager_return=0.03, epsM=0.18, epsW=0.18
# Ep 345/1000, manager_return=0.07, epsM=0.18, epsW=0.18
# Ep 346/1000, manager_return=0.03, epsM=0.18, epsW=0.18
# Ep 347/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 348/1000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 349/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 350/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 351/1000, manager_return=0.05, epsM=0.17, epsW=0.17
# Ep 352/1000, manager_return=0.05, epsM=0.17, epsW=0.17
# Ep 353/1000, manager_return=0.08, epsM=0.17, epsW=0.17
# Ep 354/1000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 355/1000, manager_return=0.07, epsM=0.17, epsW=0.17
# Ep 356/1000, manager_return=0.04, epsM=0.17, epsW=0.17
# Ep 357/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 358/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 359/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 360/1000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 361/1000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 362/1000, manager_return=0.07, epsM=0.16, epsW=0.16
# Ep 363/1000, manager_return=0.10, epsM=0.16, epsW=0.16
# Ep 364/1000, manager_return=0.03, epsM=0.16, epsW=0.16
# Ep 365/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 366/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 367/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 368/1000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 369/1000, manager_return=0.03, epsM=0.16, epsW=0.16
# Ep 370/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 371/1000, manager_return=0.06, epsM=0.16, epsW=0.16
# Ep 372/1000, manager_return=0.05, epsM=0.15, epsW=0.15
# Ep 373/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 374/1000, manager_return=0.14, epsM=0.15, epsW=0.15
# Ep 375/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 376/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 377/1000, manager_return=0.06, epsM=0.15, epsW=0.15
# Ep 378/1000, manager_return=0.10, epsM=0.15, epsW=0.15
# Ep 379/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 380/1000, manager_return=0.02, epsM=0.15, epsW=0.15
# Ep 381/1000, manager_return=0.03, epsM=0.15, epsW=0.15
# Ep 382/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 383/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 384/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 385/1000, manager_return=0.03, epsM=0.15, epsW=0.15
# Ep 386/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 387/1000, manager_return=0.06, epsM=0.14, epsW=0.14
# Ep 388/1000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 389/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 390/1000, manager_return=0.05, epsM=0.14, epsW=0.14
# Ep 391/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 392/1000, manager_return=0.11, epsM=0.14, epsW=0.14
# Ep 393/1000, manager_return=0.08, epsM=0.14, epsW=0.14
# Ep 394/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 395/1000, manager_return=0.06, epsM=0.14, epsW=0.14
# Ep 396/1000, manager_return=0.03, epsM=0.14, epsW=0.14
# Ep 397/1000, manager_return=0.06, epsM=0.14, epsW=0.14
# Ep 398/1000, manager_return=0.09, epsM=0.14, epsW=0.14
# Ep 399/1000, manager_return=0.06, epsM=0.14, epsW=0.14
# Ep 400/1000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 401/1000, manager_return=0.08, epsM=0.13, epsW=0.13
# Ep 402/1000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 403/1000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 404/1000, manager_return=0.16, epsM=0.13, epsW=0.13
# Ep 405/1000, manager_return=0.07, epsM=0.13, epsW=0.13
# Ep 406/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 407/1000, manager_return=0.17, epsM=0.13, epsW=0.13
# Ep 408/1000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 409/1000, manager_return=0.04, epsM=0.13, epsW=0.13
# Ep 410/1000, manager_return=0.14, epsM=0.13, epsW=0.13
# Ep 411/1000, manager_return=0.08, epsM=0.13, epsW=0.13
# Ep 412/1000, manager_return=0.12, epsM=0.13, epsW=0.13
# Ep 413/1000, manager_return=0.04, epsM=0.13, epsW=0.13
# Ep 414/1000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 415/1000, manager_return=0.02, epsM=0.12, epsW=0.12
# Ep 416/1000, manager_return=0.07, epsM=0.12, epsW=0.12
# Ep 417/1000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 418/1000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 419/1000, manager_return=0.05, epsM=0.12, epsW=0.12
# Ep 420/1000, manager_return=0.09, epsM=0.12, epsW=0.12
# Ep 421/1000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 422/1000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 423/1000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 424/1000, manager_return=0.08, epsM=0.12, epsW=0.12
# Ep 425/1000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 426/1000, manager_return=0.10, epsM=0.12, epsW=0.12
# Ep 427/1000, manager_return=0.19, epsM=0.12, epsW=0.12
# Ep 428/1000, manager_return=0.17, epsM=0.12, epsW=0.12
# Ep 429/1000, manager_return=0.02, epsM=0.12, epsW=0.12
# Ep 430/1000, manager_return=0.10, epsM=0.12, epsW=0.12
# Ep 431/1000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 432/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 433/1000, manager_return=0.11, epsM=0.11, epsW=0.11
# Ep 434/1000, manager_return=0.21, epsM=0.11, epsW=0.11
# Ep 435/1000, manager_return=0.11, epsM=0.11, epsW=0.11
# Ep 436/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 437/1000, manager_return=0.07, epsM=0.11, epsW=0.11
# Ep 438/1000, manager_return=0.05, epsM=0.11, epsW=0.11
# Ep 439/1000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep 440/1000, manager_return=0.13, epsM=0.11, epsW=0.11
# Ep 441/1000, manager_return=0.02, epsM=0.11, epsW=0.11
# Ep 442/1000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep 443/1000, manager_return=0.10, epsM=0.11, epsW=0.11
# Ep 444/1000, manager_return=0.10, epsM=0.11, epsW=0.11
# Ep 445/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 446/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 447/1000, manager_return=0.14, epsM=0.11, epsW=0.11
# Ep 448/1000, manager_return=0.13, epsM=0.11, epsW=0.11
# Ep 449/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 450/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 451/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 452/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 453/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 454/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 455/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 456/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 457/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 458/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 459/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 460/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 461/1000, manager_return=0.22, epsM=0.10, epsW=0.10
# Ep 462/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 463/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 464/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 465/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 466/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 467/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 468/1000, manager_return=0.25, epsM=0.10, epsW=0.10
# Ep 469/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 470/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 471/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 472/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 473/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 474/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 475/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 476/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 477/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 478/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 479/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 480/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 481/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 482/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 483/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 484/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 485/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 486/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 487/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 488/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 489/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 490/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 491/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 492/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 493/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 494/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 495/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 496/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 497/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 498/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 499/1000, manager_return=0.26, epsM=0.10, epsW=0.10
# Ep 500/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 501/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 502/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 503/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 504/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 505/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 506/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 507/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 508/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 509/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 510/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 511/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 512/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 513/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 514/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 515/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 516/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 517/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 518/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 519/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 520/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 521/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 522/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 523/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 524/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 525/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 526/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 527/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 528/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 529/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 530/1000, manager_return=0.23, epsM=0.10, epsW=0.10
# Ep 531/1000, manager_return=0.21, epsM=0.10, epsW=0.10
# Ep 532/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 533/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 534/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 535/1000, manager_return=0.41, epsM=0.10, epsW=0.10
# Ep 536/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 537/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 538/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 539/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 540/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 541/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 542/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 543/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 544/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 545/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 546/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 547/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 548/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 549/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 550/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 551/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 552/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 553/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 554/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 555/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 556/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 557/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 558/1000, manager_return=0.28, epsM=0.10, epsW=0.10
# Ep 559/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 560/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 561/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 562/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 563/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 564/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 565/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 566/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 567/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 568/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 569/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 570/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 571/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 572/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 573/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 574/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 575/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 576/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 577/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 578/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 579/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 580/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 581/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 582/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 583/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 584/1000, manager_return=0.20, epsM=0.10, epsW=0.10
# Ep 585/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 586/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 587/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 588/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 589/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 590/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 591/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 592/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 593/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 594/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 595/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 596/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 597/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 598/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 599/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 600/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 601/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 602/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 603/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 604/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 605/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 606/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 607/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 608/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 609/1000, manager_return=0.22, epsM=0.10, epsW=0.10
# Ep 610/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 611/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 612/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 613/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 614/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 615/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 616/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 617/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 618/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 619/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 620/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 621/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 622/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 623/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 624/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 625/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 626/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 627/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 628/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 629/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 630/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 631/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 632/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 633/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 634/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 635/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 636/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 637/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 638/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 639/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 640/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 641/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 642/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 643/1000, manager_return=0.20, epsM=0.10, epsW=0.10
# Ep 644/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 645/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 646/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 647/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 648/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 649/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 650/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 651/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 652/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 653/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 654/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 655/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 656/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 657/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 658/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 659/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 660/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 661/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 662/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 663/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 664/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 665/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 666/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 667/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 668/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 669/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 670/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 671/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 672/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 673/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 674/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 675/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 676/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 677/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 678/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 679/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 680/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 681/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 682/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 683/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 684/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 685/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 686/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 687/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 688/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 689/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 690/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 691/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 692/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 693/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 694/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 695/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 696/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 697/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 698/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 699/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 700/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 701/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 702/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 703/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 704/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 705/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 706/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 707/1000, manager_return=0.25, epsM=0.10, epsW=0.10
# Ep 708/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 709/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 710/1000, manager_return=0.30, epsM=0.10, epsW=0.10
# Ep 711/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 712/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 713/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 714/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 715/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 716/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 717/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 718/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 719/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 720/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 721/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 722/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 723/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 724/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 725/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 726/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 727/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 728/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 729/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 730/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 731/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 732/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 733/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 734/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 735/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 736/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 737/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 738/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 739/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 740/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 741/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 742/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 743/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 744/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 745/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 746/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 747/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 748/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 749/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 750/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 751/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 752/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 753/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 754/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 755/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 756/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 757/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 758/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 759/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 760/1000, manager_return=0.21, epsM=0.10, epsW=0.10
# Ep 761/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 762/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 763/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 764/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 765/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 766/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 767/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 768/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 769/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 770/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 771/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 772/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 773/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 774/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 775/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 776/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 777/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 778/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 779/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 780/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 781/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 782/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 783/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 784/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 785/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 786/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 787/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 788/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 789/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 790/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 791/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 792/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 793/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 794/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 795/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 796/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 797/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 798/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 799/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 800/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 801/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 802/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 803/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 804/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 805/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 806/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 807/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 808/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 809/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 810/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 811/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 812/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 813/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 814/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 815/1000, manager_return=0.23, epsM=0.10, epsW=0.10
# Ep 816/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 817/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 818/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 819/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 820/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 821/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 822/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 823/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 824/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 825/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 826/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 827/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 828/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 829/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 830/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 831/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 832/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 833/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 834/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 835/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 836/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 837/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 838/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 839/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 840/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 841/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 842/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 843/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 844/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 845/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 846/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 847/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 848/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 849/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 850/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 851/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 852/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 853/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 854/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 855/1000, manager_return=0.23, epsM=0.10, epsW=0.10
# Ep 856/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 857/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 858/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 859/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 860/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 861/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 862/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 863/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 864/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 865/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 866/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 867/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 868/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 869/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 870/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 871/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 872/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 873/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 874/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 875/1000, manager_return=0.26, epsM=0.10, epsW=0.10
# Ep 876/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 877/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 878/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 879/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 880/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 881/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 882/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 883/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 884/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 885/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 886/1000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 887/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 888/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 889/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 890/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 891/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 892/1000, manager_return=0.22, epsM=0.10, epsW=0.10
# Ep 893/1000, manager_return=0.18, epsM=0.10, epsW=0.10
# Ep 894/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 895/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 896/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 897/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 898/1000, manager_return=0.24, epsM=0.10, epsW=0.10
# Ep 899/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 900/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 901/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 902/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 903/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 904/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 905/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 906/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 907/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 908/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 909/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 910/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 911/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 912/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 913/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 914/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 915/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 916/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 917/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 918/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 919/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 920/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 921/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 922/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 923/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 924/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 925/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 926/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 927/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 928/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 929/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 930/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 931/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 932/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 933/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 934/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 935/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 936/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 937/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 938/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 939/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 940/1000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 941/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 942/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 943/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 944/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 945/1000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 946/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 947/1000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 948/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 949/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 950/1000, manager_return=0.20, epsM=0.10, epsW=0.10
# Ep 951/1000, manager_return=0.24, epsM=0.10, epsW=0.10
# Ep 952/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 953/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 954/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 955/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 956/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 957/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 958/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 959/1000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 960/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 961/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 962/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 963/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 964/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 965/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 966/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 967/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 968/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 969/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 970/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 971/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 972/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 973/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 974/1000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 975/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 976/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 977/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 978/1000, manager_return=0.22, epsM=0.10, epsW=0.10
# Ep 979/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 980/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 981/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 982/1000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 983/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 984/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 985/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 986/1000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 987/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 988/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 989/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 990/1000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 991/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 992/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 993/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 994/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 995/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 996/1000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 997/1000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 998/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 999/1000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 1000/1000, manager_return=0.17, epsM=0.10, epsW=0.10
# Feudal training complete.
# Running final demo with the trained model, saving to feudal_3d_sculpt_demo.gif ...
# /var/folders/km/9hmy_qv946z1t5m7z35vf6600000gn/T/ipykernel_78008/1229599782.py:437: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
