# %%
#!/usr/bin/env python3
"""
Feudal RL: 3D Sculpting + Demo using Trained Models
(With a Slightly Lighter Red Tint for the Target Shape)

We train a hierarchical RL agent in a 3D voxel environment. The manager picks
subgoals (x,y,z) in [0..grid_size-1], and the worker carves small steps among
±x, ±y, ±z. The environment terminates if the agent cuts into the shape or
goes out-of-bounds.

At the end, we store the trained models in Python variables
(manager_model, worker_model) so we can reuse them, and we run a final "demo"
episode using those models to create a 3D voxel GIF.

The shape is rendered in a lighter red tint, e.g. [1.0, 0.6, 0.6, 1.0].

Usage:
  python feudal_3d_sculpt.py
"""

import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import imageio

# ------------------------------------------------
# 1) ENVIRONMENT
# ------------------------------------------------
class Sculpt3DEnv:
    def __init__(self, grid_size=8, max_steps=60, manager_update_freq=5):
        """
        3D sculpt environment:
         - NxNxN 'stock' array (True => material present)
         - NxNxN 'shape' array (True => protected shape)
         - A router that starts at (0,0,0).
         - Manager picks subgoals in [0..N^3 -1].
         - Worker picks 6 discrete steps: ±x, ±y, ±z.
        """
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.manager_update_freq = manager_update_freq
        self.reset()

    def reset(self):
        # Initialize stock to True (material present)
        self.stock = np.ones((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        # Create shape (True => shape)
        self.shape = np.zeros((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        cx, cy, cz = self.grid_size//2, self.grid_size//2, self.grid_size//2
        r = self.grid_size // 3
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                for z in range(self.grid_size):
                    dx, dy, dz = x-cx, y-cy, z-cz
                    dist = dx*dx + dy*dy + dz*dz
                    if dist <= r*r:
                        self.shape[x,y,z] = True

        self.router_pos = np.array([0,0,0], dtype=int)
        self.steps_taken = 0
        self.done = False
        # Manager subgoal
        self.subgoal = np.array([cx,cy,cz], dtype=int)

        return self._get_manager_obs(), self._get_worker_obs()

    def set_subgoal(self, coord):
        coord = np.clip(coord, 0, self.grid_size-1)
        self.subgoal = coord

    def worker_step(self, action):
        """
        action in [0..5]: 0=+x,1=-x,2=+y,3=-y,4=+z,5=-z
        If shape is cut or OOB => done with penalty.
        If outside stock is removed => small reward.
        """
        if self.done:
            return self._get_worker_obs(), 0.0, True
        move = np.array([0,0,0], dtype=int)
        if action==0: move = np.array([1,0,0])
        elif action==1: move = np.array([-1,0,0])
        elif action==2: move = np.array([0,1,0])
        elif action==3: move = np.array([0,-1,0])
        elif action==4: move = np.array([0,0,1])
        elif action==5: move = np.array([0,0,-1])

        oldp = self.router_pos.copy()
        newp = oldp+move
        reward = 0.0
        # check OOB
        if not np.all((newp>=0)&(newp<self.grid_size)):
            reward -= 5.0
            self.done=True
        else:
            path = [oldp, newp]
            for (vx,vy,vz) in path:
                if self.shape[vx,vy,vz]:
                    # shape => penalty
                    reward -= 5.0
                    self.done=True
                    break
                if self.stock[vx,vy,vz]:
                    self.stock[vx,vy,vz] = False
                    reward += 1.0
            if not self.done:
                self.router_pos = newp

        self.steps_taken+=1
        if self.steps_taken>=self.max_steps:
            self.done=True

        return self._get_worker_obs(), reward, self.done

    def manager_reward(self):
        """
        fraction_outside_removed
        difference-based approach
        """
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        return frac_removed

    def manager_done(self):
        return self.done

    def _get_manager_obs(self):
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        rx,ry,rz = self.router_pos
        return np.array([frac_removed, rx, ry, rz], dtype=float)

    def _get_worker_obs(self):
        rx,ry,rz = self.router_pos
        sx,sy,sz = self.subgoal
        return np.array([rx,ry,rz, sx,sy,sz], dtype=float)


# ------------------------------------------------
# 2) NETWORKS
# ------------------------------------------------
class ManagerNet(nn.Module):
    def __init__(self, input_dim, grid_size=8, hidden_dim=128):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    def forward(self, x):
        return self.net(x)

class WorkerNet(nn.Module):
    def __init__(self, input_dim=6, hidden_dim=128, n_actions=6):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, n_actions)
        )
    def forward(self, x):
        return self.net(x)


# ------------------------------------------------
# 3) REPLAY BUFFERS
# ------------------------------------------------
class ManagerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s, a, r, s_next, d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)

class WorkerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s, a, r, s_next, d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)


# ------------------------------------------------
# 4) TRAINING
# ------------------------------------------------
def feudal_train(env,
                 manager_episodes=50,
                 batch_size=32,
                 manager_lr=1e-3,
                 worker_lr=1e-3,
                 gamma_manager=0.9,
                 gamma_worker=0.9,
                 manager_eps_start=1.0,
                 worker_eps_start=1.0,
                 eps_min=0.1,
                 eps_decay=0.995):
    device = "cpu"  
    manager_obs_dim = len(env._get_manager_obs())
    worker_obs_dim  = len(env._get_worker_obs())

    manager_model = ManagerNet(manager_obs_dim, grid_size=env.grid_size, hidden_dim=128).to(device)
    worker_model  = WorkerNet(worker_obs_dim, 128, 6).to(device)

    manager_opt = optim.Adam(manager_model.parameters(), lr=manager_lr)
    worker_opt  = optim.Adam(worker_model.parameters(),  lr=worker_lr)

    manager_replay = ManagerReplayBuffer(5000)
    worker_replay  = WorkerReplayBuffer(5000)

    manager_eps = manager_eps_start
    worker_eps  = worker_eps_start

    for ep in range(manager_episodes):
        m_obs, w_obs = env.reset()
        done=False
        manager_return = 0.0

        while not done:
            # manager picks subgoal
            manager_s = m_obs
            n_subgoals = env.grid_size**3
            if random.random()<manager_eps:
                subgoal_id = random.randint(0,n_subgoals-1)
            else:
                with torch.no_grad():
                    inp = torch.FloatTensor(manager_s).unsqueeze(0)
                    q_vals = manager_model(inp)
                    subgoal_id = q_vals.argmax(dim=1).item()

            # decode subgoal
            z = subgoal_id%env.grid_size
            y = (subgoal_id//env.grid_size)%env.grid_size
            x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
            env.set_subgoal(np.array([x,y,z]))
            old_manager_r = env.manager_reward()

            # worker does env.manager_update_freq steps
            for _ in range(env.manager_update_freq):
                if env.done:
                    break

                worker_s = w_obs
                if random.random()<worker_eps:
                    action_worker = random.randint(0,5)
                else:
                    with torch.no_grad():
                        inp = torch.FloatTensor(worker_s).unsqueeze(0)
                        q_vals = worker_model(inp)
                        action_worker = q_vals.argmax(dim=1).item()

                w_obs_next, w_r, w_done = env.worker_step(action_worker)
                worker_replay.push(worker_s, action_worker, w_r, w_obs_next, w_done)
                w_obs = w_obs_next
                done = w_done

                # update worker
                if len(worker_replay)>=batch_size:
                    s_arr,a_arr,r_arr,ns_arr,d_arr = worker_replay.sample(batch_size)
                    s_t = torch.FloatTensor(s_arr)
                    a_t = torch.LongTensor(a_arr)
                    r_t = torch.FloatTensor(r_arr)
                    ns_t= torch.FloatTensor(ns_arr)
                    d_t = torch.BoolTensor(d_arr)

                    q_vals = worker_model(s_t)
                    q_s_a = q_vals.gather(1,a_t.unsqueeze(1)).squeeze(1)
                    with torch.no_grad():
                        q_next = worker_model(ns_t)
                        max_q_next,_=torch.max(q_next,dim=1)
                        max_q_next[d_t]=0.0
                    target = r_t + gamma_worker*max_q_next
                    lossW = nn.MSELoss()(q_s_a, target)
                    worker_opt.zero_grad()
                    lossW.backward()
                    worker_opt.step()

                if done:
                    break

            m_obs_next = env._get_manager_obs()
            new_manager_r= env.manager_reward()
            delta_r = new_manager_r - old_manager_r
            manager_return += delta_r
            manager_done = env.manager_done()
            manager_replay.push(manager_s, subgoal_id, delta_r, m_obs_next, manager_done)
            m_obs = m_obs_next
            done = manager_done

            # manager update
            if len(manager_replay)>=batch_size:
                s_arr,a_arr,r_arr,ns_arr,d_arr = manager_replay.sample(batch_size)
                s_t = torch.FloatTensor(s_arr)
                a_t = torch.LongTensor(a_arr)
                r_t = torch.FloatTensor(r_arr)
                ns_t= torch.FloatTensor(ns_arr)
                d_t = torch.BoolTensor(d_arr)

                q_manager = manager_model(s_t)
                q_s_a = q_manager.gather(1,a_t.unsqueeze(1)).squeeze(1)
                with torch.no_grad():
                    q_next = manager_model(ns_t)
                    max_q_next,_=torch.max(q_next,dim=1)
                    max_q_next[d_t]=0.0
                target = r_t + gamma_manager*max_q_next
                lossM = nn.MSELoss()(q_s_a,target)
                manager_opt.zero_grad()
                lossM.backward()
                manager_opt.step()

        manager_eps = max(eps_min, manager_eps*eps_decay)
        worker_eps  = max(eps_min, worker_eps*eps_decay)
        print(f"Ep {ep+1}/{manager_episodes}, manager_return={manager_return:.2f}, epsM={manager_eps:.2f}, epsW={worker_eps:.2f}")

    print("Feudal training complete.")
    return manager_model, worker_model

# ------------------------------------------------
# 5) DEMO WITH 3D VOXEL RENDERING (LIGHT RED SHAPE)
# ------------------------------------------------
def create_3d_demo_gif(manager_model, worker_model, env, output_gif="feudal_3d_sculpt_demo.gif"):
    frames = []
    manager_eps=0.0
    worker_eps=0.0
    m_obs, w_obs = env.reset()
    done=False

    while not done:
        # Manager picks subgoal greedily
        with torch.no_grad():
            inp = torch.FloatTensor(m_obs).unsqueeze(0)
            q_vals = manager_model(inp)
            subgoal_id = q_vals.argmax(dim=1).item()

        z = subgoal_id%env.grid_size
        y = (subgoal_id//env.grid_size)%env.grid_size
        x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
        env.set_subgoal(np.array([x,y,z]))

        # up to env.manager_update_freq worker steps
        for _ in range(env.manager_update_freq):
            if env.done:
                break
            with torch.no_grad():
                inp = torch.FloatTensor(w_obs).unsqueeze(0)
                qvals = worker_model(inp)
                act = qvals.argmax(dim=1).item()

            w_obs_next, w_r, w_done = env.worker_step(act)
            w_obs = w_obs_next

            frames.append(render_3d_voxel_light_red(env))  # capture a 3D snapshot
            if w_done:
                break

        m_obs_next = env._get_manager_obs()
        done = env.manager_done()
        m_obs = m_obs_next

    imageio.mimsave(output_gif, frames, fps=2)
    print(f"Demo run saved to {output_gif}")

def render_3d_voxel_light_red(env):
    """
    Return a single RGB frame from a 3D voxel plot:
     - shape in a slight red tint e.g. [1.0, 0.6, 0.6, 1.0]
     - stock in partial alpha grey
     - removed => alpha=0
     - router => single bright voxel (green)
    """
    import io
    from matplotlib.backends.backend_agg import FigureCanvasAgg
    fig=plt.figure(figsize=(6,5))
    ax=fig.add_subplot(111, projection='3d')

    n = env.grid_size
    shape = env.shape
    stock = env.stock

    data_color = np.zeros((n,n,n,4), dtype=float)
    for x in range(n):
        for y in range(n):
            for z in range(n):
                if shape[x,y,z] and stock[x,y,z]:
                    # shape voxel => slight red tint
                    data_color[x,y,z] = [1.0, 0.6, 0.6, 0.4]
                elif (not shape[x,y,z]) and stock[x,y,z]:
                    # outside => partial alpha grey
                    data_color[x,y,z] = [0.6,0.6,0.6,0.4]
                else:
                    # removed => alpha=0
                    data_color[x,y,z] = [1,1,1,0]

    # router => single voxel bright green
    rx,ry,rz = env.router_pos
    data_color[rx,ry,rz] = [0.0,1.0,0.0,1.0]

    filled = (data_color[:,:,:,3]>0)
    ax.voxels(filled, facecolors=data_color, edgecolor=None)

    ax.set_xlim(0,n)
    ax.set_ylim(0,n)
    ax.set_zlim(0,n)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title("3D Sculpt (slight red shape)")

    canvas = FigureCanvasAgg(fig)
    canvas.draw()
    width,height = fig.canvas.get_width_height()
    buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
    buf=buf.reshape(height,width,3)
    plt.close(fig)
    return buf

# ------------------------------------------------
# 6) MAIN
# ------------------------------------------------
def main():
    # 1) Create environment
    env = Sculpt3DEnv(grid_size=8, max_steps=60, manager_update_freq=5)

    # 2) Train
    manager_model, worker_model = feudal_train(env, manager_episodes=40)
    print("Training done. Manager and Worker stored as variables.")

    # 3) Demo
    create_3d_demo_gif(manager_model, worker_model, env, "feudal_3d_sculpt_demo.gif")
    print("All done. Model is in manager_model, worker_model. Demo is feudal_3d_sculpt_demo.gif.")

if __name__=="__main__":
    main()
# Out:
# Ep 1/40, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 2/40, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 3/40, manager_return=0.05, epsM=0.99, epsW=0.99
# Ep 4/40, manager_return=0.01, epsM=0.98, epsW=0.98
# Ep 5/40, manager_return=0.01, epsM=0.98, epsW=0.98
# Ep 6/40, manager_return=0.00, epsM=0.97, epsW=0.97
# Ep 7/40, manager_return=0.00, epsM=0.97, epsW=0.97
# Ep 8/40, manager_return=0.00, epsM=0.96, epsW=0.96
# Ep 9/40, manager_return=0.00, epsM=0.96, epsW=0.96
# Ep 10/40, manager_return=0.01, epsM=0.95, epsW=0.95
# Ep 11/40, manager_return=0.00, epsM=0.95, epsW=0.95
# Ep 12/40, manager_return=0.00, epsM=0.94, epsW=0.94
# Ep 13/40, manager_return=0.01, epsM=0.94, epsW=0.94
# Ep 14/40, manager_return=0.00, epsM=0.93, epsW=0.93
# Ep 15/40, manager_return=0.02, epsM=0.93, epsW=0.93
# Ep 16/40, manager_return=0.00, epsM=0.92, epsW=0.92
# Ep 17/40, manager_return=0.00, epsM=0.92, epsW=0.92
# Ep 18/40, manager_return=0.00, epsM=0.91, epsW=0.91
# Ep 19/40, manager_return=0.01, epsM=0.91, epsW=0.91
# Ep 20/40, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 21/40, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 22/40, manager_return=0.02, epsM=0.90, epsW=0.90
# Ep 23/40, manager_return=0.00, epsM=0.89, epsW=0.89
# Ep 24/40, manager_return=0.02, epsM=0.89, epsW=0.89
# Ep 25/40, manager_return=0.00, epsM=0.88, epsW=0.88
# Ep 26/40, manager_return=0.00, epsM=0.88, epsW=0.88
# Ep 27/40, manager_return=0.00, epsM=0.87, epsW=0.87
# Ep 28/40, manager_return=0.00, epsM=0.87, epsW=0.87
# Ep 29/40, manager_return=0.00, epsM=0.86, epsW=0.86
# Ep 30/40, manager_return=0.00, epsM=0.86, epsW=0.86
# Ep 31/40, manager_return=0.01, epsM=0.86, epsW=0.86
# Ep 32/40, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 33/40, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 34/40, manager_return=0.03, epsM=0.84, epsW=0.84
# Ep 35/40, manager_return=0.00, epsM=0.84, epsW=0.84
# Ep 36/40, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 37/40, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 38/40, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 39/40, manager_return=0.02, epsM=0.82, epsW=0.82
# Ep 40/40, manager_return=0.00, epsM=0.82, epsW=0.82
# Feudal training complete.
# Training done. Manager and Worker stored as variables.
# /var/folders/km/9hmy_qv946z1t5m7z35vf6600000gn/T/ipykernel_85312/713155784.py:436: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
# Demo run saved to feudal_3d_sculpt_demo.gif
# All done. Model is in manager_model, worker_model. Demo is feudal_3d_sculpt_demo.gif.

# %%
# ------------------------------------------------
# 6) MAIN
# ------------------------------------------------
def main():
    # 1) Create environment
    env = Sculpt3DEnv(grid_size=16, max_steps=10000, manager_update_freq=5)

    # 2) Train feudal RL (manager, worker)
    manager_model, worker_model = feudal_train(env, manager_episodes=1000)

    # manager_model, worker_model are now stored in variables we can re-use.

    # 3) Use the final model to run a "demo" episode, capturing frames 
    #    with the 3D voxel rendering for each step, then compile into a GIF.
    print("Running final demo with the trained model, saving to feudal_3d_sculpt_demo.gif ...")
    create_3d_demo_gif(manager_model, worker_model, env, "feudal_3d_sculpt_demo.gif")

    print("All done. The final manager_model and worker_model are stored as Python variables.")

if __name__=="__main__":
    main()
# Out:
# Ep 1/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 2/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 3/1000, manager_return=0.00, epsM=0.99, epsW=0.99
# Ep 4/1000, manager_return=0.00, epsM=0.98, epsW=0.98
# Ep 5/1000, manager_return=0.00, epsM=0.98, epsW=0.98
# Ep 6/1000, manager_return=0.00, epsM=0.97, epsW=0.97
# Ep 7/1000, manager_return=0.00, epsM=0.97, epsW=0.97
# Ep 8/1000, manager_return=0.00, epsM=0.96, epsW=0.96
# Ep 9/1000, manager_return=0.00, epsM=0.96, epsW=0.96
# Ep 10/1000, manager_return=0.00, epsM=0.95, epsW=0.95
# Ep 11/1000, manager_return=0.00, epsM=0.95, epsW=0.95
# Ep 12/1000, manager_return=0.00, epsM=0.94, epsW=0.94
# Ep 13/1000, manager_return=0.00, epsM=0.94, epsW=0.94
# Ep 14/1000, manager_return=0.00, epsM=0.93, epsW=0.93
# Ep 15/1000, manager_return=0.00, epsM=0.93, epsW=0.93
# Ep 16/1000, manager_return=0.00, epsM=0.92, epsW=0.92
# Ep 17/1000, manager_return=0.00, epsM=0.92, epsW=0.92
# Ep 18/1000, manager_return=0.00, epsM=0.91, epsW=0.91
# Ep 19/1000, manager_return=0.00, epsM=0.91, epsW=0.91
# Ep 20/1000, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 21/1000, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 22/1000, manager_return=0.00, epsM=0.90, epsW=0.90
# Ep 23/1000, manager_return=0.00, epsM=0.89, epsW=0.89
# Ep 24/1000, manager_return=0.00, epsM=0.89, epsW=0.89
# Ep 25/1000, manager_return=0.00, epsM=0.88, epsW=0.88
# Ep 26/1000, manager_return=0.00, epsM=0.88, epsW=0.88
# Ep 27/1000, manager_return=0.00, epsM=0.87, epsW=0.87
# Ep 28/1000, manager_return=0.00, epsM=0.87, epsW=0.87
# Ep 29/1000, manager_return=0.00, epsM=0.86, epsW=0.86
# Ep 30/1000, manager_return=0.00, epsM=0.86, epsW=0.86
# Ep 31/1000, manager_return=0.00, epsM=0.86, epsW=0.86
# Ep 32/1000, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 33/1000, manager_return=0.00, epsM=0.85, epsW=0.85
# Ep 34/1000, manager_return=0.00, epsM=0.84, epsW=0.84
# Ep 35/1000, manager_return=0.00, epsM=0.84, epsW=0.84
# Ep 36/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 37/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 38/1000, manager_return=0.00, epsM=0.83, epsW=0.83
# Ep 39/1000, manager_return=0.00, epsM=0.82, epsW=0.82
# Ep 40/1000, manager_return=0.00, epsM=0.82, epsW=0.82
# Ep 41/1000, manager_return=0.00, epsM=0.81, epsW=0.81
# Ep 42/1000, manager_return=0.00, epsM=0.81, epsW=0.81
# Ep 43/1000, manager_return=0.00, epsM=0.81, epsW=0.81
# Ep 44/1000, manager_return=0.00, epsM=0.80, epsW=0.80
# Ep 45/1000, manager_return=0.00, epsM=0.80, epsW=0.80
# Ep 46/1000, manager_return=0.02, epsM=0.79, epsW=0.79
# Ep 47/1000, manager_return=0.00, epsM=0.79, epsW=0.79
# Ep 48/1000, manager_return=0.00, epsM=0.79, epsW=0.79
# Ep 49/1000, manager_return=0.00, epsM=0.78, epsW=0.78
# Ep 50/1000, manager_return=0.01, epsM=0.78, epsW=0.78
# Ep 51/1000, manager_return=0.00, epsM=0.77, epsW=0.77
# Ep 52/1000, manager_return=0.00, epsM=0.77, epsW=0.77
# Ep 53/1000, manager_return=0.00, epsM=0.77, epsW=0.77
# Ep 54/1000, manager_return=0.00, epsM=0.76, epsW=0.76
# Ep 55/1000, manager_return=0.00, epsM=0.76, epsW=0.76
# Ep 56/1000, manager_return=0.00, epsM=0.76, epsW=0.76
# Ep 57/1000, manager_return=0.00, epsM=0.75, epsW=0.75
# Ep 58/1000, manager_return=0.00, epsM=0.75, epsW=0.75
# Ep 59/1000, manager_return=0.01, epsM=0.74, epsW=0.74
1000, manager_return=0.00, epsM=0.20, epsW=0.20
# Ep 324/1000, manager_return=0.01, epsM=0.20, epsW=0.20
# Ep 325/1000, manager_return=0.01, epsM=0.20, epsW=0.20
# Ep 326/1000, manager_return=0.00, epsM=0.20, epsW=0.20
# Ep 327/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 328/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 329/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 330/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 331/1000, manager_return=0.02, epsM=0.19, epsW=0.19
# Ep 332/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 333/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 334/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 335/1000, manager_return=0.00, epsM=0.19, epsW=0.19
# Ep 336/1000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 337/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 338/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 339/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 340/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 341/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 342/1000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 343/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 344/1000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 345/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 346/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 347/1000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 348/1000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 349/1000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 350/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 351/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 352/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 353/1000, manager_return=0.00, epsM=0.17, epsW=0.17
# Ep 354/1000, manager_return=0.00, epsM=0.17, epsW=0.17
# Ep 355/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 356/1000, manager_return=0.00, epsM=0.17, epsW=0.17
# Ep 357/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 358/1000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 359/1000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 360/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 361/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 362/1000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 363/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 364/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 365/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 366/1000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 367/1000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 368/1000, manager_return=0.00, epsM=0.16, epsW=0.16
# Ep 369/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 370/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 371/1000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 372/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 373/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 374/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 375/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 376/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 377/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 378/1000, manager_return=0.03, epsM=0.15, epsW=0.15
# Ep 379/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 380/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 381/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 382/1000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 383/1000, manager_return=0.04, epsM=0.15, epsW=0.15
# Ep 384/1000, manager_return=0.05, epsM=0.15, epsW=0.15
# Ep 385/1000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 386/1000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 387/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 388/1000, manager_return=0.04, epsM=0.14, epsW=0.14
# Ep 389/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 390/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 391/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 392/1000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 393/1000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 394/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 395/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 396/1000, manager_return=0.04, epsM=0.14, epsW=0.14
# Ep 397/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 398/1000, manager_return=0.02, epsM=0.14, epsW=0.14
# Ep 399/1000, manager_return=0.00, epsM=0.14, epsW=0.14
# Ep 400/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 401/1000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 402/1000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 403/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 404/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 405/1000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 406/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 407/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 408/1000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 409/1000, manager_return=0.04, epsM=0.13, epsW=0.13
# Ep 410/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 411/1000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 412/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 413/1000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 414/1000, manager_return=0.03, epsM=0.13, epsW=0.13
# Ep 415/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 416/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 417/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 418/1000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 419/1000, manager_return=0.02, epsM=0.12, epsW=0.12
# Ep 420/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 421/1000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 422/1000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 423/1000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 424/1000, manager_return=0.03, epsM=0.12, epsW=0.12
# Ep 425/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 426/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 427/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 428/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 429/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 430/1000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 431/1000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 432/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 433/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 434/1000, manager_return=0.04, epsM=0.11, epsW=0.11
# Ep 435/1000, manager_return=0.02, epsM=0.11, epsW=0.11
# Ep 436/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 437/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 438/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 439/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 440/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 441/1000, manager_return=0.02, epsM=0.11, epsW=0.11
# Ep 442/1000, manager_return=0.04, epsM=0.11, epsW=0.11
# Ep 443/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 444/1000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep 445/1000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 446/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 447/1000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep 448/1000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 449/1000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep 450/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 451/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 452/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 453/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 454/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 455/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 456/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 457/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 458/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 459/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 460/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 461/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 462/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 463/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 464/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 465/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 466/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 467/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 468/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 469/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 470/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 471/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 472/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 473/1000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 474/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 475/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 476/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 477/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 478/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 479/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 480/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 481/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 482/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 483/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 484/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 485/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 486/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 487/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 488/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 489/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 490/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 491/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 492/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 493/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 494/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 495/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 496/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 497/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 498/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 499/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 500/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 501/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 502/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 503/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 504/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 505/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 506/1000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 507/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 508/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 509/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 510/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 511/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 512/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 513/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 514/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 515/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 516/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 517/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 518/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 519/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 520/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 521/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 522/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 523/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 524/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 525/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 526/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 527/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 528/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 529/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 530/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 531/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 532/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 533/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 534/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 535/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 536/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 537/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 538/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 539/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 540/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 541/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 542/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 543/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 544/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 545/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 546/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 547/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 548/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 549/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 550/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 551/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 552/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 553/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 554/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 555/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 556/1000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 557/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 558/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 559/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 560/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 561/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 562/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 563/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 564/1000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 565/1000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 566/1000, manager_return=0.01, epsM=0.10, epsW=0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      18     print("All done. The final manager_model and worker_model are stored as Python variables.")
#      20 if __name__=="__main__":
# ---> 21     main()
#
# Cell In[4], line 9, in main()
#       6 env = Sculpt3DEnv(grid_size=16, max_steps=10000, manager_update_freq=5)
#       8 # 2) Train feudal RL (manager, worker)
# ----> 9 manager_model, worker_model = feudal_train(env, manager_episodes=1000)
#      11 # manager_model, worker_model are now stored in variables we can re-use.
#      12
#      13 # 3) Use the final model to run a "demo" episode, capturing frames
#      14 #    with the 3D voxel rendering for each step, then compile into a GIF.
#      15 print("Running final demo with the trained model, saving to feudal_3d_sculpt_demo.gif ...")
#
# Cell In[3], line 260, in feudal_train(env, manager_episodes, batch_size, manager_lr, worker_lr, gamma_manager, gamma_worker, manager_eps_start, worker_eps_start, eps_min, eps_decay)
#     258 x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
#     259 env.set_subgoal(np.array([x,y,z]))
# --> 260 old_manager_r = env.manager_reward()
#     262 # worker does env.manager_update_freq steps
#     263 for _ in range(env.manager_update_freq):
#
# Cell In[3], line 125, in Sculpt3DEnv.manager_reward(self)
#     120 def manager_reward(self):
#     121     """
#     122     fraction_outside_removed
#     123     difference-based approach
#     124     """
# --> 125     outside_mask = (self.shape==False)
#     126     outside_total = np.sum(outside_mask)
#     127     outside_removed = outside_total - np.sum(self.stock[outside_mask])
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python3
"""
Feudal RL: 3D Sculpting + Demo using Trained Models
(With a Clearly Visible Target Shape)

We train a hierarchical RL agent in a 3D voxel environment. The manager picks
subgoals (x,y,z) in [0..grid_size-1], and the worker carves small steps among
±x, ±y, ±z. The environment terminates if the agent cuts into the shape or
goes out-of-bounds.

At the end, we store the trained models in Python variables
(manager_model, worker_model), and we run a final "demo" using those models
to create a 3D voxel GIF.

The target shape is fully opaque in a medium red color, so it should be
clearly visible in the final rendering.
"""

import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import imageio

# ------------------------------------------------
# 1) ENVIRONMENT
# ------------------------------------------------
class Sculpt3DEnv:
    def __init__(self, grid_size=8, max_steps=60, manager_update_freq=5):
        """
        3D sculpt environment:
         - NxNxN 'stock' array (True => material present)
         - NxNxN 'shape' array (True => protected shape)
         - A router at (0,0,0).
         - Manager picks subgoals in [0..N^3 -1].
         - Worker picks 6 discrete steps: ±x, ±y, ±z.
        """
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.manager_update_freq = manager_update_freq
        self.reset()

    def reset(self):
        # Initialize stock to True (material present)
        self.stock = np.ones((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        
        # Create shape (True => shape). Use a bigger radius so it's clearly visible
        self.shape = np.zeros((self.grid_size, self.grid_size, self.grid_size), dtype=bool)
        cx, cy, cz = self.grid_size//2, self.grid_size//2, self.grid_size//2
        # Make shape large so we definitely see it
        r = self.grid_size // 2 - 1   #  TODO Altered,
        for x in range(self.grid_size):
            for y in range(self.grid_size):
                for z in range(self.grid_size):
                    dx, dy, dz = x-cx, y-cy, z-cz
                    dist = dx*dx + dy*dy + dz*dz
                    if dist <= r*r:
                        self.shape[x,y,z] = True
        
        self.router_pos = np.array([0,0,0], dtype=int)
        self.steps_taken = 0
        self.done = False
        # Manager subgoal
        self.subgoal = np.array([cx,cy,cz], dtype=int)

        # Debug line: 
        # print("shape voxels =", np.sum(self.shape))

        return self._get_manager_obs(), self._get_worker_obs()

    def set_subgoal(self, coord):
        coord = np.clip(coord, 0, self.grid_size-1)
        self.subgoal = coord

    def worker_step(self, action):
        """
        action in [0..5]: 0=+x,1=-x,2=+y,3=-y,4=+z,5=-z
        If shape is cut or OOB => done with penalty.
        If outside stock is removed => small reward.
        """
        if self.done:
            return self._get_worker_obs(), 0.0, True
        move = np.array([0,0,0], dtype=int)
        if action==0: move = np.array([1,0,0])
        elif action==1: move = np.array([-1,0,0])
        elif action==2: move = np.array([0,1,0])
        elif action==3: move = np.array([0,-1,0])
        elif action==4: move = np.array([0,0,1])
        elif action==5: move = np.array([0,0,-1])

        oldp = self.router_pos.copy()
        newp = oldp+move
        reward = 0.0
        # check OOB
        if not np.all((newp>=0)&(newp<self.grid_size)):
            reward -= 5.0
            self.done=True
        else:
            path = [oldp, newp]
            for (vx,vy,vz) in path:
                if self.shape[vx,vy,vz]:
                    # shape => penalty
                    reward -= 5.0
                    self.done=True
                    break
                if self.stock[vx,vy,vz]:
                    self.stock[vx,vy,vz] = False
                    reward += 1.0
            if not self.done:
                self.router_pos = newp

        self.steps_taken+=1
        if self.steps_taken>=self.max_steps:
            self.done=True

        return self._get_worker_obs(), reward, self.done

    def manager_reward(self):
        """
        fraction_outside_removed
        difference-based approach
        """
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        return frac_removed

    def manager_done(self):
        return self.done

    def _get_manager_obs(self):
        outside_mask = (self.shape==False)
        outside_total = np.sum(outside_mask)
        outside_removed = outside_total - np.sum(self.stock[outside_mask])
        frac_removed = outside_removed/(outside_total+1e-8)
        rx,ry,rz = self.router_pos
        return np.array([frac_removed, rx, ry, rz], dtype=float)

    def _get_worker_obs(self):
        rx,ry,rz = self.router_pos
        sx,sy,sz = self.subgoal
        return np.array([rx,ry,rz, sx,sy,sz], dtype=float)


# ------------------------------------------------
# 2) NETWORKS
# ------------------------------------------------
class ManagerNet(nn.Module):
    def __init__(self, input_dim, grid_size=8, hidden_dim=128):
        super().__init__()
        self.grid_size = grid_size
        self.output_dim = grid_size**3
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, self.output_dim)
        )
    def forward(self, x):
        return self.net(x)

class WorkerNet(nn.Module):
    def __init__(self, input_dim=6, hidden_dim=128, n_actions=6):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, n_actions)
        )
    def forward(self, x):
        return self.net(x)


# ------------------------------------------------
# 3) REPLAY BUFFERS
# ------------------------------------------------
class ManagerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s,a,r,s_next,d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)

class WorkerReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)
    def push(self, s,a,r,s_next,d):
        self.buffer.append((s,a,r,s_next,d))
    def sample(self,batch_size):
        batch = random.sample(self.buffer,batch_size)
        s,a,r,ns,d = zip(*batch)
        return np.array(s), np.array(a), np.array(r), np.array(ns), np.array(d)
    def __len__(self):
        return len(self.buffer)


# ------------------------------------------------
# 4) TRAINING
# ------------------------------------------------
def feudal_train(env,
                 manager_episodes=50,
                 batch_size=32,
                 manager_lr=1e-3,
                 worker_lr=1e-3,
                 gamma_manager=0.9,
                 gamma_worker=0.9,
                 manager_eps_start=1.0,
                 worker_eps_start=1.0,
                 eps_min=0.1,
                 eps_decay=0.995):
    device = "cpu"  
    manager_obs_dim = len(env._get_manager_obs())
    worker_obs_dim  = len(env._get_worker_obs())

    manager_model = ManagerNet(manager_obs_dim, grid_size=env.grid_size, hidden_dim=128).to(device)
    worker_model  = WorkerNet(worker_obs_dim, 128, 6).to(device)

    manager_opt = optim.Adam(manager_model.parameters(), lr=manager_lr)
    worker_opt  = optim.Adam(worker_model.parameters(),  lr=worker_lr)

    manager_replay = ManagerReplayBuffer(5000)
    worker_replay  = WorkerReplayBuffer(5000)

    manager_eps = manager_eps_start
    worker_eps  = worker_eps_start

    for ep in range(manager_episodes):
        m_obs, w_obs = env.reset()
        done=False
        manager_return = 0.0

        while not done:
            # manager picks subgoal
            manager_s = m_obs
            n_subgoals = env.grid_size**3
            if random.random()<manager_eps:
                subgoal_id = random.randint(0,n_subgoals-1)
            else:
                with torch.no_grad():
                    inp = torch.FloatTensor(manager_s).unsqueeze(0)
                    q_vals = manager_model(inp)
                    subgoal_id = q_vals.argmax(dim=1).item()

            # decode subgoal
            z = subgoal_id%env.grid_size
            y = (subgoal_id//env.grid_size)%env.grid_size
            x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
            env.set_subgoal(np.array([x,y,z]))
            old_manager_r = env.manager_reward()

            # worker steps
            for _ in range(env.manager_update_freq):
                if env.done:
                    break
                worker_s = w_obs
                if random.random()<worker_eps:
                    action_worker = random.randint(0,5)
                else:
                    with torch.no_grad():
                        inp = torch.FloatTensor(worker_s).unsqueeze(0)
                        q_vals = worker_model(inp)
                        action_worker = q_vals.argmax(dim=1).item()

                w_obs_next, w_r, w_done = env.worker_step(action_worker)
                worker_replay.push(worker_s, action_worker, w_r, w_obs_next, w_done)
                w_obs = w_obs_next
                done = w_done

                if len(worker_replay)>=batch_size:
                    s_arr,a_arr,r_arr,ns_arr,d_arr = worker_replay.sample(batch_size)
                    s_t = torch.FloatTensor(s_arr)
                    a_t = torch.LongTensor(a_arr)
                    r_t = torch.FloatTensor(r_arr)
                    ns_t= torch.FloatTensor(ns_arr)
                    d_t = torch.BoolTensor(d_arr)

                    q_vals = worker_model(s_t)
                    q_s_a = q_vals.gather(1,a_t.unsqueeze(1)).squeeze(1)
                    with torch.no_grad():
                        q_next = worker_model(ns_t)
                        max_q_next,_=torch.max(q_next,dim=1)
                        max_q_next[d_t]=0.0
                    target = r_t + gamma_worker*max_q_next
                    lossW = nn.MSELoss()(q_s_a,target)
                    worker_opt.zero_grad()
                    lossW.backward()
                    worker_opt.step()

                if done:
                    break

            m_obs_next = env._get_manager_obs()
            new_manager_r= env.manager_reward()
            delta_r = new_manager_r - old_manager_r
            manager_return += delta_r
            manager_done = env.manager_done()
            manager_replay.push(manager_s, subgoal_id, delta_r, m_obs_next, manager_done)
            m_obs = m_obs_next
            done = manager_done

            if len(manager_replay)>=batch_size:
                s_arr,a_arr,r_arr,ns_arr,d_arr = manager_replay.sample(batch_size)
                s_t = torch.FloatTensor(s_arr)
                a_t = torch.LongTensor(a_arr)
                r_t = torch.FloatTensor(r_arr)
                ns_t= torch.FloatTensor(ns_arr)
                d_t = torch.BoolTensor(d_arr)

                q_manager = manager_model(s_t)
                q_s_a = q_manager.gather(1,a_t.unsqueeze(1)).squeeze(1)
                with torch.no_grad():
                    q_next = manager_model(ns_t)
                    max_q_next,_=torch.max(q_next,dim=1)
                    max_q_next[d_t]=0.0
                target = r_t + gamma_manager*max_q_next
                lossM = nn.MSELoss()(q_s_a,target)
                manager_opt.zero_grad()
                lossM.backward()
                manager_opt.step()

        manager_eps = max(eps_min, manager_eps*eps_decay)
        worker_eps  = max(eps_min, worker_eps*eps_decay)
        print(f"Ep {ep+1}/{manager_episodes}, manager_return={manager_return:.2f}, epsM={manager_eps:.2f}, epsW={worker_eps:.2f}")

    print("Feudal training complete.")
    return manager_model, worker_model

# ------------------------------------------------
# 5) DEMO WITH 3D VOXEL RENDERING
# ------------------------------------------------
def create_3d_demo_gif(manager_model, worker_model, env, output_gif="feudal_3d_sculpt_demo.gif"):
    frames = []
    m_obs, w_obs = env.reset()
    done=False

    while not done:
        # Manager picks subgoal greedily
        with torch.no_grad():
            inp = torch.FloatTensor(m_obs).unsqueeze(0)
            q_vals = manager_model(inp)
            subgoal_id = q_vals.argmax(dim=1).item()

        z = subgoal_id%env.grid_size
        y = (subgoal_id//env.grid_size)%env.grid_size
        x = (subgoal_id//(env.grid_size*env.grid_size))%env.grid_size
        env.set_subgoal(np.array([x,y,z]))

        for _ in range(env.manager_update_freq):
            if env.done:
                break

            with torch.no_grad():
                inp = torch.FloatTensor(w_obs).unsqueeze(0)
                qvals = worker_model(inp)
                act = qvals.argmax(dim=1).item()

            w_obs_next, w_r, w_done = env.worker_step(act)
            w_obs = w_obs_next
            frames.append(render_3d_voxel_visible_shape(env))
            if w_done:
                break

        m_obs_next = env._get_manager_obs()
        done = env.manager_done()
        m_obs = m_obs_next

    imageio.mimsave(output_gif, frames, fps=2)
    print(f"Demo run saved to {output_gif}")

def render_3d_voxel_visible_shape(env):
    """
    Return a single RGB frame with a 3D voxel plot:
     - shape in [1.0, 0.5, 0.5, 1.0] => fully opaque red tint
     - outside stock in [0.6,0.6,0.6,0.4] => partial alpha grey
     - removed => alpha=0
     - router => bright green voxel
    """
    from matplotlib.backends.backend_agg import FigureCanvasAgg
    import io
    import matplotlib.pyplot as plt

    n = env.grid_size
    shape = env.shape
    stock = env.stock

    data_color = np.zeros((n,n,n,4), dtype=float)
    for x in range(n):
        for y in range(n):
            for z in range(n):
                if shape[x,y,z] and stock[x,y,z]:
                    # shape => medium red, full alpha
                    data_color[x,y,z] = [1.0,0.5,0.5,1.0]
                elif not shape[x,y,z] and stock[x,y,z]:
                    # outside => partial alpha grey
                    data_color[x,y,z] = [0.6,0.6,0.6,0.4]
                else:
                    # removed => alpha=0
                    data_color[x,y,z] = [1,1,1,0]

    # router => bright green
    rx,ry,rz = env.router_pos
    data_color[rx,ry,rz] = [0.0,1.0,0.0,1.0]

    filled = (data_color[:,:,:,3]>0.0)

    fig = plt.figure(figsize=(6,5))
    ax = fig.add_subplot(111, projection='3d')
    ax.voxels(filled, facecolors=data_color, edgecolor=None)
    ax.set_xlim(0,n)
    ax.set_ylim(0,n)
    ax.set_zlim(0,n)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title("3D Sculpt - Visible Shape")

    canvas = FigureCanvasAgg(fig)
    canvas.draw()
    width,height = fig.canvas.get_width_height()
    buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
    buf=buf.reshape(height,width,3)
    plt.close(fig)
    return buf

# ------------------------------------------------
# 6) MAIN
# ------------------------------------------------
def main():
    env = Sculpt3DEnv(grid_size=8, max_steps=1000, manager_update_freq=5)
    manager_model, worker_model = feudal_train(env, manager_episodes=10000)
    print("Training done. Manager and Worker stored as variables.")
    create_3d_demo_gif(manager_model, worker_model, env, "feudal_3d_sculpt_demo.gif")
    print("All done. Demo is in feudal_3d_sculpt_demo.gif")

if __name__=="__main__":
    main()
# Out:
# Ep 1/10000, manager_return=0.01, epsM=0.99, epsW=0.99
, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 335/10000, manager_return=0.01, epsM=0.19, epsW=0.19
# Ep 336/10000, manager_return=0.06, epsM=0.19, epsW=0.19
# Ep 337/10000, manager_return=0.03, epsM=0.18, epsW=0.18
# Ep 338/10000, manager_return=0.04, epsM=0.18, epsW=0.18
# Ep 339/10000, manager_return=0.06, epsM=0.18, epsW=0.18
# Ep 340/10000, manager_return=0.03, epsM=0.18, epsW=0.18
# Ep 341/10000, manager_return=0.01, epsM=0.18, epsW=0.18
# Ep 342/10000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 343/10000, manager_return=0.00, epsM=0.18, epsW=0.18
# Ep 344/10000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 345/10000, manager_return=0.06, epsM=0.18, epsW=0.18
# Ep 346/10000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 347/10000, manager_return=0.02, epsM=0.18, epsW=0.18
# Ep 348/10000, manager_return=0.03, epsM=0.17, epsW=0.17
# Ep 349/10000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 350/10000, manager_return=0.03, epsM=0.17, epsW=0.17
# Ep 351/10000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 352/10000, manager_return=0.06, epsM=0.17, epsW=0.17
# Ep 353/10000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 354/10000, manager_return=0.04, epsM=0.17, epsW=0.17
# Ep 355/10000, manager_return=0.02, epsM=0.17, epsW=0.17
# Ep 356/10000, manager_return=0.01, epsM=0.17, epsW=0.17
# Ep 357/10000, manager_return=0.04, epsM=0.17, epsW=0.17
# Ep 358/10000, manager_return=0.05, epsM=0.17, epsW=0.17
# Ep 359/10000, manager_return=0.03, epsM=0.17, epsW=0.17
# Ep 360/10000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 361/10000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 362/10000, manager_return=0.04, epsM=0.16, epsW=0.16
# Ep 363/10000, manager_return=0.03, epsM=0.16, epsW=0.16
# Ep 364/10000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 365/10000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 366/10000, manager_return=0.03, epsM=0.16, epsW=0.16
# Ep 367/10000, manager_return=0.03, epsM=0.16, epsW=0.16
# Ep 368/10000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 369/10000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 370/10000, manager_return=0.01, epsM=0.16, epsW=0.16
# Ep 371/10000, manager_return=0.02, epsM=0.16, epsW=0.16
# Ep 372/10000, manager_return=0.08, epsM=0.15, epsW=0.15
# Ep 373/10000, manager_return=0.02, epsM=0.15, epsW=0.15
# Ep 374/10000, manager_return=0.02, epsM=0.15, epsW=0.15
# Ep 375/10000, manager_return=0.01, epsM=0.15, epsW=0.15
# Ep 376/10000, manager_return=0.03, epsM=0.15, epsW=0.15
# Ep 377/10000, manager_return=0.06, epsM=0.15, epsW=0.15
# Ep 378/10000, manager_return=0.03, epsM=0.15, epsW=0.15
# Ep 379/10000, manager_return=0.00, epsM=0.15, epsW=0.15
# Ep 380/10000, manager_return=0.07, epsM=0.15, epsW=0.15
# Ep 381/10000, manager_return=0.06, epsM=0.15, epsW=0.15
# Ep 382/10000, manager_return=0.02, epsM=0.15, epsW=0.15
# Ep 383/10000, manager_return=0.02, epsM=0.15, epsW=0.15
# Ep 384/10000, manager_return=0.04, epsM=0.15, epsW=0.15
# Ep 385/10000, manager_return=0.12, epsM=0.15, epsW=0.15
# Ep 386/10000, manager_return=0.05, epsM=0.14, epsW=0.14
# Ep 387/10000, manager_return=0.08, epsM=0.14, epsW=0.14
# Ep 388/10000, manager_return=0.10, epsM=0.14, epsW=0.14
# Ep 389/10000, manager_return=0.03, epsM=0.14, epsW=0.14
# Ep 390/10000, manager_return=0.07, epsM=0.14, epsW=0.14
# Ep 391/10000, manager_return=0.05, epsM=0.14, epsW=0.14
# Ep 392/10000, manager_return=0.04, epsM=0.14, epsW=0.14
# Ep 393/10000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 394/10000, manager_return=0.04, epsM=0.14, epsW=0.14
# Ep 395/10000, manager_return=0.01, epsM=0.14, epsW=0.14
# Ep 396/10000, manager_return=0.05, epsM=0.14, epsW=0.14
# Ep 397/10000, manager_return=0.04, epsM=0.14, epsW=0.14
# Ep 398/10000, manager_return=0.05, epsM=0.14, epsW=0.14
# Ep 399/10000, manager_return=0.06, epsM=0.14, epsW=0.14
# Ep 400/10000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 401/10000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 402/10000, manager_return=0.00, epsM=0.13, epsW=0.13
# Ep 403/10000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 404/10000, manager_return=0.03, epsM=0.13, epsW=0.13
# Ep 405/10000, manager_return=0.06, epsM=0.13, epsW=0.13
# Ep 406/10000, manager_return=0.04, epsM=0.13, epsW=0.13
# Ep 407/10000, manager_return=0.08, epsM=0.13, epsW=0.13
# Ep 408/10000, manager_return=0.10, epsM=0.13, epsW=0.13
# Ep 409/10000, manager_return=0.07, epsM=0.13, epsW=0.13
# Ep 410/10000, manager_return=0.12, epsM=0.13, epsW=0.13
# Ep 411/10000, manager_return=0.02, epsM=0.13, epsW=0.13
# Ep 412/10000, manager_return=0.03, epsM=0.13, epsW=0.13
# Ep 413/10000, manager_return=0.01, epsM=0.13, epsW=0.13
# Ep 414/10000, manager_return=0.09, epsM=0.13, epsW=0.13
# Ep 415/10000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 416/10000, manager_return=0.05, epsM=0.12, epsW=0.12
# Ep 417/10000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 418/10000, manager_return=0.07, epsM=0.12, epsW=0.12
# Ep 419/10000, manager_return=0.03, epsM=0.12, epsW=0.12
# Ep 420/10000, manager_return=0.05, epsM=0.12, epsW=0.12
# Ep 421/10000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 422/10000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 423/10000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 424/10000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 425/10000, manager_return=0.03, epsM=0.12, epsW=0.12
# Ep 426/10000, manager_return=0.06, epsM=0.12, epsW=0.12
# Ep 427/10000, manager_return=0.05, epsM=0.12, epsW=0.12
# Ep 428/10000, manager_return=0.05, epsM=0.12, epsW=0.12
# Ep 429/10000, manager_return=0.00, epsM=0.12, epsW=0.12
# Ep 430/10000, manager_return=0.01, epsM=0.12, epsW=0.12
# Ep 431/10000, manager_return=0.04, epsM=0.12, epsW=0.12
# Ep 432/10000, manager_return=0.08, epsM=0.11, epsW=0.11
# Ep 433/10000, manager_return=0.04, epsM=0.11, epsW=0.11
# Ep 434/10000, manager_return=0.02, epsM=0.11, epsW=0.11
# Ep 435/10000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 436/10000, manager_return=0.01, epsM=0.11, epsW=0.11
# Ep 437/10000, manager_return=0.05, epsM=0.11, epsW=0.11
# Ep 438/10000, manager_return=0.00, epsM=0.11, epsW=0.11
# Ep 439/10000, manager_return=0.03, epsM=0.11, epsW=0.11
# Ep
10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9866/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9867/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9868/10000, manager_return=0.26, epsM=0.10, epsW=0.10
# Ep 9869/10000, manager_return=0.24, epsM=0.10, epsW=0.10
# Ep 9870/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9871/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9872/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9873/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9874/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9875/10000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 9876/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9877/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9878/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9879/10000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 9880/10000, manager_return=0.22, epsM=0.10, epsW=0.10
# Ep 9881/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9882/10000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 9883/10000, manager_return=0.26, epsM=0.10, epsW=0.10
# Ep 9884/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9885/10000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 9886/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9887/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9888/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9889/10000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 9890/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9891/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9892/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9893/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9894/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9895/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9896/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9897/10000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 9898/10000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 9899/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9900/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9901/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9902/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9903/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9904/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9905/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9906/10000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 9907/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9908/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9909/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9910/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9911/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9912/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9913/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9914/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9915/10000, manager_return=0.20, epsM=0.10, epsW=0.10
# Ep 9916/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9917/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9918/10000, manager_return=0.26, epsM=0.10, epsW=0.10
# Ep 9919/10000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 9920/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9921/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9922/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9923/10000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 9924/10000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 9925/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9926/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9927/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9928/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9929/10000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 9930/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9931/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9932/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9933/10000, manager_return=0.23, epsM=0.10, epsW=0.10
# Ep 9934/10000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 9935/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9936/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9937/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9938/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9939/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9940/10000, manager_return=0.17, epsM=0.10, epsW=0.10
# Ep 9941/10000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 9942/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9943/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9944/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9945/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9946/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9947/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9948/10000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 9949/10000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 9950/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9951/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9952/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9953/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9954/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9955/10000, manager_return=0.19, epsM=0.10, epsW=0.10
# Ep 9956/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9957/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9958/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9959/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9960/10000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 9961/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9962/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9963/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9964/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9965/10000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 9966/10000, manager_return=0.04, epsM=0.10, epsW=0.10
# Ep 9967/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9968/10000, manager_return=0.12, epsM=0.10, epsW=0.10
# Ep 9969/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9970/10000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 9971/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9972/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9973/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9974/10000, manager_return=0.00, epsM=0.10, epsW=0.10
# Ep 9975/10000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 9976/10000, manager_return=0.13, epsM=0.10, epsW=0.10
# Ep 9977/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9978/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9979/10000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 9980/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9981/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9982/10000, manager_return=0.09, epsM=0.10, epsW=0.10
# Ep 9983/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 9984/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9985/10000, manager_return=0.10, epsM=0.10, epsW=0.10
# Ep 9986/10000, manager_return=0.15, epsM=0.10, epsW=0.10
# Ep 9987/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9988/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9989/10000, manager_return=0.06, epsM=0.10, epsW=0.10
# Ep 9990/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9991/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Ep 9992/10000, manager_return=0.07, epsM=0.10, epsW=0.10
# Ep 9993/10000, manager_return=0.11, epsM=0.10, epsW=0.10
# Ep 9994/10000, manager_return=0.02, epsM=0.10, epsW=0.10
# Ep 9995/10000, manager_return=0.16, epsM=0.10, epsW=0.10
# Ep 9996/10000, manager_return=0.03, epsM=0.10, epsW=0.10
# Ep 9997/10000, manager_return=0.08, epsM=0.10, epsW=0.10
# Ep 9998/10000, manager_return=0.14, epsM=0.10, epsW=0.10
# Ep 9999/10000, manager_return=0.05, epsM=0.10, epsW=0.10
# Ep 10000/10000, manager_return=0.01, epsM=0.10, epsW=0.10
# Feudal training complete.
# Training done. Manager and Worker stored as variables.
# /var/folders/km/9hmy_qv946z1t5m7z35vf6600000gn/T/ipykernel_85312/1529847969.py:433: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed in 3.10. Use buffer_rgba instead.
#   buf = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
# Demo run saved to feudal_3d_sculpt_demo.gif
# All done. Demo is in feudal_3d_sculpt_demo.gif
